# %%
import pandas as pd
from os.path import join

NET_DIR = '/home/pc/Desktop/AdilStuff/Projects/SemRepMed/umls semantic network/processed_data'

# %%
pd.read_csv(join(NET_DIR, 'meta_net.csv'))
# Out:
#       relation_name link_status  nan_values version head_abv tail_abv  \
# 0    co-occurs_with           D         NaN  2013AB     acab     inpo
# 1               isa           D         NaN  2013AB     acab     anab
# 2         result_of           D         NaN  2013AB     acab     bhvr
# 3               isa           D         NaN  2013AB     acty     evnt
# 4               isa           D         NaN  2013AB     aggp     grup
# ..              ...         ...         ...     ...      ...      ...
# 753      process_of           B         NaN    1992     orgf     celf
# 754      process_of           B         NaN    1992     orgf     moft
# 755      process_of           B         NaN    1992     ortf     celf
# 756      process_of           B         NaN    1992     ortf     moft
# 757      process_of           B         NaN    1992     celf     moft
#
#                          head                    tail
# 0        Acquired Abnormality     Injury or Poisoning
# 1        Acquired Abnormality  Anatomical Abnormality
# 2        Acquired Abnormality                Behavior
# 3                    Activity                   Event
# 4                   Age Group                   Group
# ..                        ...                     ...
# 753         Organism Function           Cell Function
# 754         Organism Function      Molecular Function
# 755  Organ or Tissue Function           Cell Function
# 756  Organ or Tissue Function      Molecular Function
# 757             Cell Function      Molecular Function
#
# [758 rows x 8 columns]

# %%
pd.read_csv(join(NET_DIR, 'rel_heirarchy.csv'))
# Out:
#                          H0                       H1                       H2  \
# 0     physically_related_to    physically_related_to    physically_related_to
# 1     physically_related_to                  part_of                  part_of
# 2     physically_related_to                 contains                 contains
# 3      spatially_related_to              location_of              location_of
# 4     temporally_related_to    temporally_related_to    temporally_related_to
# 5     temporally_related_to           co-occurs_with           co-occurs_with
# 6     temporally_related_to                 precedes                 precedes
# 7   functionally_related_to  functionally_related_to  functionally_related_to
# 8   functionally_related_to                occurs_in               process_of
# 9   functionally_related_to                 performs              carries_out
# 10  functionally_related_to                  affects           interacts_with
# 11  functionally_related_to                 performs                practices
# 12  functionally_related_to             brings_about                 produces
# 13  functionally_related_to                 performs                 exhibits
# 14  functionally_related_to                  affects                 disrupts
# 15  functionally_related_to             brings_about                   causes
# 16  functionally_related_to                  affects                 prevents
# 17  functionally_related_to                  affects              complicates
# 18  functionally_related_to         manifestation_of         manifestation_of
# 19  functionally_related_to                  affects                  affects
# 20  functionally_related_to                occurs_in                occurs_in
# 21  functionally_related_to                  affects                  manages
# 22  functionally_related_to                  affects                   treats
# 23  functionally_related_to                     uses                     uses
# 24  functionally_related_to                indicates                indicates
# 25  functionally_related_to                result_of                result_of
# 26  conceptually_related_to  conceptually_related_to  conceptually_related_to
# 27  conceptually_related_to              property_of              property_of
# 28  conceptually_related_to       conceptual_part_of       conceptual_part_of
# 29  conceptually_related_to            evaluation_of            evaluation_of
# 30  conceptually_related_to                 measures                 measures
# 31  conceptually_related_to                diagnoses                diagnoses
# 32  conceptually_related_to                 analyzes       assesses_effect_of
# 33  conceptually_related_to                 issue_in                 issue_in
# 34          associated_with          associated_with          associated_with
# 35    physically_related_to              consists_of              consists_of
# 36     spatially_related_to              adjacent_to              adjacent_to
# 37    physically_related_to             connected_to             connected_to
# 38    physically_related_to            interconnects            interconnects
# 39     spatially_related_to                surrounds                surrounds
# 40     spatially_related_to                traverses                traverses
# 41  conceptually_related_to            derivative_of            derivative_of
# 42  conceptually_related_to    developmental_form_of    developmental_form_of
# 43  conceptually_related_to                degree_of                degree_of
# 44  conceptually_related_to           measurement_of           measurement_of
# 45  conceptually_related_to                method_of                method_of
# 46                      isa                      isa                      isa
# 47  functionally_related_to             brings_about             brings_about
# 48  functionally_related_to                 performs                 performs
# 49     spatially_related_to     spatially_related_to     spatially_related_to
# 50  conceptually_related_to                 analyzes                 analyzes
# 51    physically_related_to                branch_of                branch_of
# 52    physically_related_to             tributary_of             tributary_of
# 53    physically_related_to            ingredient_of            ingredient_of
#
#     Level
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
# 5       1
# 6       1
# 7       0
# 8       2
# 9       2
# 10      2
# 11      2
# 12      2
# 13      2
# 14      2
# 15      2
# 16      2
# 17      2
# 18      1
# 19      1
# 20      1
# 21      2
# 22      2
# 23      1
# 24      1
# 25      1
# 26      0
# 27      1
# 28      1
# 29      1
# 30      1
# 31      1
# 32      2
# 33      1
# 34      0
# 35      1
# 36      1
# 37      1
# 38      1
# 39      1
# 40      1
# 41      1
# 42      1
# 43      1
# 44      1
# 45      1
# 46      0
# 47      1
# 48      1
# 49      0
# 50      1
# 51      1
# 52      1
# 53      1

# %%
df = pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')
