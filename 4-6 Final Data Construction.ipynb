# %% [markdown]
# The Objective of this note book is to integrate the different modelities into one knowledge graph. The modalities are:
#
# - structural: constituted by the triples of the knowledge graph
# - uncertain: constituted by the factuality based confidence scores
# - temporal: constituted by the time validity of the different triples
# - semantic: constituted by the triples' definitions

# %%
import pandas as pd
from os.path import join
import json
TRIPLES_DIR = 'all_triples'
CITATIONS_DIR = 'CITATIONS'
TRIP_SENT_DIR = 'TRIPLE_SENTENCES'
SELECTED_TRIPLES = 'Selected Triples'
PROC_UMLS = '/home/pc/Desktop/AdilStuff/Projects/SemRepMed/umls processed net data'

COVID_CUIs = ['C5203670', 'C5203671', 'C5203672', 'C5203673', 'C5203674', 'C5203675', 'C5203676']

# %%
def write_json_lines(file_name,dict_data):
    json_string = json.dumps(dict_data)
    with open(file_name, 'a') as f:
        f.write(json_string+"\n")
        
def read_json_lines(file_name):
    lines = []
    with open(file_name) as file_in:
        for line in file_in:
            lines.append(json.loads(line))
    return lines

def read_json(file_name):
    with open(file_name, 'r') as f:
        data = json.load(f)
    return data

def get_all_data(fully_complete = True):
    # entity to type mapping
    ent_2_type_map = read_json(join('all_triples', 'all_entity_types.json'))
    # entity to name 
    ent_2_name_map = read_json(join('all_triples', 'all_entity_names.json'))
    ###################### Modalities
    # structural and uncertain modality data
    str_un_mod_df = pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')
    # time modality data
    time_mod_df = pd.DataFrame(read_json_lines(join(TRIPLES_DIR, 'origin_time.jsonl')))
    ##### semantic modality data
    # entity semantics
    ent_sem_mod_df = pd.read_csv(join('all_triples', 'entity_description_can.csv'), compression = 'gzip')
    # relation semantics
    rel_sem_mod_df = pd.read_csv(join('all_triples', 'relation_type_description.csv'), compression = 'gzip')
    # entity type semantics
    type_sem_mod_df =pd.read_csv(join('all_triples', 'entity_type_description.csv'), compression = 'gzip')
    #### structural semantics: different relations withe different types
    tran_comp = read_json(join(PROC_UMLS, 'umls_biokg_rel_patterns.json'))
    # transitive relations
    transitive_rels = tran_comp['transitive_rels']
    # composition relations
    composition_rels = tran_comp['composition_rels']
    # relation hierarchy
    rel_heirarchy = pd.read_csv(join(PROC_UMLS, 'rel_heirarchy.csv'))
    # type heirarchy
    ent_type_heirarchy = pd.read_csv(join(PROC_UMLS, 'ent_type_heirarchy.csv'))
    # meta kg
    sem_net = pd.read_csv(join(PROC_UMLS, 'sem_network.csv'))

def completeness_filtering(str_un_mod_df):
    # time modality data
    time_mod_df = pd.DataFrame(read_json_lines(join(TRIPLES_DIR, 'origin_time.jsonl')))
    ##### semantic modality data
    # entity semantics
    ent_sem_mod_df = pd.read_csv(join('all_triples', 'entity_description_can.csv'), compression = 'gzip')
    ent_sem_mod_df = ent_sem_mod_df[~ent_sem_mod_df['DEFINITION'].isna()]
    # relation semantics
    rel_sem_mod_df = pd.read_csv(join('all_triples', 'relation_type_description.csv'), compression = 'gzip')
    # entity type semantics
    type_sem_mod_df =pd.read_csv(join('all_triples', 'entity_type_description.csv'), compression = 'gzip')
    ##### Filtering
    print('original count: ', str_un_mod_df.shape[0])
    str_un_mod_df = str_un_mod_df[str_un_mod_df['SUBJECT_CUI'].isin(ent_sem_mod_df['ENTITY']) & str_un_mod_df['OBJECT_CUI'].isin(ent_sem_mod_df['ENTITY'])]
    print('count leaving only ents with description: ', str_un_mod_df.shape[0])
    str_un_mod_df = str_un_mod_df[str_un_mod_df['ORIGIN_ID'].isin(time_mod_df['ORIGIN_ID'])]
    print('count leaving only triples with time: ', str_un_mod_df.shape[0])
    str_un_mod_df = str_un_mod_df[str_un_mod_df['SUBJECT_TYPE'].isin(type_sem_mod_df['abbreviation']) & str_un_mod_df['OBJECT_TYPE'].isin(type_sem_mod_df['abbreviation'])]
    print('count leaving only types with : ', str_un_mod_df.shape[0])
    str_un_mod_df = str_un_mod_df[str_un_mod_df['PREDICATE'].isin(list(rel_sem_mod_df['name']) + list(rel_sem_mod_df['relation_inverse']))]
    print('count leaving only relations with description: ', str_un_mod_df.shape[0])
    return str_un_mod_df

def get_completed_data():
    # not all entities have a description and not all triples have a date
    # this function extract the triples for the complete entities only
    # entity to type mapping
    ent_2_type_map = read_json(join('all_triples', 'all_entity_types.json'))
    # entity to name 
    ent_2_name_map = read_json(join('all_triples', 'all_entity_names.json'))
    # structural and uncertain modality data
    str_un_mod_df = pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')
    str_un_mod_df['SUBJECT_TYPE'] = str_un_mod_df['SUBJECT_CUI'].map(ent_2_type_map)
    str_un_mod_df['OBJECT_TYPE'] = str_un_mod_df['OBJECT_CUI'].map(ent_2_type_map)
    str_un_mod_df = completeness_filtering(str_un_mod_df.copy())
    return str_un_mod_df

def get_ent_types():
    ent_2_type_map = read_json(join('all_triples', 'all_entity_types.json'))
    # entity to name 
    ent_2_name_map = read_json(join('all_triples', 'all_entity_names.json'))
    # structural and uncertain modality data
    str_un_mod_df = pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')
    str_un_mod_df['SUBJECT_TYPE'] = str_un_mod_df['SUBJECT_CUI'].map(ent_2_type_map)
    str_un_mod_df['OBJECT_TYPE'] = str_un_mod_df['OBJECT_CUI'].map(ent_2_type_map)
    return str_un_mod_df

def get_sub_schema_triples(ent_types):
    # the objective of this function is the selection of the different
    # 
    ent_2_type_map = read_json(join('all_triples', 'all_entity_types.json'))
    # entity to name 
    ent_2_name_map = read_json(join('all_triples', 'all_entity_names.json'))
    # structural and uncertain modality data
    str_un_mod_df = pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')
    str_un_mod_df['SUBJECT_TYPE'] = str_un_mod_df['SUBJECT_CUI'].map(ent_2_type_map)
    str_un_mod_df['OBJECT_TYPE'] = str_un_mod_df['OBJECT_CUI'].map(ent_2_type_map)
    str_un_mod_df = str_un_mod_df[str_un_mod_df['SUBJECT_TYPE'].isin(ent_types) & str_un_mod_df['OBJECT_TYPE'].isin(ent_types)]
    return str_un_mod_df

def get_specialized_data(intrest_ents):
    # in the case where we have a certain entity that we are intrested in studying
    # we can take the a) entity type b) go to the semantic net and get the meta kg
    # c) onnly take triples whose entity types exist in the meta kg
    # this ensures local completness while reducing the number of triples to train
    # the discarded entities wont have any relation with the targer*t entity anyway
    # entity to type mapping
    ent_2_type_map = read_json(join('all_triples', 'all_entity_types.json'))
    # entity to name 
    ent_2_name_map = read_json(join('all_triples', 'all_entity_names.json'))
    
    intrest_ents_types = list(map(ent_2_type_map.get, intrest_ents))
    sem_net = pd.read_csv(join(PROC_UMLS, 'sem_network.csv'))
    extend_sem_types = sem_net[sem_net['head_type'].isin(intrest_ents_types) | sem_net['tail_type'].isin(intrest_ents_types)]
    extend_sem_types = list(set(list(extend_sem_types['head_type'])+list(extend_sem_types['tail_type'])))
    ### full KG with ent sem types
    str_un_mod_df = pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')    
    str_un_mod_df['SUBJECT_TYPE'] = str_un_mod_df['SUBJECT_CUI'].map(ent_2_type_map)
    str_un_mod_df['OBJECT_TYPE'] = str_un_mod_df['OBJECT_CUI'].map(ent_2_type_map)
    # triples with entities of intrest that should be included
    sub_intrest = str_un_mod_df[str_un_mod_df['SUBJECT_CUI'].isin(intrest_ents) | str_un_mod_df['OBJECT_CUI'].isin(intrest_ents)]
    print('full kg: ', str_un_mod_df.shape[0])
    ### 
    str_un_mod_df = str_un_mod_df[str_un_mod_df['SUBJECT_TYPE'].isin(extend_sem_types) & str_un_mod_df['OBJECT_TYPE'].isin(extend_sem_types)]
    print('target schema complet kg: ', str_un_mod_df.shape[0])
    ###### add the covid specific triples, concat, then  remove duplicates / this is to insure the 
    str_un_mod_df = completeness_filtering(str_un_mod_df.copy())
    str_un_mod_df = pd.concat([str_un_mod_df, sub_intrest]).drop_duplicates()
    return str_un_mod_df

# %% [markdown]
# ## Full Triples

# %%
get_completed_data()
# Out:
# original count:  28416917
# count leaving only ents with description:  12104432
# count leaving only triples with time:  12104432
# count leaving only types with :  12104432
# count leaving only relations with description:  8269295
#           ORIGIN_ID       PREDICATE SUBJECT_CUI OBJECT_CUI  label_proba  \
# 5                 5          CAUSES    C0042776   C0012634      0.92434
# 10                9         PART_OF    C0242210   C0006034      1.00000
# 13               12  INTERACTS_WITH    C0004611   C0025646      0.96875
# 14               13         AFFECTS    C0031516   C0017262      0.93750
# 16               15         PART_OF    C1167395   C0042567      0.99097
# ...             ...             ...         ...        ...          ...
# 28416904   23857431         AFFECTS    C2985438   C0282577      1.00000
# 28416907   23857433      PROCESS_OF    C1519323   C1333691      1.00000
# 28416908   23857433      PROCESS_OF    C1519323   C1333691      1.00000
# 28416915   23857436      PROCESS_OF    C4023614   C1413914      1.00000
# 28416916   23857436      PROCESS_OF    C4023614   C1413914      1.00000
#
#          SUBJECT_TYPE OBJECT_TYPE
# 5                virs        dsyn
# 10               aapp        bact
# 13               bact        aapp
# 14               bacs        genf
# 16               orgm        vtbt
# ...               ...         ...
# 28416904         comd        dsyn
# 28416907         genf        aapp
# 28416908         genf        aapp
# 28416915         genf        aapp
# 28416916         genf        aapp
#
# [8269295 rows x 7 columns]

# %%
covid_selected_df = get_specialized_data(COVID_CUIs)
# 8170408
# Out:
# full kg:  28416917
# target schema complet kg:  28048295
# original count:  28048295
# count leaving only ents with description:  11965927
# count leaving only triples with time:  11965927
# count leaving only types with :  11965927
# count leaving only relations with description:  8170408

# %%
covid_selected_df
# Out:
#           ORIGIN_ID       PREDICATE SUBJECT_CUI OBJECT_CUI  label_proba  \
# 5                 5          CAUSES    C0042776   C0012634      0.92434
# 10                9         PART_OF    C0242210   C0006034      1.00000
# 13               12  INTERACTS_WITH    C0004611   C0025646      0.96875
# 14               13         AFFECTS    C0031516   C0017262      0.93750
# 16               15         PART_OF    C1167395   C0042567      0.99097
# ...             ...             ...         ...        ...          ...
# 28415776   23856508     PREDISPOSES    C0026769   C5203670      1.00000
# 28415805   23856535          CAUSES    C5203670   C0302158      1.00000
# 28416431   23857062        PREVENTS    C0055361   C5203676      1.00000
# 28416685   23857260   COEXISTS_WITH    C1510586   C5203670      1.00000
# 28416748   23857309   COEXISTS_WITH    C3203547   C5203670      1.00000
#
#          SUBJECT_TYPE OBJECT_TYPE
# 5                virs        dsyn
# 10               aapp        bact
# 13               bact        aapp
# 14               bacs        genf
# 16               orgm        vtbt
# ...               ...         ...
# 28415776         dsyn        dsyn
# 28415805         dsyn        patf
# 28416431         phsu        virs
# 28416685         mobd        dsyn
# 28416748         dsyn        dsyn
#
# [7867182 rows x 7 columns]

# %%
covid_selected_df[covid_selected_df['SUBJECT_CUI'].isin(COVID_CUIs) | covid_selected_df['OBJECT_CUI'].isin(COVID_CUIs)]
# Out:
#           ORIGIN_ID        PREDICATE SUBJECT_CUI OBJECT_CUI  label_proba  \
# 24628645   20881082    COEXISTS_WITH    C0161479   C5203670     1.000000
# 24628646   20881083       PROCESS_OF    C5203676   C0030705     0.982900
# 24628656   20881093           CAUSES    C5203676   C0275518     0.916667
# 24628657   20881094           CAUSES    C0206750   C5203670     0.993223
# 24628660   20881097  ASSOCIATED_WITH    C0014695   C5203670     0.775862
# ...             ...              ...         ...        ...          ...
# 28415776   23856508      PREDISPOSES    C0026769   C5203670     1.000000
# 28415805   23856535           CAUSES    C5203670   C0302158     1.000000
# 28416431   23857062         PREVENTS    C0055361   C5203676     1.000000
# 28416685   23857260    COEXISTS_WITH    C1510586   C5203670     1.000000
# 28416748   23857309    COEXISTS_WITH    C3203547   C5203670     1.000000
#
#          SUBJECT_TYPE OBJECT_TYPE
# 24628645         inpo        dsyn
# 24628646         virs        humn
# 24628656         virs        dsyn
# 24628657         dsyn        dsyn
# 24628660         phsu        dsyn
# ...               ...         ...
# 28415776         dsyn        dsyn
# 28415805         dsyn        patf
# 28416431         phsu        virs
# 28416685         mobd        dsyn
# 28416748         dsyn        dsyn
#
# [17405 rows x 7 columns]

# %%
covid_selected_df.to_csv(join(SELECTED_TRIPLES, 'COVID Complet', 'full_kg.csv'), compression = 'gzip', index= False)

# %% [markdown]
# ## Type Based Study
# The objective of this extraction process is the definition of a domain specific schema complet KG.
#
# Risk factor type abbreviations are:
# 'hlca', 'eehu', 'ocac', 'aggp', 'dora', 'orga', 'socb', 'imft', 'hops', 'famg', 'genf', 'geoa'
# (look in 'UMLS Semantic Network Structure' for how we found them based on https://www.researchgate.net/publication/258741187_Comorbidities_Modeling_for_Supporting_Integrated_Care_in_Chronic_Cardiorenal_Disease)

# %% [markdown]
# ### Select the right types

# %%
str_un_mod_df = get_ent_types()

# %%
str_un_mod_df
# Out:
#           ORIGIN_ID      PREDICATE SUBJECT_CUI OBJECT_CUI  label_proba  \
# 0                 0     PROCESS_OF    C0003725   C0999630     1.000000
# 1                 1            ISA    C0039258   C0446169     1.000000
# 2                 2            ISA    C0318627   C0206590     1.000000
# 3                 3            ISA    C0446169   C0003725     1.000000
# 4                 4     PROCESS_OF    C0012634   C0020114     0.989018
# ...             ...            ...         ...        ...          ...
# 28416912   23857434  COEXISTS_WITH    C1413909   C1413914     1.000000
# 28416913   23857435     PROCESS_OF    C4023614   C1413909     1.000000
# 28416914   23857435     PROCESS_OF    C4023614   C1413909     1.000000
# 28416915   23857436     PROCESS_OF    C4023614   C1413914     1.000000
# 28416916   23857436     PROCESS_OF    C4023614   C1413914     1.000000
#
#          SUBJECT_TYPE OBJECT_TYPE
# 0                gngm        mamm
# 1                virs        virs
# 2                virs        virs
# 3                virs        gngm
# 4                dsyn        grup
# ...               ...         ...
# 28416912         gngm        aapp
# 28416913         genf        gngm
# 28416914         genf        gngm
# 28416915         genf        aapp
# 28416916         genf        aapp
#
# [28416917 rows x 7 columns]

# %%
# covid related types
def get_types(str_un_mod_df):
    all_types = []
    all_types += list(str_un_mod_df[str_un_mod_df['SUBJECT_CUI'].isin(COVID_CUIs)]['SUBJECT_TYPE'])
    all_types += list(str_un_mod_df[str_un_mod_df['OBJECT_CUI'].isin(COVID_CUIs)]['OBJECT_TYPE'])
    return list(set(all_types))

# %%
get_types(str_un_mod_df)
# Out:
# ['aapp', 'dsyn', 'virs', 'fndg', 'topp']

# %% [markdown]
# ### Extracting the SubKG

# %%
ent_types = ['aapp', 'dsyn', 'virs', 'fndg', 'topp', 'hlca', 'eehu', 'ocac', 'aggp', 'dora', 'orga', 'socb', 'imft', 'hops', 'famg', 'genf', 'geoa']

# %%
df = get_sub_schema_triples(ent_types)

# %%
df.to_csv(join(SELECTED_TRIPLES, 'risk factor covid kg', 'full_kg.csv'), compression = 'gzip', index= False)

# %% [markdown]
# ## Tests

# %%
pd.DataFrame(read_json_lines(join(TRIPLES_DIR, 'origin_time.jsonl')))
# Out:
#           ORIGIN_ID             time_min             time_max  true_time
# 0                 0  2006-03-15 00:00:00  2006-03-15 00:00:00       True
# 1                 1  1991-05-01 00:00:00  2006-03-15 00:00:00       True
# 2                 2  2006-03-15 00:00:00  2006-03-15 00:00:00       True
# 3                 3  1988-04-01 00:00:00  2006-03-15 00:00:00       True
# 4                 4  1947-10-01 00:00:00  2017-07-01 00:00:00       True
# ...             ...                  ...                  ...        ...
# 23601729   23857432                                                False
# 23601730   23857433                                                False
# 23601731   23857434                                                False
# 23601732   23857435                                                False
# 23601733   23857436                                                False
#
# [23601734 rows x 4 columns]

# %%
# probability component
pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')
# Out:
#           ORIGIN_ID      PREDICATE SUBJECT_CUI OBJECT_CUI  label_proba
# 0                 0     PROCESS_OF    C0003725   C0999630     1.000000
# 1                 1            ISA    C0039258   C0446169     1.000000
# 2                 2            ISA    C0318627   C0206590     1.000000
# 3                 3            ISA    C0446169   C0003725     1.000000
# 4                 4     PROCESS_OF    C0012634   C0020114     0.989018
# ...             ...            ...         ...        ...          ...
# 28416912   23857434  COEXISTS_WITH    C1413909   C1413914     1.000000
# 28416913   23857435     PROCESS_OF    C4023614   C1413909     1.000000
# 28416914   23857435     PROCESS_OF    C4023614   C1413909     1.000000
# 28416915   23857436     PROCESS_OF    C4023614   C1413914     1.000000
# 28416916   23857436     PROCESS_OF    C4023614   C1413914     1.000000
#
# [28416917 rows x 5 columns]

# %%
# entity description

ent_defs = pd.read_csv(join('all_triples', 'entity_description_can.csv'), compression = 'gzip')

# %%
ent_defs[ent_defs['ENTITY'].isin(COVID_CUIs)]
# Out:
#           ENTITY DEFINITION  \
# 358897  C5203676        NaN
# 358902  C5203670        NaN
# 359004  C5203671        NaN
# 430308  C5203672        NaN
# 447893  C5203674        NaN
# 471009  C5203674        NaN
#
#                                                   ALIASES  \
# 358897  Wuhan coronavirus|2019-nCoV|2019 novel coronav...
# 358902  Disease caused by 2019-nCoV|Disease caused by ...
# 359004  Suspected disease caused by 2019-nCoV|Suspecte...
# 430308  2019 novel coronavirus vaccination|2019-nCoV v...
# 447893  Antibody to 2019 novel coronavirus|Antibody to...
# 471009  Antibody to 2019 novel coronavirus|Antibody to...
#
#                           NAME
# 358897              SARS-CoV-2
# 358902                COVID-19
# 359004      Suspected COVID-19
# 430308  SARS-CoV-2 vaccination
# 447893  Antibody to SARS-CoV-2
# 471009  Antibody to SARS-CoV-2

# %%
ent_defs[~ent_defs['DEFINITION'].isna()]
# Out:
#           ENTITY                                         DEFINITION  \
# 0       C0003725  Arthropod-borne viruses. A non-taxonomic desig...
# 3       C0012634  A definite pathologic process with a character...
# 4       C0042776  Minute infectious agents whose genomes are com...
# 6       C0242210  General term for proteins that have binding as...
# 9       C0242210  General term for proteins that have binding as...
# ...          ...                                                ...
# 474849  C1328042  An epithelial neoplasm arising from the thymus...
# 474854  C1149654  Catalysis of the reaction: dUTP + H2O = dUMP +...
# 474861  C1327041  The chemical reactions and pathways resulting ...
# 474862  C4048299  Tissue factor (295 aa, ~33 kDa) is encoded by ...
# 474863  C4329283  A subgroup of alleles of a polymorphic gene th...
#
#                                                   ALIASES  \
# 0       Arbovirus (navigational concept)|arbovirus|Arb...
# 3       Disease|Clinical disease or syndrome|Clinical ...
# 4       Virus|Virus, NOS|Viruses, General|Virus (organ...
# 6       Ligand Binding Protein|Binding Protein|binding...
# 9       Ligand Binding Protein|Binding Protein|binding...
# ...                                                   ...
# 474849  Plump Cell Thymoma|type B thymoma|epithelioid ...
# 474854  dUTPase activity|dUTP pyrophosphatase activity...
# 474861  mycothiol formation|mycothiol biosynthesis|myc...
# 474862  Thromboplastin|F3 Protein|CD142 Antigen|F3|TF|...
# 474863                              Allelic Family|ALLFAM
#
#                                   NAME
# 0                          Arboviruses
# 3                              Disease
# 4                                Virus
# 6                     Binding Proteins
# 9                     Binding Proteins
# ...                                ...
# 474849                  Thymoma Type B
# 474854   dUTP pyrophosphatase activity
# 474861  mycothiol biosynthetic process
# 474862                   Tissue Factor
# 474863                  Allelic Family
#
# [135794 rows x 4 columns]

# %%
read_json(join('all_triples', 'all_entity_types.json'))
# Out:
# {'C0999630': 'mamm',
#  'C0446169': 'virs',
#  'C0206590': 'virs',
#  'C0003725': 'gngm',
#  'C0020114': 'grup',
#  'C0012634': 'dsyn',
#  'C0003241': 'aapp',
#  'C0002273': 'gngm',
#  'C0006034': 'bact',
#  'C0019878': 'aapp',
#  'C0025646': 'aapp',
#  'C0017262': 'genf',
#  'C0001675': 'humn',
#  'C0042567': 'vtbt',
#  'C1167395': 'orgm',
#  'C0003062': 'anim',
#  'C0162318': 'anim',
#  'C1136254': 'phsu',
#  'C0949665': 'orch',
#  'C0013227': 'phsu',
#  'C0014061': 'dsyn',
#  'C0030705': 'humn',
#  'C0086287': 'orga',
#  'C0086582': 'orga',
#  'C1552130': 'bpoc',
#  'C0237401': 'humn',
#  'C1457887': 'sosy',
#  'C0021311': 'dsyn',
#  'C0089701': 'orch',
#  'C0012854': 'bacs',
#  'C0456981': 'imft',
#  'C0021368': 'patf',
#  'C0004368': 'patf',
#  'C0039194': 'cell',
#  'C0003315': 'gngm',
#  'C0670896': 'aapp',
#  'C1185625': 'bsoj',
#  'C0597357': 'aapp',
#  'C0035549': 'orch',
#  'C0162638': 'celf',
#  'C0998896': 'fish',
#  'C0332124': 'fndg',
#  'C0015780': 'orga',
#  'C0998689': 'euka',
#  'C0017199': 'emst',
#  'C0162415': 'emst',
#  'C0181909': 'medd',
#  'C0005539': 'gngm',
#  'C0026591': 'famg',
#  'C0028661': 'prog',
#  'C0037863': 'cell',
#  'C0007634': 'cell',
#  'C0036679': 'patf',
#  'C0034693': 'mamm',
#  'C0032594': 'orch',
#  'C0033692': 'aapp',
#  'C0017973': 'bacs',
#  'C0028959': 'orch',
#  'C0204514': 'topp',
#  'C0012611': 'orch',
#  'C1533168': 'phsu',
#  'C0039231': 'fndg',
#  'C0029463': 'neop',
#  'C0006826': 'neop',
#  'C0683971': 'humn',
#  'C0087111': 'topp',
#  'C0020063': 'aapp',
#  'C0025741': 'aapp',
#  'C0027651': 'neop',
#  'C0017337': 'gngm',
#  'C1414461': 'gngm',
#  'C1412099': 'gngm',
#  'C1414462': 'gngm',
#  'C1412100': 'gngm',
#  'C0014939': 'orch',
#  'C0043210': 'popg',
#  'C0029456': 'dsyn',
#  'C0028754': 'dsyn',
#  'C0227525': 'cell',
#  'C0021390': 'dsyn',
#  'C0020541': 'dsyn',
#  'C0001645': 'gngm',
#  'C0016059': 'patf',
#  'C1511606': 'fndg',
#  'C0235974': 'neop',
#  'C0027051': 'dsyn',
#  'C0240816': 'humn',
#  'C0342257': 'dsyn',
#  'C1275743': 'fndg',
#  'C0011854': 'dsyn',
#  'C0008946': 'npop',
#  'C0016627': 'dsyn',
#  'C0027361': 'humn',
#  'C0012746': 'mobd',
#  'C1261469': 'dsyn',
#  'C1565489': 'dsyn',
#  'C0699748': 'patf',
#  'C0010852': 'gngm',
#  'C0024141': 'dsyn',
#  'C0879626': 'patf',
#  'C0011065': 'orgf',
#  'C0160420': 'inpo',
#  'C0277785': 'patf',
#  'C0079189': 'aapp',
#  'C0175677': 'inpo',
#  'C0008059': 'aggp',
#  'C0015879': 'bacs',
#  'C0022658': 'dsyn',
#  'C1257890': 'humn',
#  'C0022661': 'dsyn',
#  'C0035078': 'dsyn',
#  'C0011947': 'phsu',
#  'C0021760': 'aapp',
#  'C1159690': 'celf',
#  'C0019868': 'biof',
#  'C0552639': 'cell',
#  'C0031727': 'aapp',
#  'C0002006': 'gngm',
#  'C0040649': 'genf',
#  'C0005826': 'fndg',
#  'C0022646': 'bpoc',
#  'C0019247': 'dsyn',
#  'C1272641': 'fndg',
#  'C0596070': 'popg',
#  'C0574785': 'sosy',
#  'C0025266': 'humn',
#  'C0003385': 'phsu',
#  'C0680022': 'popg',
#  'C0026447': 'mamm',
#  'C0034927': 'hlca',
#  'C1261322': 'hlca',
#  'C0162326': 'nusq',
#  'C0201683': 'lbpr',
#  'C0021102': 'medd',
#  'C0221192': 'prog',
#  'C0022122': 'bpoc',
#  'C0206365': 'bpoc',
#  'C0037004': 'blor',
#  'C0243032': 'diap',
#  'C0947637': 'patf',
#  'C0007282': 'dsyn',
#  'C0333463': 'acab',
#  'C0260280': 'humn',
#  'C0871685': 'prog',
#  'C0037313': 'orgf',
#  'C0037317': 'sosy',
#  'C0442696': 'phsf',
#  'C0920580': 'prog',
#  'C0039593': 'resa',
#  'C0003364': 'phsu',
#  'C1420485': 'gngm',
#  'C1421917': 'gngm',
#  'C0948089': 'dsyn',
#  'C0162589': 'medd',
#  'C0017638': 'neop',
#  'C0007595': 'celf',
#  'C0178874': 'neop',
#  'C0074992': 'orch',
#  'C0599779': 'anim',
#  'C0431085': 'cell',
#  'C1307407': 'aapp',
#  'C1302475': 'aapp',
#  'C0280100': 'neop',
#  'C0678613': 'npop',
#  'C0013081': 'moft',
#  'C0023467': 'neop',
#  'C0026809': 'mamm',
#  'C0596263': 'neop',
#  'C0242379': 'neop',
#  'C0001418': 'neop',
#  'C0599161': 'mbrt',
#  'C0685938': 'neop',
#  'C0237753': 'qnco',
#  'C0027627': 'neop',
#  'C1326912': 'neop',
#  'C0003250': 'aapp',
#  'C0005847': 'bpoc',
#  'C0450238': 'gngm',
#  'C0028303': 'genf',
#  'C0796346': 'diap',
#  'C0015576': 'humn',
#  'C0009917': 'anab',
#  'C0205851': 'neop',
#  'C0175895': 'patf',
#  'C0039082': 'dsyn',
#  'C0221198': 'fndg',
#  'C0687140': 'neop',
#  'C0027960': 'neop',
#  'C0023516': 'cell',
#  'C1427070': 'gngm',
#  'C1117581': 'gngm',
#  'C0021270': 'humn',
#  'C0030208': 'mnob',
#  'C0162789': 'mbrt',
#  'C0182400': 'medd',
#  'C0004509': 'dsyn',
#  'C1420418': 'aapp',
#  'C1426736': 'aapp',
#  'C0026882': 'genf',
#  'C0006926': 'gngm',
#  'C0243069': 'patf',
#  'C0013570': 'dsyn',
#  'C0000768': 'cgab',
#  'C1564139': 'aapp',
#  'C0003123': 'gngm',
#  'C0129831': 'gngm',
#  'C0337857': 'humn',
#  'C0002085': 'gngm',
#  'C0870604': 'humn',
#  'C0240182': 'fndg',
#  'C0263534': 'sosy',
#  'C0152096': 'dsyn',
#  'C0007603': 'celc',
#  'C0023779': 'orch',
#  'C1524082': 'topp',
#  'C0683911': 'inpo',
#  'C0018787': 'bpoc',
#  'C0677898': 'neop',
#  'C1527116': 'humn',
#  'C0015264': 'orgf',
#  'C0030450': 'prog',
#  'C1280632': 'bpoc',
#  'C1273869': 'hlca',
#  'C0208355': 'gngm',
#  'C0175996': 'celc',
#  'C0023884': 'bpoc',
#  'C1150095': 'moft',
#  'C0679646': 'popg',
#  'C0079633': 'aapp',
#  'C1171892': 'aapp',
#  'C1177422': 'aapp',
#  'C0018270': 'orgf',
#  'C0302600': 'ortf',
#  'C0030946': 'aapp',
#  'C0449619': 'aapp',
#  'C0619465': 'aapp',
#  '100616101': 'aapp',
#  '100616102': 'aapp',
#  '100616103': 'aapp',
#  '100775105': 'aapp',
#  '100862683': 'aapp',
#  '100862684': 'aapp',
#  '100862685': 'gngm',
#  'C0040018': 'aapp',
#  'C0033954': 'bacs',
#  'C0005320': 'orch',
#  'C0008399': 'gngm',
#  'C0023521': 'dsyn',
#  'C0027347': 'gngm',
#  'C0079904': 'aapp',
#  'C0752312': 'aapp',
#  'C1367731': 'gngm',
#  'C1365599': 'gngm',
#  'C1451465': 'aapp',
#  'C1451398': 'aapp',
#  'C0024296': 'tisu',
#  'C0524851': 'dsyn',
#  'C0521989': 'sosy',
#  'C0025914': 'mamm',
#  'C1136031': 'genf',
#  'C1510464': 'gngm',
#  'C0036025': 'fngs',
#  'C0032433': 'orch',
#  'C0037871': 'bacs',
#  'C0037874': 'bacs',
#  'C0000618': 'phsu',
#  'C0039902': 'orch',
#  'C0597573': 'phsu',
#  'C0061415': 'aapp',
#  'C0014442': 'aapp',
#  'C0021853': 'bpoc',
#  'C0275521': 'dsyn',
#  'C0647210': 'orch',
#  'C0036945': 'mamm',
#  'C0031164': 'npop',
#  'C0019054': 'celf',
#  'C0030956': 'phsu',
#  'C0007526': 'mamm',
#  'C0999514': 'mamm',
#  'C0027312': 'aapp',
#  'C0003402': 'phsu',
#  'C1556111': 'bpoc',
#  'C0243144': 'phsf',
#  'C0220839': 'aapp',
#  'C0521119': 'celc',
#  'C0599732': 'comd',
#  'C0003596': 'gngm',
#  'C0871261': 'orga',
#  'C1330957': 'celf',
#  'C0007124': 'gngm',
#  'C0025920': 'mamm',
#  'C0016693': 'inch',
#  'C0007682': 'dsyn',
#  'C0070002': 'orch',
#  'C0135190': 'orch',
#  'C0007587': 'celf',
#  'C0600437': 'phsu',
#  'C0037533': 'orch',
#  'C0162493': 'genf',
#  'C1159816': 'celf',
#  'C0027746': 'comd',
#  'C0039259': 'bpoc',
#  'C0053932': 'bacs',
#  'C0243043': 'aapp',
#  'C0243308': 'aapp',
#  'C0085078': 'dsyn',
#  'C0057192': 'gngm',
#  'C0238286': 'dsyn',
#  'C0005495': 'npop',
#  'C0010620': 'phsu',
#  'C0037303': 'bpoc',
#  'C0015914': 'orgf',
#  'C0755562': 'orch',
#  'C0169101': 'aapp',
#  'C1326638': 'ortf',
#  'C0026649': 'orgf',
#  'C0005075': 'gngm',
#  'C0006899': 'gngm',
#  'C0081029': 'gngm',
#  'C1333539': 'gngm',
#  'C1332253': 'gngm',
#  'C0013935': 'emst',
#  'C0035298': 'bpoc',
#  'C0027908': 'bacs',
#  'C0154828': 'patf',
#  'C0016904': 'phsu',
#  'C0017890': 'aapp',
#  'C0039350': 'gngm',
#  'C0085845': 'aapp',
#  'C0271055': 'dsyn',
#  'C0043457': 'fish',
#  'C0055359': 'gngm',
#  'C0035309': 'dsyn',
#  'C0042164': 'dsyn',
#  'C0015392': 'bpoc',
#  'C0042338': 'virs',
#  'C0006962': 'gngm',
#  'C1155266': 'patf',
#  'C0001992': 'gngm',
#  'C0033684': 'aapp',
#  'C0034700': 'mamm',
#  'C0025519': 'orgf',
#  'C0035322': 'bpoc',
#  'C0242643': 'aapp',
#  'C0039005': 'mamm',
#  'C0376622': 'gngm',
#  'C0375243': 'gngm',
#  'C0042523': 'orch',
#  'C0598829': 'cell',
#  'C0026336': 'resd',
#  'C0242383': 'dsyn',
#  'C0724693': 'orch',
#  'C0200189': 'diap',
#  'C0032042': 'topp',
#  'C0595862': 'patf',
#  'C0595921': 'dsyn',
#  'C0017601': 'dsyn',
#  'C0543467': 'topp',
#  'C0161398': 'inpo',
#  'C0014597': 'cell',
#  'C1278886': 'bpoc',
#  'C0015283': 'celf',
#  'C0085243': 'mamm',
#  'C0069580': 'gngm',
#  'C1366586': 'gngm',
#  'C1182610': 'cell',
#  'C0005575': 'orch',
#  'C0033640': 'aapp',
#  'C0164786': 'aapp',
#  'C0164207': 'aapp',
#  'C0085140': 'bpoc',
#  'C0700329': 'fndg',
#  'C0004153': 'gngm',
#  'C0022203': 'npop',
#  'C0253005': 'gngm',
#  'C0026473': 'cell',
#  'C0599755': 'humn',
#  'C0031676': 'bacs',
#  'C0577631': 'dsyn',
#  'C0003313': 'gngm',
#  'C0004366': 'patf',
#  'C0003320': 'imft',
#  'C0023820': 'bacs',
#  'C0003593': 'gngm',
#  'C0003338': 'bacs',
#  'C0008377': 'bacs',
#  'C0205847': 'humn',
#  'C1441526': 'lbpr',
#  'C0201699': 'lbpr',
#  'C0038792': 'orch',
#  'C0544357': 'phsu',
#  'C0043047': 'inch',
#  'C0870883': 'bacs',
#  'C0042960': 'prog',
#  'C1511790': 'topp',
#  'C0010825': 'virs',
#  'C1155099': 'moft',
#  'C0376387': 'humn',
#  'C0443769': 'chvf',
#  'C0085979': 'mamm',
#  'C0172537': 'aapp',
#  'C0596981': 'cell',
#  'C0035126': 'inpo',
#  'C0232164': 'ortf',
#  'C0000970': 'gngm',
#  'C0085540': 'bact',
#  'C0949707': 'aapp',
#  'C0025979': 'celc',
#  'C1517186': 'celc',
#  'C1180307': 'aapp',
#  'C0920283': 'aapp',
#  'C0164045': 'aapp',
#  'C0334861': 'prog',
#  'C0009368': 'bpoc',
#  'C0669372': 'aapp',
#  'C0664843': 'aapp',
#  'C1519670': 'neop',
#  'C0520484': 'topp',
#  'C1122629': 'orch',
#  'C0598934': 'neop',
#  'C0032821': 'bacs',
#  'C0002062': 'orch',
#  'C0007097': 'gngm',
#  'C0077678': 'aapp',
#  'C1481993': 'virs',
#  'C0003346': 'aapp',
#  'C0007435': 'topp',
#  'C0010614': 'fish',
#  'C0042776': 'virs',
#  'C1136253': 'virs',
#  'C0677040': 'moft',
#  'C0728810': 'aapp',
#  'C0728590': 'aapp',
#  'C0032447': 'orch',
#  'C0020247': 'orch',
#  'C0043076': 'bodm',
#  'C0969677': 'orch',
#  'C0075816': 'phsu',
#  'C0024947': 'bpoc',
#  'C0033147': 'mamm',
#  'C0007009': 'gngm',
#  'C0040642': 'aapp',
#  'C0699791': 'neop',
#  'C0016157': 'phsu',
#  'C0007613': 'celf',
#  'C0010406': 'gngm',
#  'C0007450': 'mamm',
#  'C0021359': 'patf',
#  'C0012984': 'mamm',
#  'C0939793': 'mamm',
#  'C0029045': 'cell',
#  'C0032961': 'orgf',
#  'C0007452': 'mamm',
#  'C0680063': 'humn',
#  'C0009013': 'gngm',
#  'C1334043': 'gngm',
#  'C0230956': 'mamm',
#  'C1335188': 'gngm',
#  'C1335052': 'gngm',
#  'C1355824': 'gngm',
#  'C0025252': 'aapp',
#  'C0037813': 'lbpr',
#  'C1167622': 'moft',
#  'C0029418': 'cell',
#  'C0180153': 'medd',
#  'C0007586': 'celf',
#  'C0235169': 'sosy',
#  'C0007765': 'bpoc',
#  'C0184906': 'topp',
#  'C0043775': 'orch',
#  'C0288263': 'aapp',
#  'C0006732': 'aapp',
#  'C0006685': 'aapp',
#  'C1395184': 'patf',
#  'C0011646': 'tisu',
#  'C0150866': 'diap',
#  'C1540912': 'neop',
#  'C0024301': 'neop',
#  'C0013216': 'topp',
#  'C0040808': 'topp',
#  'C0032136': 'bacs',
#  'C0025516': 'orgf',
#  'C0033809': 'bact',
#  'C0029224': 'orch',
#  'C0441665': 'npop',
#  'C0054498': 'gngm',
#  'C0014834': 'bact',
#  'C0599770': 'gngm',
#  'C0004589': 'gngm',
#  'C0042765': 'biof',
#  'C0817320': 'bpoc',
#  'C0001166': 'npop',
#  'C1328436': 'lbpr',
#  'C0023401': 'aapp',
#  'C0002521': 'aapp',
#  'C0034703': 'mamm',
#  'C0028778': 'patf',
#  'C1519106': 'emod',
#  'C0525033': 'bact',
#  'C0010125': 'gngm',
#  'C0812385': 'gngm',
#  'C0812613': 'gngm',
#  'C0034790': 'gngm',
#  'C0036962': 'aapp',
#  'C0214570': 'gngm',
#  'C0214894': 'gngm',
#  'C0021758': 'aapp',
#  'C0029433': 'ortf',
#  'C0021289': 'humn',
#  'C0131450': 'gngm',
#  'C0029431': 'cell',
#  'C0333957': 'patf',
#  'C1154313': 'gngm',
#  'C0002895': 'dsyn',
#  'C0014792': 'cell',
#  'C0018801': 'dsyn',
#  'C0038435': 'fndg',
#  'C0021641': 'aapp',
#  'C0004936': 'mobd',
#  'C0029343': 'virs',
#  'C0935640': 'virs',
#  'C1522485': 'irda',
#  'C0040674': 'topp',
#  'C0003242': 'aapp',
#  'C0064755': 'aapp',
#  'C0012923': 'virs',
#  'C1579410': 'phsu',
#  'C0206580': 'virs',
#  'C0441633': 'diap',
#  'C0030498': 'euka',
#  'C0008415': 'aapp',
#  'C0029235': 'orgm',
#  'C0529330': 'aapp',
#  'C0000185': 'gngm',
#  'C0027950': 'cell',
#  'C0040395': 'diap',
#  'C0598958': 'celf',
#  'C0600388': 'aapp',
#  'C0035565': 'aapp',
#  'C0995501': 'bact',
#  'C0679670': 'popg',
#  'C0678601': 'npop',
#  'C0019944': 'mamm',
#  'C0658195': 'gngm',
#  'C0046079': 'orch',
#  'C0007974': 'phsu',
#  'C0032089': 'aapp',
#  'C0034493': 'mamm',
#  'C0301872': 'orgf',
#  'C0085104': 'medd',
#  'C0236075': 'sosy',
#  'C0005802': 'orch',
#  'C0178784': 'bpoc',
#  'C0033362': 'bacs',
#  'C0029408': 'dsyn',
#  'C0021107': 'topp',
#  'C0029468': 'topp',
#  'C0010957': 'inpo',
#  'C0013470': 'orgf',
#  'C1154417': 'celf',
#  'C0391690': 'aapp',
#  'C0041236': 'aapp',
#  'C0001792': 'humn',
#  'C0338656': 'mobd',
#  'C0596020': 'fndg',
#  'C0678603': 'npop',
#  'C0175723': 'medd',
#  'C0042210': 'aapp',
#  'C0475463': 'aapp',
#  'C0020964': 'ortf',
#  'C0180392': 'medd',
#  'C0282641': 'gngm',
#  'C0079460': 'aapp',
#  'C0071437': 'orch',
#  'C0073918': 'aapp',
#  'C0206194': 'humn',
#  'C1279051': 'bpoc',
#  'C0334044': 'patf',
#  'C0152027': 'dsyn',
#  'C0423572': 'sosy',
#  'C0002028': 'euka',
#  'C1550678': 'inch',
#  'C0600688': 'inpo',
#  'C0184661': 'topp',
#  'C0004927': 'bhvr',
#  'C0231170': 'fndg',
#  'C0145947': 'aapp',
#  'C0239946': 'dsyn',
#  'C0016767': 'food',
#  'C0014653': 'orgf',
#  'C0028908': 'orch',
#  'C0206135': 'inch',
#  'C0599918': 'inpo',
#  'C0028128': 'phsu',
#  'C0022023': 'elii',
#  'C0006212': 'inch',
#  'C0020282': 'hops',
#  'C0013502': 'dsyn',
#  'C0431648': 'cgab',
#  'C0598067': 'ortf',
#  'C1519726': 'moft',
#  'C0021665': 'aapp',
#  'C0450442': 'chvf',
#  'C0086982': 'moft',
#  'C0971859': 'ortf',
#  'C0007090': 'hops',
#  'C0007137': 'neop',
#  'C0003162': 'aapp',
#  'C0001430': 'neop',
#  'C0024109': 'bpoc',
#  'C0023610': 'horm',
#  'C0022796': 'aapp',
#  'C1417166': 'gngm',
#  'C0001545': 'gngm',
#  'C0919425': 'gngm',
#  'C0911543': 'gngm',
#  'C1148673': 'genf',
#  'C0035696': 'bacs',
#  'C0439861': 'sbst',
#  'C1451357': 'aapp',
#  'C1459564': 'aapp',
#  'C0001275': 'orch',
#  'C0003075': 'elii',
#  'C0442540': 'npop',
#  'C0060600': 'hops',
#  'C0608091': 'horm',
#  'C0076733': 'inch',
#  'C0599786': 'hops',
#  'C0350056': 'bodm',
#  'C0031117': 'dsyn',
#  'C0442874': 'dsyn',
#  'C0458247': 'fndg',
#  'C0027836': 'cell',
#  'C0278220': 'ortf',
#  'C0036341': 'mobd',
#  'C0037083': 'celf',
#  'C0598501': 'celf',
#  'C0061928': 'aapp',
#  'C1281026': 'bpoc',
#  'C0107103': 'aapp',
#  'C0000761': 'gngm',
#  'C0022471': 'orch',
#  'C0085301': 'gngm',
#  'C0082353': 'gngm',
#  'C0596588': 'aapp',
#  'C0592353': 'aapp',
#  'C1414908': 'gngm',
#  'C1412554': 'gngm',
#  'C0027765': 'dsyn',
#  'C0678903': 'celf',
#  'C0040822': 'sosy',
#  'C0002554': 'gngm',
#  'C0596611': 'genf',
#  'C0270736': 'dsyn',
#  'C0007457': 'humn',
#  'C0015859': 'mamm',
#  'C0227650': 'cell',
#  'C0268731': 'dsyn',
#  'C1260875': 'orgf',
#  'C0001041': 'gngm',
#  'C0026845': 'tisu',
#  'C0376702': 'cell',
#  'C0001044': 'aapp',
#  'C0040669': 'mbrt',
#  'C0031849': 'orch',
#  'C0025086': 'diap',
#  'C0162772': 'bacs',
#  'C0030193': 'sosy',
#  'C0012683': 'topp',
#  'C0007286': 'dsyn',
#  'C0311392': 'fndg',
#  'C0751922': 'dsyn',
#  'C0144576': 'orch',
#  'C0020429': 'sosy',
#  'C0011164': 'patf',
#  'C0004461': 'celc',
#  'C0501385': 'bpoc',
#  'C1157338': 'moft',
#  'C0858318': 'dsyn',
#  'C0762819': 'aapp',
#  'C0678544': 'npop',
#  'C0011573': 'mobd',
#  'C0167206': 'aapp',
#  'C0164071': 'aapp',
#  'C0682708': 'tisu',
#  'C0058990': 'aapp',
#  'C0030943': 'aapp',
#  'C0487637': 'gngm',
#  'C0007786': 'dsyn',
#  'C0521449': 'blor',
#  'C0020960': 'aapp',
#  'C0021792': 'cell',
#  'C0575090': 'sosy',
#  'C0015535': 'humn',
#  'C1335770': 'gngm',
#  'C0206745': 'mamm',
#  'C0162512': 'bpoc',
#  'C0007370': 'mobd',
#  'C0162788': 'mbrt',
#  'C0042839': 'orch',
#  'C0015674': 'dsyn',
#  'C0020255': 'dsyn',
#  'C0022116': 'patf',
#  'C0149784': 'phsf',
#  'C0746574': 'phsu',
#  'C1136249': 'dsyn',
#  'C0282109': 'aapp',
#  'C0013139': 'euka',
#  'C0011529': 'nnon',
#  'C0026584': 'euka',
#  'C0302583': 'phsu',
#  'C0041912': 'dsyn',
#  'C0264221': 'inpo',
#  'C0028429': 'bpoc',
#  'C1260880': 'sosy',
#  'C0214439': 'antb',
#  'C0733758': 'aapp',
#  'C0736046': 'aapp',
#  'C0013798': 'diap',
#  'C0002186': 'gngm',
#  'C0677666': 'phsu',
#  'C0007103': 'gngm',
#  'C0074926': 'aapp',
#  'C0032150': 'euka',
#  'C0002345': 'genf',
#  'C0024660': 'mamm',
#  'C0385463': 'aapp',
#  'C0383953': 'aapp',
#  'C0017375': 'gngm',
#  'C0016898': 'aapp',
#  'C0006104': 'bpoc',
#  'C0871125': 'phsf',
#  'C1337069': 'inpo',
#  'C0009630': 'bacs',
#  'C0021756': 'aapp',
#  'C1159339': 'celf',
#  'C0288011': 'aapp',
#  'C1155046': 'celf',
#  'C0001492': 'aapp',
#  'C0544650': 'ortf',
#  'C0002395': 'dsyn',
#  'C0017837': 'gngm',
#  'C0133482': 'aapp',
#  'C0373156': 'aapp',
#  'C0243192': 'phsu',
#  'C1158770': 'genf',
#  'C0020281': 'phsu',
#  'C0003197': 'gngm',
#  'C0003198': 'gngm',
#  'C0003200': 'aapp',
#  'C0003201': 'gngm',
#  'C0003202': 'aapp',
#  'C0003203': 'gngm',
#  'C0003204': 'phsu',
#  'C0003205': 'phsu',
#  'C0003206': 'gngm',
#  'C0003207': 'gngm',
#  'C0003209': 'phsu',
#  'C1419746': 'gngm',
#  'C1419252': 'gngm',
#  'C0031715': 'moft',
#  'C0085828': 'aapp',
#  'C0082354': 'aapp',
#  'C0083725': 'aapp',
#  'C0083726': 'aapp',
#  'C0083727': 'aapp',
#  'C0040648': 'aapp',
#  'C0041904': 'moft',
#  'C0007620': 'celf',
#  'C0017360': 'gngm',
#  '100616496': 'gngm',
#  'C0035668': 'nnon',
#  'C0314732': 'orgm',
#  'C100616496': 'gngm',
#  'C0035366': 'virs',
#  'C0017281': 'gngm',
#  'C0031212': 'mobd',
#  'C0027882': 'cell',
#  'C0047845': 'orch',
#  'C1253955': 'bsoj',
#  'C0038818': 'phsu',
#  'C0857127': 'topp',
#  'C0020971': 'topp',
#  'C0000973': 'aapp',
#  '102723407': 'aapp',
#  'C1332104': 'gngm',
#  'C1310513': 'gngm',
#  'C0010513': 'aapp',
#  'C0206358': 'gngm',
#  'C0012186': 'orch',
#  'C0001128': 'gngm',
#  'C0042930': 'bpoc',
#  'C0015350': 'tisu',
#  'C1521828': 'qnco',
#  'C0018483': 'bact',
#  'C0052796': 'orch',
#  'C0340044': 'dsyn',
#  'C0001617': 'horm',
#  'C0243065': 'patf',
#  'C0426706': 'fndg',
#  'C0476273': 'sosy',
#  'C0646681': 'orch',
#  'C0037494': 'inch',
#  'C0023870': 'elii',
#  'C0014175': 'dsyn',
#  'C0870221': 'humn',
#  'C0026848': 'dsyn',
#  'C0521450': 'blor',
#  'C0450138': 'bpoc',
#  'C0015278': 'aapp',
#  'C0337580': 'humn',
#  'C0270960': 'dsyn',
#  'C0037047': 'famg',
#  'C1336014': 'bacs',
#  'C1160638': 'biof',
#  'C0017004': 'medd',
#  'C0038220': 'dsyn',
#  'C0012472': 'horm',
#  'C0085387': 'phsu',
#  'C0002716': 'bacs',
#  'C0486805': 'bdsu',
#  'C0004774': 'gngm',
#  'C0004781': 'gngm',
#  'C0004782': 'gngm',
#  'C0004784': 'gngm',
#  'C0114799': 'gngm',
#  'C0023621': 'orgt',
#  'C1269578': 'bpoc',
#  'C0013384': 'dsyn',
#  'C0023570': 'bacs',
#  'C1154437': 'moft',
#  'C0030567': 'dsyn',
#  'C1136180': 'orgf',
#  'C0057738': 'aapp',
#  'C0034170': 'bacs',
#  'C0029282': 'aapp',
#  'C0019587': 'aapp',
#  'C0052331': 'gngm',
#  'C0007590': 'celf',
#  'C0542479': 'npop',
#  'C0001109': 'gngm',
#  'C0034320': 'inch',
#  'C1157206': 'moft',
#  'C0065042': 'bacs',
#  'C0032520': 'mbrt',
#  'C1157011': 'moft',
#  'C1156971': 'moft',
#  'C0004728': 'mamm',
#  'C0374291': 'gngm',
#  'C1370600': 'gngm',
#  'C1443775': 'phsu',
#  'C0596290': 'celf',
#  'C0242982': 'gngm',
#  'C0241956': 'gngm',
#  'C0387583': 'gngm',
#  'C0018282': 'bacs',
#  'C1257954': 'orch',
#  'C0334227': 'cell',
#  'C0021557': 'gngm',
#  'C0596902': 'aapp',
#  'C0031621': 'bacs',
#  'C0021547': 'orch',
#  'C0016163': 'fish',
#  'C0013839': 'diap',
#  'C1552132': 'bpoc',
#  'C0008972': 'resa',
#  'C1265658': 'inpo',
#  'C1293903': 'diap',
#  'C0206131': 'cell',
#  'C0034715': 'mamm',
#  'C0596843': 'moft',
#  'C0166417': 'gngm',
#  'C0041004': 'bacs',
#  'C1260899': 'dsyn',
#  'C0073320': 'aapp',
#  'C0398550': 'dsyn',
#  'C0086282': 'humn',
#  'C0525038': 'genf',
#  'C1171362': 'genf',
#  'C0076934': 'aapp',
#  'C0446085': 'fngs',
#  'C1335623': 'gngm',
#  'C1338737': 'gngm',
#  'C0004038': 'gngm',
#  'C0949771': 'aapp',
#  'C0230770': 'celc',
#  'C1159342': 'celf',
#  'C0016832': 'fngs',
#  'C0033382': 'aapp',
#  'C0017345': 'gngm',
#  'C1334046': 'gngm',
#  'C0283827': 'aapp',
#  'C0004810': 'gngm',
#  'C0319683': 'fngs',
#  'C1269100': 'aapp',
#  'C1264155': 'aapp',
#  'C0004037': 'fngs',
#  'C0017696': 'orch',
#  'C0521049': 'fngs',
#  'C0007623': 'celc',
#  'C0001962': 'orch',
#  'C0014544': 'dsyn',
#  'C0038317': 'phsu',
#  'C0328038': 'fish',
#  'C0018120': 'bpoc',
#  'C0304866': 'gngm',
#  'C0205065': 'bpoc',
#  'C0220821': 'orch',
#  'C1141639': 'aapp',
#  'C1141081': 'aapp',
#  'C1143342': 'aapp',
#  'C1193659': 'aapp',
#  'C1325702': 'celc',
#  'C0010934': 'gngm',
#  'C1160520': 'celf',
#  'C1366555': 'gngm',
#  'C1361806': 'gngm',
#  'C0020855': 'gngm',
#  'C0181835': 'medd',
#  'C0017110': 'chvs',
#  'C0020564': 'patf',
#  'C0018284': 'aapp',
#  'C0022984': 'bacs',
#  'C0206535': 'mamm',
#  'C0040690': 'aapp',
#  'C0015075': 'orch',
#  'C0920552': 'orgf',
#  'C0597252': 'orgf',
#  'C0678632': 'lbpr',
#  'C0068003': 'orch',
#  'C0001975': 'orch',
#  'C0014898': 'orch',
#  'C0015083': 'hops',
#  'C0077096': 'hops',
#  'C0982392': 'inch',
#  'C0035525': 'phsu',
#  'C0002594': 'aapp',
#  'C0015695': 'dsyn',
#  'C0010674': 'dsyn',
#  'C0004611': 'bact',
#  'C0175925': 'mamm',
#  'C0035204': 'dsyn',
#  'C1136170': 'bacs',
#  'C0220905': 'rnlw',
#  'C0029921': 'humn',
#  'C0020034': 'npop',
#  'C0936012': 'resa',
#  'C0019169': 'virs',
#  'C0005955': 'cell',
#  'C0025936': 'mamm',
#  'C0301521': 'aapp',
#  'C0005790': 'lbpr',
#  'C0684072': 'mamm',
#  'C0043342': 'amph',
#  'C1267211': 'bpoc',
#  'C0006574': 'gngm',
#  'C0231048': 'emst',
#  'C0042449': 'bpoc',
#  'C0043240': 'orgf',
#  'C1415406': 'gngm',
#  'C1413014': 'gngm',
#  'C0243114': 'lbpr',
#  'C0008550': 'lbpr',
#  'C0023630': 'aapp',
#  'C0002245': 'gngm',
#  'C0317603': 'bact',
#  'C0002712': 'aapp',
#  'C0002732': 'orch',
#  'C0024658': 'phsu',
#  'C0065603': 'orch',
#  'C0021186': 'orch',
#  'C0185115': 'topp',
#  'C0059747': 'orch',
#  'C0238806': 'dsyn',
#  'C0085268': 'ortf',
#  'C0033497': 'orch',
#  'C0029419': 'aapp',
#  'C0000054': 'aapp',
#  'C0029458': 'dsyn',
#  'C0012544': 'phsu',
#  'C0379199': 'phsu',
#  'C0039401': 'edac',
#  'C0021900': 'medd',
#  'C0289121': 'aapp',
#  'C0243044': 'aapp',
#  'C0243320': 'gngm',
#  'C1335884': 'aapp',
#  'C0026764': 'neop',
#  'C1176309': 'orch',
#  'C1443643': 'aapp',
#  'C0178522': 'inch',
#  'C0001271': 'aapp',
#  'C0598148': 'aapp',
#  'C0597428': 'lbpr',
#  'C1519619': 'genf',
#  'C0270814': 'dsyn',
#  'C0242849': 'lbpr',
#  'C0597545': 'ortf',
#  'C1519751': 'moft',
#  'C0302614': 'medd',
#  ...}

# %%
read_json(join('all_triples', 'all_entity_names.json'))
# Out:
# {'C0999630': 'Lepus capensis (organism)',
#  'C0446169': 'California Group Viruses',
#  'C0206590': 'Coltivirus',
#  'C0003725': 'JUN',
#  'C0020114': 'Human',
#  'C0012634': 'Disease',
#  'C0003241': 'Antibodies',
#  'C0002273': 'FHL1',
#  'C0006034': 'Borrelia burgdorferi',
#  'C0019878': 'homocysteine',
#  'C0025646': 'methionine',
#  'C0017262': 'Gene Expression',
#  'C0001675': 'Adult',
#  'C0042567': 'Vertebrates',
#  'C1167395': 'Host (organism)',
#  'C0003062': 'Animals',
#  'C0162318': 'Farm Animals',
#  'C1136254': 'Microbicides',
#  'C0949665': 'Fluoroquinolones',
#  'C0013227': 'Pharmaceutical Preparations',
#  'C0014061': 'Tick-Borne Encephalitis',
#  'C0030705': 'Patients',
#  'C0086287': 'Females',
#  'C0086582': 'Males',
#  'C1552130': '16s',
#  'C0237401': 'Individual',
#  'C1457887': 'Symptoms',
#  'C0021311': 'Infection',
#  'C0089701': '1-oleoyl-2-stearoylphosphatidylcholine',
#  'C0012854': 'DNA',
#  'C0456981': 'Specific antigen',
#  'C0021368': 'Inflammation',
#  'C0004368': 'Autoimmunity',
#  'C0039194': 'T-Lymphocyte',
#  'C0003315': 'HSPB1',
#  'C0670896': 'Toll-like receptors',
#  'C1185625': 'Compartments',
#  'C0597357': 'receptor',
#  'C0035549': 'ribose',
#  'C0162638': 'Apoptosis',
#  'C0998896': 'Scorpaenidae',
#  'C0332124': 'No past history',
#  'C0015780': 'Female',
#  'C0998689': 'Hemicentrotus pulcherrimus',
#  'C0017199': 'Gastrula',
#  'C0162415': 'Mesenchyma',
#  'C0181909': 'Mounts',
#  'C0005539': 'PPY',
#  'C0026591': 'Mother (person)',
#  'C0028661': 'Nurses',
#  'C0037863': 'Spermatocytes',
#  'C0007634': 'Cells',
#  'C0036679': 'Diastasis',
#  'C0034693': 'Rattus norvegicus',
#  'C0032594': 'Polysaccharides',
#  'C0033692': 'Proteoglycan',
#  'C0017973': 'Glycosaminoglycans',
#  'C0028959': 'Oligosaccharides',
#  'C0204514': 'Structural analysis',
#  'C0012611': 'Disaccharides',
#  'C1533168': 'sorbate',
#  'C0039231': 'Tachycardia',
#  'C0029463': 'Osteosarcoma',
#  'C0006826': 'Malignant Neoplasms',
#  'C0683971': 'General Population',
#  'C0087111': 'Therapeutic procedure',
#  'C0020063': 'PTH protein, human',
#  'C0025741': 'PTH',
#  'C0027651': 'Neoplasms',
#  'C0017337': 'Genes',
#  'C1414461': 'ESR1 gene',
#  'C1412099': 'ABO gene',
#  'C1414462': 'ESR2 gene',
#  'C1412100': 'ESR2',
#  'C0014939': 'estrogens',
#  'C0043210': 'Woman',
#  'C0029456': 'Osteoporosis',
#  'C0028754': 'Obesity',
#  'C0227525': 'Hepatocyte',
#  'C0021390': 'Inflammatory Bowel Diseases',
#  'C0020541': 'Portal Hypertension',
#  'C0001645': 'AKR1C1',
#  'C0016059': 'Fibrosis',
#  'C1511606': 'Cystic lesions',
#  'C0235974': 'Pancreatic carcinoma',
#  'C0027051': 'Myocardial Infarction',
#  'C0240816': 'Sex Workers',
#  'C0342257': 'Complications of Diabetes Mellitus',
#  'C1275743': 'Co-morbid conditions',
#  'C0011854': 'Diabetes Mellitus, Insulin-Dependent',
#  'C0008946': 'Climate',
#  'C0016627': 'Influenza in Birds',
#  'C0027361': 'Persons',
#  'C0012746': 'Dissociative disorder',
#  'C1261469': 'End stage renal failure',
#  'C1565489': 'Renal Insufficiency',
#  'C0699748': 'Pathogenesis',
#  'C0010852': 'Cytoskeletal Proteins',
#  'C0024141': 'Lupus Erythematosus, Systemic',
#  'C0879626': 'Adverse effects',
#  'C0011065': 'Cessation of life',
#  'C0160420': 'Injury of kidney',
#  'C0277785': 'Functional disorder',
#  'C0079189': 'cytokine',
#  'C0175677': 'Injury',
#  'C0008059': 'Child',
#  'C0015879': 'Ferritin',
#  'C0022658': 'Kidney Diseases',
#  'C1257890': 'Population Group',
#  'C0022661': 'Kidney Failure, Chronic',
#  'C0035078': 'Kidney Failure',
#  'C0011947': 'Dialysis Solutions',
#  'C0021760': 'interleukin-6',
#  'C1159690': 'sodium ion transport',
#  'C0019868': 'Homeostasis',
#  'C0552639': 'tubular cells',
#  'C0031727': 'Phosphotransferases',
#  'C0002006': 'ELN',
#  'C0040649': 'Transcription, Genetic',
#  'C0005826': 'Abnormal blood pressure',
#  'C0022646': 'Kidney',
#  'C0019247': 'Hereditary Diseases',
#  'C1272641': 'Systemic arterial pressure',
#  'C0596070': 'Americas Ethnicity',
#  'C0574785': 'Lower Urinary Tract Symptoms',
#  'C0025266': 'Male population group',
#  'C0003385': 'Muscarinic Antagonists',
#  'C0680022': 'member',
#  'C0026447': 'Monkeys',
#  'C0034927': 'Patient referral',
#  'C1261322': 'Evaluation procedure',
#  'C0162326': 'DNA Sequence',
#  'C0201683': 'Chemical method',
#  'C0021102': 'Implants',
#  'C0221192': 'Author',
#  'C0022122': 'Bone structure of ischium',
#  'C0206365': 'Structure of collateral ligament',
#  'C0037004': 'Shoulder',
#  'C0243032': 'Magnetic Resonance Angiography',
#  'C0947637': 'Stenosis, unspecified',
#  'C0007282': 'Carotid Stenosis',
#  'C0333463': 'Senile Plaques',
#  'C0260280': 'Technologist',
#  'C0871685': 'Clinician',
#  'C0037313': 'Sleep',
#  'C0037317': 'Sleep disturbances',
#  'C0442696': 'Waking',
#  'C0920580': 'medical specialist',
#  'C0039593': 'Testing',
#  'C0003364': 'Antihypertensive Agents',
#  'C1420485': 'STN gene',
#  'C1421917': 'EEF1A2',
#  'C0948089': 'Acute Coronary Syndrome',
#  'C0162589': 'Implantable defibrillator',
#  'C0017638': 'Glioma',
#  'C0007595': 'Cell Growth',
#  'C0178874': 'Tumor Progression',
#  'C0074992': 'sphingosine 1-phosphate',
#  'C0599779': 'Animal Model',
#  'C0431085': 'Tumor cells, uncertain whether benign or malignant',
#  'C1307407': 'FRAP1 protein, human',
#  'C1302475': 'MTOR',
#  'C0280100': 'Solid Neoplasm',
#  'C0678613': 'feedback inhibition',
#  'C0013081': 'Down-Regulation',
#  'C0023467': 'Leukemia, Myelocytic, Acute',
#  'C0026809': 'Mus',
#  'C0596263': 'Carcinogenesis',
#  'C0242379': 'Malignant neoplasm of lung',
#  'C0001418': 'Adenocarcinoma',
#  'C0599161': 'Reverse Transcriptase Polymerase Chain Reaction',
#  'C0685938': 'Malignant neoplasm of gastrointestinal tract',
#  'C0237753': 'Numbers',
#  'C0027627': 'Neoplasm Metastasis',
#  'C1326912': 'Tumorigenesis',
#  'C0003250': 'Monoclonal Antibodies',
#  'C0005847': 'Blood Vessel',
#  'C0450238': 'Whole chromosome',
#  'C0028303': 'Nondisjunction, Genetic',
#  'C0796346': 'Polymorphic Microsatellite Marker',
#  'C0015576': 'Family',
#  'C0009917': 'Contracture',
#  'C0205851': 'Germ cell tumor',
#  'C0175895': 'calcification',
#  'C0039082': 'Syndrome',
#  'C0221198': 'Lesion',
#  'C0687140': 'Hemangioma of skin',
#  'C0027960': 'Nevus',
#  'C0023516': 'Leukocytes',
#  'C1427070': 'TWIST2 gene',
#  'C1117581': 'TWIST2',
#  'C0021270': 'Infant',
#  'C0030208': 'Paintings',
#  'C0162789': 'Fluorescent in Situ Hybridization',
#  'C0182400': 'Probes',
#  'C0004509': 'Azoospermia',
#  'C1420418': 'SRY gene',
#  'C1426736': 'SRY',
#  'C0026882': 'Mutation',
#  'C0006926': 'TBX3',
#  'C0243069': 'Hypoplasia',
#  'C0013570': 'Ecthyma, Contagious',
#  'C0000768': 'Congenital Abnormality',
#  'C1564139': 'Mutant Proteins',
#  'C0003123': 'HLA-DRB1',
#  'C0129831': 'RBM45',
#  'C0337857': 'Athabascans',
#  'C0002085': 'Alleles',
#  'C0870604': 'Female child',
#  'C0240182': 'Leukonychia',
#  'C0263534': "Beau's lines",
#  'C0152096': 'Complete trisomy 18 syndrome',
#  'C0007603': 'Plasma membrane',
#  'C0023779': 'Lipids',
#  'C1524082': 'Derivation procedure',
#  'C0683911': 'Vehicle accident NOS',
#  'C0018787': 'Heart',
#  'C0677898': 'Invasive Malignant Neoplasm',
#  'C1527116': 'Workers',
#  'C0015264': 'Exertion',
#  'C0030450': 'Paramedical Personnel',
#  'C1280632': 'Entire trunk',
#  'C1273869': 'Intervention regimes',
#  'C0208355': 'multicatalytic endopeptidase complex',
#  'C0175996': 'Protoplasm',
#  'C0023884': 'Liver',
#  'C1150095': 'peptidase activity',
#  'C0679646': 'Participant',
#  'C0079633': 'interleukin-8',
#  'C1171892': 'VEGF protein, human',
#  'C1177422': 'VEGFA',
#  'C0018270': 'Growth',
#  'C0302600': 'Angiogenic Process',
#  'C0030946': 'Endopeptidases',
#  'C0449619': 'ERVK-7',
#  'C0619465': 'ERVK-8',
#  '100616101': 'ERVK-10',
#  '100616102': 'ERVK-9',
#  '100616103': 'ERVK-21',
#  '100775105': 'ERVK-18',
#  '100862683': 'ERVK-25',
#  '100862684': 'ERVK-24',
#  '100862685': 'ERVK-19',
#  'C0040018': 'thrombin',
#  'C0033954': 'Psychosine',
#  'C0005320': 'betaxolol',
#  'C0008399': 'PLA2G10',
#  'C0023521': 'Globoid cell leukodystrophy',
#  'C0027347': 'STK39',
#  'C0079904': 'NF-kappa B',
#  'C0752312': 'Mitogen-Activated Protein Kinases',
#  'C1367731': 'MAPK8 gene',
#  'C1365599': 'MAPK8',
#  'C1451465': 'UBE2J1',
#  'C1451398': 'CRK',
#  'C0024296': 'Lymphoid Tissue',
#  'C0524851': 'Neurodegenerative Disorders',
#  'C0521989': 'Associated symptom',
#  'C0025914': 'House mice',
#  'C1136031': 'RNA Interference',
#  'C1510464': 'Protein Structure',
#  'C0036025': 'Saccharomyces cerevisiae',
#  'C0032433': 'Polyamines',
#  'C0037871': 'spermidine',
#  'C0037874': 'spermine',
#  'C0000618': 'mercaptopurine',
#  'C0039902': 'thioguanine',
#  'C0597573': 'thiopurine',
#  'C0061415': 'Glucose-1-phosphate adenylyltransferase',
#  'C0014442': 'Enzymes',
#  'C0021853': 'Intestines',
#  'C0275521': 'Clinical infection',
#  'C0647210': 'monooxyethylene trimethylolpropane tristearate',
#  'C0036945': 'Sheep',
#  'C0031164': 'Permeability',
#  'C0019054': 'hemolysis',
#  'C0030956': 'Peptides',
#  'C0007526': 'Capuchin Monkey',
#  'C0999514': 'Cebus brunneus',
#  'C0027312': 'NADPH Dehydrogenase',
#  'C0003402': 'Antioxidants',
#  'C1556111': 'Supernumerary mandibular left first primary molar',
#  'C0243144': 'Uptake',
#  'C0220839': 'glutamate',
#  'C0521119': 'Extracellular',
#  'C0599732': 'cell injury',
#  'C0003596': 'IL13',
#  'C0871261': 'Response process',
#  'C1330957': 'Cytokinesis of the fertilized ovum',
#  'C0007124': 'TNF',
#  'C0025920': 'Mice, Inbred C3H',
#  'C0016693': 'Free Radicals',
#  'C0007682': 'CNS disorder',
#  'C0070002': 'panaxydol',
#  'C0135190': 'panaxynol',
#  'C0007587': 'Cell Death',
#  'C0600437': 'Nitric Oxide Donors',
#  'C0037533': 'sodium nitroprusside',
#  'C0162493': 'Transcriptional Activation',
#  'C1159816': 'anti-apoptosis',
#  'C0027746': 'Nerve Degeneration',
#  'C0039259': 'Tail',
#  'C0053932': 'Bone Morphogenetic Proteins',
#  'C0243043': 'Heat-Shock Proteins 70',
#  'C0243308': 'HSPA4',
#  'C0085078': 'Lysosomal Storage Diseases',
#  'C0057192': 'MCOLN1',
#  'C0238286': 'Mucolipidosis Type IV',
#  'C0005495': 'Origin of Life',
#  'C0010620': 'cyproheptadine',
#  'C0037303': 'Bone structure of cranium',
#  'C0015914': 'Fertilization',
#  'C0755562': 'U 0126',
#  'C0169101': 'Mitogen-Activated Protein Kinase Kinases',
#  'C1326638': 'midbrain development',
#  'C0026649': 'Movement',
#  'C0005075': 'PAX1',
#  'C0006899': 'TBX1',
#  'C0081029': 'WNT5B',
#  'C1333539': 'FGF8 gene',
#  'C1332253': 'FGF8',
#  'C0013935': 'Embryo',
#  'C0035298': 'Retina',
#  'C0027908': 'Neurotransmitters',
#  'C0154828': 'Traction detachment of retina',
#  'C0016904': 'gamma-aminobutyric acid',
#  'C0017890': 'glycine',
#  'C0039350': 'taurine',
#  'C0085845': 'Aspartate',
#  'C0271055': 'Rhegmatogenous retinal detachment',
#  'C0043457': 'Zebrafish',
#  'C0055359': 'STYK1',
#  'C0035309': 'Retinal Diseases',
#  'C0042164': 'Uveitis',
#  'C0015392': 'Eye',
#  'C0042338': 'herpesvirus 3, human',
#  'C0006962': 'TRBV20OR9-2',
#  'C1155266': 'Inflammatory Response',
#  'C0001992': 'SERPINB1',
#  'C0033684': 'Proteins',
#  'C0034700': 'Rats, Inbred BN',
#  'C0025519': 'Metabolism',
#  'C0035322': 'Structure of retinal pigment epithelium',
#  'C0242643': 'P-Glycoprotein',
#  'C0039005': 'Family suidae',
#  'C0376622': 'ABCB1 gene',
#  'C0375243': 'ABCB1',
#  'C0042523': 'verapamil',
#  'C0598829': 'Madin Darby Canine Kidney Cells',
#  'C0026336': 'Study models',
#  'C0242383': 'Age related macular degeneration',
#  'C0724693': 'sildenafil citrate',
#  'C0200189': 'Fundus photography',
#  'C0032042': 'Placebos',
#  'C0595862': 'Vasodilation disorder',
#  'C0595921': 'Intraocular pressure disorder',
#  'C0017601': 'Glaucoma',
#  'C0543467': 'Operative Surgical Procedures',
#  'C0161398': 'Optic Nerve Injuries',
#  'C0014597': 'Epithelial Cells',
#  'C1278886': 'Entire lacrimal gland',
#  'C0015283': 'Exocytosis',
#  'C0085243': 'Mice, Inbred NOD',
#  'C0069580': 'Rod Opsins',
#  'C1366586': 'SNW1 Gene',
#  'C1182610': 'Corneal epithelial cell',
#  'C0005575': 'biotin',
#  'C0033640': 'Protein Kinases',
#  'C0164786': 'Proto-Oncogene Proteins c-akt',
#  'C0164207': 'AKT1',
#  'C0085140': 'Prosencephalon',
#  'C0700329': 'Physical shape',
#  'C0004153': 'MBL2',
#  'C0022203': 'Isomerism (chemical phenomenon)',
#  'C0253005': 'chitotriosidase',
#  'C0026473': 'Monocytes',
#  'C0599755': 'Cohort',
#  'C0031676': 'phospholipids',
#  'C0577631': 'Carotid Atherosclerosis',
#  'C0003313': 'HSPA9',
#  'C0004366': 'Autoimmune Response',
#  'C0003320': 'Antigens',
#  'C0023820': 'Lipoproteins',
#  'C0003593': 'IL12B',
#  'C0003338': 'APOB',
#  'C0008377': 'cholesterol',
#  'C0205847': 'Middle Aged',
#  'C1441526': 'COMPUTED',
#  'C0201699': 'Electrophoresis, Capillary',
#  'C0038792': 'Sulindac',
#  'C0544357': 'human plasma',
#  'C0043047': 'water',
#  'C0870883': 'Metabolite',
#  'C0042960': 'Voluntary Workers',
#  'C1511790': 'Detection',
#  'C0010825': 'Cytomegalovirus',
#  'C1155099': 'cytokine biosynthesis',
#  'C0376387': 'Transplant Recipients',
#  'C0443769': 'volatile substances',
#  'C0085979': 'Cavia',
#  'C0172537': 'Matrix Metalloproteinase 2',
#  'C0596981': 'Muscle Cells',
#  'C0035126': 'Reperfusion Injury',
#  'C0232164': 'Cardiac function',
#  'C0000970': 'CD70',
#  'C0085540': 'Anabaena',
#  'C0949707': 'Sensory Rhodopsins',
#  'C0025979': 'Microfilaments',
#  'C1517186': 'Filament',
#  'C1180307': 'F-Actin',
#  'C0920283': 'DNA Helicases',
#  'C0164045': 'HFM1',
#  'C0334861': 'Biologist (general)',
#  'C0009368': 'Colon structure (body structure)',
#  'C0669372': 'NOS2A protein, human',
#  'C0664843': 'NOS2',
#  'C1519670': 'Tumor Angiogenesis',
#  'C0520484': 'Xenograft procedure',
#  'C1122629': 'ZD 6126',
#  'C0598934': 'tumor growth',
#  'C0032821': 'potassium',
#  'C0002062': 'Alkaloids',
#  'C0007097': 'TLR2',
#  'C0077678': 'ubiquitin-protein ligase',
#  'C1481993': 'Haloviruses',
#  'C0003346': 'HTN1',
#  'C0007435': 'Catheterization, Central Venous',
#  'C0010614': 'Cypriniformes',
#  'C0042776': 'Virus',
#  'C1136253': 'Prophages',
#  'C0677040': 'Stereochemistry',
#  'C0728810': 'Butyrylcholinesterase',
#  'C0728590': 'BCHE',
#  'C0032447': 'Polychlorinated Biphenyls',
#  'C0020247': 'Hydrocarbons, Chlorinated',
#  'C0043076': 'Waxes',
#  'C0969677': 'alpha tocopherol',
#  'C0075816': 'taraxerol',
#  'C0024947': 'Maxilla',
#  'C0033147': 'Primates',
#  'C0007009': 'TMBIM6',
#  'C0040642': 'Transcobalamin',
#  'C0699791': 'Stomach Carcinoma',
#  'C0016157': 'fish oils',
#  'C0007613': 'Cell physiology',
#  'C0010406': 'WFDC2',
#  'C0007450': 'Felis catus',
#  'C0021359': 'Infertility',
#  'C0012984': 'Canis familiaris',
#  'C0939793': 'Female dog',
#  'C0029045': 'Oocytes',
#  'C0032961': 'Pregnancy',
#  'C0007452': 'Cattle',
#  'C0680063': 'Offspring',
#  'C0009013': 'TAF1C',
#  'C1334043': 'Homologous Gene',
#  'C0230956': 'Eutheria',
#  'C1335188': 'PAG gene',
#  'C1335052': 'PRDX1',
#  'C1355824': 'PAG1',
#  'C0025252': 'Membrane Proteins',
#  'C0037813': 'Mass Spectrometry',
#  'C1167622': 'Binding (Molecular Function)',
#  'C0029418': 'Osteoblasts',
#  'C0180153': 'Covers',
#  'C0007586': 'Cell Cycle',
#  'C0235169': 'Excitability',
#  'C0007765': 'Cerebellum',
#  'C0184906': 'Bifurcation (procedure)',
#  'C0043775': "1,2-bis(2-aminophenoxy)ethane-N,N,N',N'-tetraacetic acid",
#  'C0288263': 'L-Type Calcium Channels',
#  'C0006732': 'Calcium-Binding Proteins',
#  'C0006685': 'Calcium Channel',
#  'C1395184': 'depolarization',
#  'C0011646': 'Dermis',
#  'C0150866': 'Biopsy of skin procedure',
#  'C1540912': 'Hypereosinophilic syndrome',
#  'C0024301': 'Lymphoma, Follicular',
#  'C0013216': 'Pharmacotherapy',
#  'C0040808': 'Treatment Protocols',
#  'C0032136': 'Plasmids',
#  'C0025516': 'Metabolic Detoxication, Drug',
#  'C0033809': 'Pseudomonas aeruginosa',
#  'C0029224': 'Organic Chemicals',
#  'C0441665': 'Disk diffusion, function',
#  'C0054498': 'SMOX',
#  'C0014834': 'Escherichia coli',
#  'C0599770': 'genetic element',
#  'C0004589': 'MUC7',
#  'C0042765': 'Virulence',
#  'C0817320': 'Left femur',
#  'C0001166': 'Acoustics',
#  'C1328436': 'Amino acid level',
#  'C0023401': 'leucine',
#  'C0002521': 'Amino Acids, Branched-Chain',
#  'C0034703': 'Rats, Inbred F344',
#  'C0028778': 'Obstruction',
#  'C1519106': 'Rodent Model',
#  'C0525033': 'Probiotics',
#  'C0010125': 'RASGRP1',
#  'C0812385': 'BCR gene',
#  'C0812613': 'BCR',
#  'C0034790': 'T-Cell Receptor',
#  'C0036962': 'TRBV20OR9-2',
#  'C0214570': 'CCND2 protein, human',
#  'C0214894': 'CCND2',
#  'C0021758': 'interleukin-4',
#  'C0029433': 'Osteogenesis',
#  'C0021289': 'Infant, Newborn',
#  'C0131450': 'CD200R1',
#  'C0029431': 'Osteoclasts',
#  'C0333957': 'Growth acceleration',
#  'C1154313': 'CFAP206',
#  'C0002895': 'Anemia, Sickle Cell',
#  'C0014792': 'Erythrocytes',
#  'C0018801': 'Heart failure',
#  'C0038435': 'Stress',
#  'C0021641': 'Insulin',
#  'C0004936': 'Mental disorders',
#  'C0029343': 'Influenza A Virus, Avian',
#  'C0935640': 'Baculovirus',
#  'C1522485': 'Tracer',
#  'C0040674': 'Transposition procedure',
#  'C0003242': 'Antibodies, Anti-Idiotypic',
#  'C0064755': 'lentil lectin',
#  'C0012923': 'DNA Viruses',
#  'C1579410': 'Nucleoside Analogs',
#  'C0206580': 'Orthopoxvirus',
#  'C0441633': 'Scanning',
#  'C0030498': 'Parasites',
#  'C0008415': 'Choline Kinase',
#  'C0029235': 'Organism',
#  'C0529330': 'Receptor, Angiotensin, Type 1',
#  'C0000185': 'AGTR1',
#  'C0027950': 'neutrophil',
#  'C0040395': 'tomography',
#  'C0598958': 'Neuroprotection',
#  'C0600388': 'Extracellular Signal Regulated Kinases',
#  'C0035565': 'Ribulose-Bisphosphate Carboxylase',
#  'C0995501': 'Rhodopseudomonas palustris',
#  'C0679670': 'network',
#  'C0678601': 'covalence',
#  'C0019944': 'Equus caballus',
#  'C0658195': 'sulfide oxidase',
#  'C0046079': '2-diethylaminoethanol',
#  'C0007974': 'Chelating Agents',
#  'C0032089': 'Plant Proteins',
#  'C0034493': 'Oryctolagus cuniculus',
#  'C0301872': 'Immune response',
#  'C0085104': 'Drug Delivery Systems',
#  'C0236075': 'Menopausal symptom',
#  'C0005802': 'Blood Glucose',
#  'C0178784': 'Organ',
#  'C0033362': 'Proinsulin',
#  'C0029408': 'Degenerative polyarthritis',
#  'C0021107': 'Implantation procedure',
#  'C0029468': 'Osteotomy',
#  'C0010957': 'Tissue damage',
#  'C0013470': 'Eating',
#  'C1154417': 'growth hormone secretion',
#  'C0391690': 'growth hormone secretagogue receptor',
#  'C0041236': 'trypsin',
#  'C0001792': 'Elderly (population group)',
#  'C0338656': 'Impaired cognition',
#  'C0596020': 'Does hit (finding)',
#  'C0678603': 'electron affinity',
#  'C0175723': 'Bands',
#  'C0042210': 'Vaccines',
#  'C0475463': 'Antibodies, Neutralizing',
#  'C0020964': 'Immune response',
#  'C0180392': 'Detectors',
#  'C0282641': 'Transgenes',
#  'C0079460': 'Granulocyte-Macrophage Colony-Stimulating Factor',
#  'C0071437': 'poly(hexyl-2-cyanoacrylate)',
#  'C0073918': 'LAMC2',
#  'C0206194': 'Survivors',
#  'C1279051': 'Entire fascia',
#  'C0334044': 'Dysplasia',
#  'C0152027': 'Sensory Disorders',
#  'C0423572': 'Pins and needles',
#  'C0002028': 'Algae',
#  'C1550678': 'Water Specimen',
#  'C0600688': 'Toxic effect',
#  'C0184661': 'Interventional procedure',
#  'C0004927': 'Behavior',
#  'C0231170': 'Disability',
#  'C0145947': 'Tissue-Inhibitor of Metalloproteinase-1',
#  'C0239946': 'Fibrosis, Liver',
#  'C0016767': 'Fruit',
#  'C0014653': 'Equilibrium',
#  'C0028908': 'Oils',
#  'C0206135': 'Platinum Compounds',
#  'C0599918': 'NEPHROTOXICITY',
#  'C0028128': 'nitric oxide',
#  'C0022023': 'Ions',
#  'C0006212': 'Bromates',
#  'C0020282': 'Hydrogen Sulfide',
#  'C0013502': 'Echinococcosis',
#  'C0431648': 'Rokitansky sequence',
#  'C0598067': 'Chondrogenesis',
#  'C1519726': 'Tyrosine Phosphorylation',
#  'C0021665': 'Insulin-Like Growth Factor I',
#  'C0450442': 'Agent',
#  'C0086982': 'Signal Transduction Pathways',
#  'C0971859': 'Bone Growth',
#  'C0007090': 'Carcinogens',
#  'C0007137': 'Squamous cell carcinoma',
#  'C0003162': 'HMOX1',
#  'C0001430': 'Adenoma',
#  'C0024109': 'Lung',
#  'C0023610': 'Gonadorelin',
#  'C0022796': 'GNRH1',
#  'C1417166': 'MICE gene',
#  'C0001545': 'CYP1B1',
#  'C0919425': 'CYP1A1 gene',
#  'C0911543': 'CYP1A1',
#  'C1148673': 'DNA Binding',
#  'C0035696': 'RNA, Messenger',
#  'C0439861': 'Substance',
#  'C1451357': 'BCAR1 protein, human',
#  'C1459564': 'BCAR1',
#  'C0001275': 'activated charcoal',
#  'C0003075': 'Anions',
#  'C0442540': 'Streams',
#  'C0060600': 'Fly Ash',
#  'C0608091': "Low's mixture",
#  'C0076733': 'titanium dioxide',
#  'C0599786': 'Pollutant',
#  'C0350056': 'Adsorbent',
#  'C0031117': 'Peripheral Neuropathy',
#  'C0442874': 'Neuropathy',
#  'C0458247': 'Allodynia',
#  'C0027836': 'Neuroglia',
#  'C0278220': 'Auditory reflex',
#  'C0036341': 'Schizophrenia',
#  'C0037083': 'Signal Transduction',
#  'C0598501': 'Chromosome Pairing',
#  'C0061928': 'GTPase-Activating Proteins',
#  'C1281026': 'Entire dentate gyrus',
#  'C0107103': 'Brain-Derived Neurotrophic Factor',
#  'C0000761': 'CA3',
#  'C0022471': 'Kainic Acid',
#  'C0085301': 'Proto-Oncogene Proteins c-fos',
#  'C0082353': 'FOS',
#  'C0596588': 'FOS Protein',
#  'C0592353': 'FOS',
#  'C1414908': 'GABRA1 gene',
#  'C1412554': 'ARSB gene',
#  'C0027765': 'nervous system disorder',
#  'C0678903': 'Neuronal Transmission',
#  'C0040822': 'Tremor',
#  'C0002554': 'GABRA1',
#  'C0596611': 'Gene Mutation',
#  'C0270736': 'Essential Tremor',
#  'C0007457': 'Caucasian',
#  'C0015859': 'Ferrets',
#  'C0227650': 'Juxtaglomerular cell',
#  'C0268731': 'Renal glomerular disease',
#  'C1260875': 'mating',
#  'C0001041': 'CDSN',
#  'C0026845': 'Muscle Tissue',
#  'C0376702': 'COS Cells',
#  'C0001044': 'acetylcholinesterase',
#  'C0040669': 'Transfection',
#  'C0031849': 'physostigmine',
#  'C0025086': 'Medical Imaging',
#  'C0162772': 'Reactive Oxygen Species',
#  'C0030193': 'Pain',
#  'C0012683': 'Disinfection',
#  'C0007286': 'Carpal Tunnel Syndrome',
#  'C0311392': 'Physical findings',
#  'C0751922': 'Median Neuropathy',
#  'C0144576': 'paclitaxel',
#  'C0020429': 'Hyperalgesia',
#  'C0011164': 'Abnormal degeneration',
#  'C0004461': 'Axon',
#  'C0501385': 'Sensory nerve',
#  'C1157338': 'isoprenoid biosynthetic process',
#  'C0858318': 'Plasmodium falciparum infection',
#  'C0762819': 'ROP 1 protein, Toxoplasma gondii',
#  'C0678544': 'wave - physical agent',
#  'C0011573': 'Endogenous depression',
#  'C0167206': 'TM4SF1 protein, human',
#  'C0164071': 'TM4SF1',
#  'C0682708': 'White matter',
#  'C0058990': 'Eukaryotic Initiation Factor-4G',
#  'C0030943': 'Peptide Initiation Factors',
#  'C0487637': 'T lymphocyte antigen',
#  'C0007786': 'Brain Ischemia',
#  'C0521449': 'Cytoplasmic',
#  'C0020960': 'Immune Sera',
#  'C0021792': 'Interneurons',
#  'C0575090': 'Equilibration disorder',
#  'C0015535': 'Faculty',
#  'C1335770': 'PTPN1',
#  'C0206745': 'Mice, Knockout',
#  'C0162512': 'Neostriatum',
#  'C0007370': 'Catalepsy',
#  'C0162788': 'In Situ Hybridization',
#  'C0042839': 'vitamin A',
#  'C0015674': 'Chronic Fatigue Syndrome',
#  'C0020255': 'Hydrocephalus',
#  'C0022116': 'Ischemia',
#  'C0149784': 'biological adaptation to stress',
#  'C0746574': 'methylate',
#  'C1136249': 'Mental Retardation, X-Linked',
#  'C0282109': 'Holoenzymes',
#  'C0013139': 'Drosophila melanogaster',
#  'C0011529': 'Deoxyribonucleotides',
#  'C0026584': 'Culicidae',
#  'C0302583': 'iron',
#  'C0041912': 'Upper Respiratory Infections',
#  'C0264221': 'Disorder of upper respiratory system',
#  'C0028429': 'Nose',
#  'C1260880': 'Rhinorrhea',
#  'C0214439': 'marbofloxacin',
#  'C0733758': 'Follicle Stimulating Hormone',
#  'C0736046': 'BRD2',
#  'C0013798': 'Electrocardiogram',
#  'C0002186': 'BPTF',
#  'C0677666': 'soy protein isolate',
#  'C0007103': 'TSPAN8',
#  'C0074926': 'Soy Proteins',
#  'C0032150': 'Plasmodium falciparum',
#  'C0002345': 'Alternative Splicing',
#  'C0024660': 'Mammals',
#  'C0385463': 'leptin receptor',
#  'C0383953': 'LEPR',
#  'C0017375': 'tat Genes',
#  'C0016898': 'TAT',
#  'C0006104': 'Brain',
#  'C0871125': 'prepulse inhibition activity',
#  'C1337069': 'Trauma, chest',
#  'C0009630': 'Concanavalin A',
#  'C0021756': 'Interleukin-2',
#  'C1159339': 'Protein Secretion',
#  'C0288011': 'NF-AT',
#  'C1155046': 'T-Cell Proliferation',
#  'C0001492': 'Adenylate Cyclase',
#  'C0544650': 'Adrenergic receptor function',
#  'C0002395': "Alzheimer's Disease",
#  'C0017837': 'Glutathione S-Transferase',
#  'C0133482': 'SLCO6A1',
#  'C0373156': 'GSTK1',
#  'C0243192': 'agonists',
#  'C1158770': 'Transcriptional Regulation',
#  'C0020281': 'hydrogen peroxide',
#  'C0003197': 'HOXA@',
#  'C0003198': 'HOXA1',
#  'C0003200': 'HOXA3',
#  'C0003201': 'HOXA4',
#  'C0003202': 'HOXA5',
#  'C0003203': 'HOXA6',
#  'C0003204': 'Anti-Infective Agents',
#  'C0003205': 'Anti-Infective Agents, Local',
#  'C0003206': 'HOXA10',
#  'C0003207': 'HOXA11',
#  'C0003209': 'Anti-Inflammatory Agents',
#  'C1419746': 'RPS6KA5 gene',
#  'C1419252': 'RPS6KA5',
#  'C0031715': 'Phosphorylation',
#  'C0085828': 'Transcription Factor AP-1',
#  'C0082354': 'FOSB',
#  'C0083725': 'JUN',
#  'C0083726': 'JUNB',
#  'C0083727': 'Neurogranin',
#  'C0040648': 'TRANSCRIPTION FACTOR',
#  'C0041904': 'Up-Regulation (Physiology)',
#  'C0007620': 'Cell Survival',
#  'C0017360': 'pol genes',
#  '100616496': 'ERVW-4',
#  'C0035668': 'RNA',
#  'C0314732': 'Infectious agent',
#  'C100616496': 'ERVW-4',
#  'C0035366': 'Retroviridae',
#  'C0017281': 'Gene Products, pol',
#  'C0031212': 'Personality Disorders',
#  'C0027882': 'Neurons',
#  'C0047845': 'gaboxadol',
#  'C1253955': 'Body cavity structure',
#  'C0038818': 'Sunscreening Agents',
#  'C0857127': 'Induction procedure',
#  'C0020971': 'Immunization',
#  'C0000973': 'CD79A',
#  '102723407': 'LOC102723407',
#  'C1332104': 'APPBP2 gene',
#  'C1310513': 'APPBP2',
#  'C0010513': 'APPBP2',
#  'C0206358': 'SLC36A1',
#  'C0012186': 'Diethyl Pyrocarbonate',
#  'C0001128': 'CHRM1',
#  'C0042930': 'Vocal cord structure',
#  'C0015350': 'Extracellular Matrix',
#  'C1521828': 'Rate',
#  'C0018483': 'Haemophilus influenzae',
#  'C0052796': 'azithromycin',
#  'C0340044': 'Acute exacerbation of chronic obstructive airways disease',
#  'C0001617': 'Adrenal Cortex Hormones',
#  'C0243065': 'Aplasia, NOS',
#  'C0426706': 'Absent kidney',
#  'C0476273': 'Respiratory distress',
#  'C0646681': 'Carrington dermal wound gel',
#  'C0037494': 'sodium chloride',
#  'C0023870': 'lithium',
#  'C0014175': 'Endometriosis',
#  'C0870221': 'Boys',
#  'C0026848': 'Myopathy',
#  'C0521450': 'lysosomal',
#  'C0450138': 'Cultured skin',
#  'C0015278': 'Glucan 1,4-alpha-Glucosidase',
#  'C0337580': 'Cousin',
#  'C0270960': 'Congenital myopathy (disorder)',
#  'C0037047': 'Sibling',
#  'C1336014': 'Small RNA',
#  'C1160638': 'Viral life cycle',
#  'C0017004': 'Gamma Cameras',
#  'C0038220': 'Status Epilepticus',
#  'C0012472': 'dinoprostone',
#  'C0085387': 'Cyclooxygenase Inhibitors',
#  'C0002716': 'Amyloid',
#  'C0486805': 'Fragments',
#  'C0004774': 'NFIA',
#  'C0004781': 'NFIB',
#  'C0004782': 'NFIC',
#  'C0004784': 'NFIX',
#  'C0114799': 'ESCO1',
#  'C0023621': 'Libraries',
#  'C1269578': 'Entire substantia nigra',
#  'C0013384': 'Dyskinetic syndrome',
#  'C0023570': 'levodopa',
#  'C1154437': 'dopamine metabolism',
#  'C0030567': 'Parkinson Disease',
#  'C1136180': 'Disease Resistance',
#  'C0057738': 'Diazepam Binding Inhibitor',
#  'C0034170': 'Putrescine',
#  'C0029282': 'Ornithine Decarboxylase',
#  'C0019587': 'Amine Oxidase (Copper-Containing)',
#  'C0052331': 'Arginine decarboxylase',
#  'C0007590': 'Cell division',
#  'C0542479': 'Energy, Physics',
#  'C0001109': 'AKR1C4',
#  'C0034320': 'Diphosphates',
#  'C1157206': 'starch biosynthetic process',
#  'C0065042': 'Annexins',
#  'C0032520': 'Polymerase Chain Reaction',
#  'C1157011': 'phenylpropanoid metabolic process',
#  'C1156971': 'anthocyanin-containing compound biosynthetic process',
#  'C0004728': 'Rats, Bandicoot',
#  'C0374291': 'NDUFS7',
#  'C1370600': 'MAP Kinase Gene',
#  'C1443775': 'Epidermal growth factor receptor inhibitor (product)',
#  'C0596290': 'Cell Proliferation',
#  'C0242982': 'c-erbB-1 Proto-Oncogenes',
#  'C0241956': 'EGFR',
#  'C0387583': 'cyclooxygenase 2',
#  'C0018282': 'Growth Inhibitors',
#  'C1257954': 'Cyclooxygenase 2 Inhibitors',
#  'C0334227': 'Tumor cells, malignant',
#  'C0021557': 'myo-Inositol-1-Phosphate Synthase',
#  'C0596902': 'Membrane Transport Proteins',
#  'C0031621': 'phosphatidylinositols',
#  'C0021547': 'inositol',
#  'C0016163': 'Fishes',
#  'C0013839': 'Electromyography',
#  'C1552132': 'Supernumerary mandibular left second molar',
#  'C0008972': 'Clinical Research',
#  'C1265658': 'Anterior dislocation',
#  'C1293903': 'Vagal stimulation',
#  'C0206131': 'Adipocytes',
#  'C0034715': 'Rats, Sprague-Dawley',
#  'C0596843': 'Adipogenesis',
#  'C0166417': 'PPAR gamma',
#  'C0041004': 'Triglycerides',
#  'C1260899': 'Anemia, Diamond-Blackfan',
#  'C0073320': 'ribosomal protein S19',
#  'C0398550': 'Congenital pure red cell aplasia',
#  'C0086282': 'Family member',
#  'C0525038': 'Amino Acid Substitution',
#  'C1171362': 'protein expression',
#  'C0076934': 'Transposase',
#  'C0446085': 'Aspergillus awamori',
#  'C1335623': 'RIPK1 gene',
#  'C1338737': 'RIPK1',
#  'C0004038': 'LRP4',
#  'C0949771': 'Amino Acid Transporter',
#  'C0230770': 'Endoplasmic reticulum, membrane',
#  'C1159342': 'Secretory Pathway',
#  'C0016832': 'Fungi',
#  'C0033382': 'proline',
#  'C0017345': 'Genes, Fungal',
#  'C1334046': 'Genes, Housekeeping',
#  'C0283827': 'Elongation Factor 1alpha',
#  'C0004810': 'NHS',
#  'C0319683': 'Pleurotus ostreatus',
#  'C1269100': 'Eosinophilic major basic protein',
#  'C1264155': 'MBP',
#  'C0004037': 'Aspergillus fumigatus',
#  'C0017696': 'Glucans',
#  'C0521049': 'Conidia',
#  'C0007623': 'Cell Wall',
#  'C0001962': 'ethanol',
#  'C0014544': 'Epilepsy',
#  'C0038317': 'Steroids',
#  'C0328038': 'Cyprinus carpio',
#  'C0018120': 'Ovarian Follicle',
#  'C0304866': 'Insulin, Beef',
#  'C0205065': 'Ovarian',
#  'C0220821': 'dihydropyridine',
#  'C1141639': 'Human Chorionic Gonadotropin',
#  'C1141081': 'CGA',
#  'C1143342': 'HTC2',
#  'C1193659': 'CGB5',
#  'C1325702': 'germinal vesicle',
#  'C0010934': 'MORF4',
#  'C1160520': 'oocyte maturation',
#  'C1366555': 'DPYD gene',
#  'C1361806': 'DPYD',
#  'C0020855': 'IgG1',
#  'C0181835': 'Micromanipulator',
#  'C0017110': 'Gases',
#  'C0020564': 'Hypertrophy',
#  'C0018284': 'Growth Factor',
#  'C0022984': 'Laminin',
#  'C0206535': 'Mice, Inbred mdx',
#  'C0040690': 'Transforming Growth Factor beta',
#  'C0015075': 'ethylene',
#  'C0920552': 'hormonal regulation',
#  'C0597252': 'Plant Development',
#  'C0678632': 'two-dimensional electrophoresis',
#  'C0068003': 'n-heptane',
#  'C0001975': 'Alcohols',
#  'C0014898': 'Esters',
#  'C0015083': 'ethylene glycol',
#  'C0077096': 'triethylamine',
#  'C0982392': 'SODIUM MONOHYDRATE',
#  'C0035525': 'ribavirin',
#  'C0002594': 'Transaminases',
#  'C0015695': 'Fatty Liver',
#  'C0010674': 'Cystic Fibrosis',
#  'C0004611': 'Bacteria',
#  'C0175925': 'Cattle for milk production',
#  'C0035204': 'Respiration Disorders',
#  'C1136170': 'Virulence Factors',
#  'C0220905': 'regulatory',
#  'C0029921': 'Outpatients',
#  'C0020034': 'Host-Parasite Interactions',
#  'C0936012': 'Analysis',
#  'C0019169': 'hepatitis B virus',
#  'C0005955': 'Bone Marrow Cells',
#  'C0025936': 'Mice, Transgenic',
#  'C0301521': 'Therapeutic vaccine',
#  'C0005790': 'Blood coagulation tests',
#  'C0684072': 'albino rat',
#  'C0043342': 'Xenopus',
#  'C1267211': 'Entire duct',
#  'C0006574': 'SLC20A1',
#  'C0231048': 'Pronephric structure',
#  'C0042449': 'Veins',
#  'C0043240': 'Wound Healing',
#  'C1415406': 'H2AX gene',
#  'C1413014': 'H2AFX',
#  'C0243114': 'purification',
#  'C0008550': 'Chromatography',
#  'C0023630': 'INS',
#  'C0002245': 'FGD1',
#  'C0317603': 'Limosilactobacillus fermentum',
#  'C0002712': 'amylase',
#  'C0002732': 'Amylose',
#  'C0024658': 'maltose',
#  'C0065603': 'maltoheptaose',
#  'C0021186': 'indapamide',
#  'C0185115': 'Extraction',
#  'C0059747': 'ethyl acetate',
#  'C0238806': 'BONE MASS',
#  'C0085268': 'Bone remodeling',
#  'C0033497': 'propranolol',
#  'C0029419': 'Osteocalcin',
#  'C0000054': 'ACP5',
#  'C0029458': 'Osteoporosis, Postmenopausal',
#  'C0012544': 'Diphosphonates',
#  'C0379199': 'ibandronate',
#  'C0039401': 'Educational process of instructing',
#  'C0021900': 'Intrauterine Devices',
#  'C0289121': 'protein phosphatase 5',
#  'C0243044': 'HSP90 Heat-Shock Proteins',
#  'C0243320': 'HSP90AA1',
#  'C1335884': 'SWI1',
#  'C0026764': 'Multiple Myeloma',
#  'C1176309': 'bortezomib',
#  'C1443643': 'INSR',
#  'C0178522': 'boronic acid',
#  'C0001271': 'Actins',
#  'C0598148': 'hybrid protein',
#  'C0597428': 'Sedimentation procedure',
#  'C1519619': 'Translational Repression',
#  'C0270814': 'Spastic syndrome',
#  'C0242849': 'Microscopy, Atomic Force',
#  'C0597545': 'synaptogenesis',
#  'C1519751': 'Ubiquitination',
#  'C0302614': 'Guide device',
#  ...}

# %%
pd.read_csv(join('all_triples', 'relation_type_description.csv'), compression = 'gzip')
# Out:
#                        name  \
# 0     PHYSICALLY_RELATED_TO
# 1                   PART_OF
# 2                  CONTAINS
# 3               LOCATION_OF
# 4     TEMPORALLY_RELATED_TO
# 5            CO-OCCURS_WITH
# 6                  PRECEDES
# 7   FUNCTIONALLY_RELATED_TO
# 8                PROCESS_OF
# 9               CARRIES_OUT
# 10           INTERACTS_WITH
# 11                PRACTICES
# 12                 PRODUCES
# 13                 EXHIBITS
# 14                 DISRUPTS
# 15                   CAUSES
# 16                 PREVENTS
# 17              COMPLICATES
# 18         MANIFESTATION_OF
# 19                  AFFECTS
# 20                OCCURS_IN
# 21                  MANAGES
# 22                   TREATS
# 23                     USES
# 24                INDICATES
# 25                RESULT_OF
# 26  CONCEPTUALLY_RELATED_TO
# 27              PROPERTY_OF
# 28       CONCEPTUAL_PART_OF
# 29            EVALUATION_OF
# 30                 MEASURES
# 31                DIAGNOSES
# 32       ASSESSES_EFFECT_OF
# 33                 ISSUE_IN
# 34          ASSOCIATED_WITH
# 35              CONSISTS_OF
# 36              ADJACENT_TO
# 37             CONNECTED_TO
# 38            INTERCONNECTS
# 39                SURROUNDS
# 40                TRAVERSES
# 41            DERIVATIVE_OF
# 42    DEVELOPMENTAL_FORM_OF
# 43                DEGREE_OF
# 44           MEASUREMENT_OF
# 45                METHOD_OF
# 46                      ISA
# 47             BRINGS_ABOUT
# 48                 PERFORMS
# 49     SPATIALLY_RELATED_TO
# 50                 ANALYZES
# 51                BRANCH_OF
# 52             TRIBUTARY_OF
# 53            INGREDIENT_OF
#
#                                            definition  usage_note  \
# 0   Related by virtue of some physical attribute o...         NaN
# 1   Composes, with one or more other physical unit...         NaN
# 2   Holds or is the receptacle for fluids or other...         NaN
# 3   The position, site, or region of an entity or ...         NaN
# 4   Related in time by preceding, co-occuring with...         NaN
# 5   Occurs at the same time as, together with, or ...         NaN
# 6   Occurs earlier in time. This includes antedate...         NaN
# 7   Related by the carrying out of some function o...         NaN
# 8                      Action, function, or state of.         NaN
# 9   Executes a function or performs a procedure or...         NaN
# 10        Acts, functions, or operates together with.         NaN
# 11                Performs habitually or customarily.         NaN
# 12  Brings forth, generates or creates. This inclu...         NaN
# 13                             Shows or demonstrates.         NaN
# 14  Alters or influences an already existing condi...         NaN
# 15  Brings about a condition or an effect. Implied...         NaN
# 16  Stops, hinders or eliminates an action or cond...         NaN
# 17  Causes to become more severe or complex or res...         NaN
# 18  That part of a phenomenon which is directly ob...         NaN
# 19  Produces a direct effect on. Implied here is t...         NaN
# 20  Takes place in or happens under given conditio...         NaN
# 21  Administers, or contributes to the care of an ...         NaN
# 22  Applies a remedy with the object of effecting ...         NaN
# 23  Employs in the carrying out of some activity. ...         NaN
# 24  Gives evidence for the presence at some time o...         NaN
# 25  The condition, product, or state occurring as ...         NaN
# 26  Related by some abstract concept, thought, or ...         NaN
# 27                  Characteristic of, or quality of.         NaN
# 28  Conceptually a portion, division, or component...         NaN
# 29  Judgment of the value or degree of some attrib...         NaN
# 30  Ascertains or marks the dimensions, quantity, ...         NaN
# 31  Distinguishes or identifies the nature or char...         NaN
# 32  Analyzes the influence or consequences of the ...         NaN
# 33  Is an issue in or a point of discussion, study...         NaN
# 34      has a significant or salient relationship to.         NaN
# 35  Is structurally made up of in whole or in part...         NaN
# 36  Close to, near or abutting another physical un...         NaN
# 37  Directly attached to another physical unit as ...         NaN
# 38  Serves to link or join together two or more ot...         NaN
# 39  Establishes the boundaries for, or defines the...         NaN
# 40  Crosses or extends across another physical str...         NaN
# 41  In chemistry, a substance structurally related...         NaN
# 42  An earlier stage in the individual maturation of.         NaN
# 43  The relative intensity of a process or the rel...         NaN
# 44  The dimension, quantity, or capacity determine...         NaN
# 45  The manner and sequence of events in performin...         NaN
# 46  The basic hierarchical link in the Network. If...         NaN
# 47                   Acts on or influences an entity.         NaN
# 48   Executes, accomplishes, or achieves an activity.         NaN
# 49                        Related by place or region.         NaN
# 50  Studies or examines using established quantita...         NaN
# 51  Arises from the division of. For example, the ...         NaN
# 52  Merges with. For example, the confluence of ve...         NaN
# 53  Is a component of, as in a constituent of a pr...         NaN
#
#            relation_inverse abbreviation
# 0     PHYSICALLY_RELATED_TO           PR
# 1                  HAS_PART           PT
# 2              CONTAINED_IN           CT
# 3              HAS_LOCATION           LO
# 4     TEMPORALLY_RELATED_TO           TR
# 5            CO-OCCURS_WITH           CW
# 6                   FOLLOWS           PC
# 7   FUNCTIONALLY_RELATED_TO           FR
# 8               HAS_PROCESS           PO
# 9            CARRIED_OUT_BY           CO
# 10           INTERACTS_WITH           IW
# 11             PRACTICED_BY           PA
# 12              PRODUCED_BY           PS
# 13             EXHIBITED_BY           EX
# 14             DISRUPTED_BY           DS
# 15                CAUSED_BY           CA
# 16             PREVENTED_BY           PV
# 17           COMPLICATED_BY           CM
# 18        HAS_MANIFESTATION           MF
# 19              AFFECTED_BY           AF
# 20           HAS_OCCURRENCE           OC
# 21               MANAGED_BY           MN
# 22               TREATED_BY           TS
# 23                  USED_BY           US
# 24             INDICATED_BY           IN
# 25               HAS_RESULT           RO
# 26  CONCEPTUALLY_RELATED_TO           CR
# 27             HAS_PROPERTY           PP
# 28      HAS_CONCEPTUAL_PART           CP
# 29           HAS_EVALUATION           EV
# 30              MEASURED_BY           MS
# 31             DIAGNOSED_BY           DI
# 32   ASSESSED_FOR_EFFECT_BY           AE
# 33                HAS_ISSUE           II
# 34          ASSOCIATED_WITH           AW
# 35              CONSTITUTES           CS
# 36              ADJACENT_TO           AD
# 37             CONNECTED_TO           CN
# 38        INTERCONNECTED_BY           IC
# 39            SURROUNDED_BY           SR
# 40             TRAVERSED_BY           TV
# 41           HAS_DERIVATIVE           DO
# 42   HAS_DEVELOPMENTAL_FORM           DF
# 43               HAS_DEGREE           DE
# 44          HAS_MEASUREMENT           ME
# 45               HAS_METHOD           MT
# 46              INVERSE_ISA           IS
# 47         BROUGHT_ABOUT_BY           BA
# 48             PERFORMED_BY           PE
# 49     SPATIALLY_RELATED_TO           SP
# 50              ANALYZED_BY           AN
# 51               HAS_BRANCH           BR
# 52            HAS_TRIBUTARY           TB
# 53           HAS_INGREDIENT           IG

# %%
entity_type_desc = pd.read_csv(join('all_triples', 'entity_type_description.csv'), compression = 'gzip')

# %%
entity_type_desc
# Out:
#                                           name  \
# 0                                     Organism
# 1                                        Plant
# 2                                       Fungus
# 3                                        Virus
# 4                                    Bacterium
# ..                                         ...
# 131                                      Lipid
# 132  Neuroreactive Substance or Biogenic Amine
# 133                                       Alga
# 134                    Rickettsia or Chlamydia
# 135                               Invertebrate
#
#                                             definition  \
# 0    Generally, a living individual, including all ...
# 1    An organism having cellulose cell walls, growi...
# 2    A eukaryotic organism characterized by the abs...
# 3    An organism consisting of a core of a single n...
# 4    A small, typically one-celled, prokaryotic mic...
# ..                                                 ...
# 131  An inclusive group of fat or fat-derived subst...
# 132  An endogenous substance whose activities affec...
# 133  A chiefly aquatic plant that contains chloroph...
# 134  An organism intermediate in size and complexit...
# 135              An animal which has no spinal column.
#
#                                             usage_note abbreviation
# 0                                                  NaN         orgm
# 1                                                  NaN         plnt
# 2                                                  NaN         fngs
# 3                                                  NaN         virs
# 4                                                  NaN         bact
# ..                                                 ...          ...
# 131  Phospholipids should not also be typed with 'O...         lipd
# 132  Unlike many of the other types under 'Biologic...         nsba
# 133                                                NaN         alga
# 134                                                NaN         rich
# 135  This type has no children in the network and i...         invt
#
# [136 rows x 4 columns]

# %%
entity_type_desc[entity_type_desc['name'].str.contains('Virus')]
# Out:
#     name                                         definition usage_note  \
# 3  Virus  An organism consisting of a core of a single n...        NaN
#
#   abbreviation
# 3         virs

# %%
pd.read_csv(join(PROC_UMLS, 'sem_network.csv'))
# Out:
#      head_type       rel tail_type
# 0         acab   affects      amph
# 1         acab   affects      anim
# 2         acab   affects      arch
# 3         acab   affects      bact
# 4         acab   affects      bird
# ...        ...       ...       ...
# 6100      vita       isa      enty
# 6101      vita       isa      phob
# 6102      vita       isa      sbst
# 6103      vita  issue_in      bmod
# 6104      vita  issue_in      ocdi
#
# [6105 rows x 3 columns]
