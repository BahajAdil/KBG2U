# %%
import pandas as pd
from glob import glob
from os.path import join
import networkx as nx
from tqdm.notebook import tqdm
import json

PREDICATION_COLS = [
    'PREDICATION_ID', 'SENTENCE_ID', 'PMID', 'PREDICATE', 
    'SUBJECT_CUI', 'SUBJECT_NAME', 'SUBJECT_SEMTYPE', 'SUBJECT_NOVELTY', 'OBJECT_CUI',
    'OBJECT_NAME', 'OBJECT_SEMTYPE', 'OBJECT_NOVELTY', 'Nan1', 'Nan2', 'Nan3']

SENTENCE_DIR = 'SENTENCE'
PREDICATION_DIR = 'PREDICATION'
PREDICATION_AUX_DIR = 'PREDICATION_AUX'

# %%
def save_json(save_path, data):
    with open(save_path, 'w') as f:
        json.dump(data, f)
        
def read_json(save_path):
    with open(save_path, 'r') as f:
        data = json.load(f)
    return data

# %%
def canonize_cui(cui):
    cacon_form = 'C0000000'
    if len(cui)<8:
        cui = cacon_form[0:-len(cui)]+cui
    elif 'C' not in  cui:
        cui = 'C' + cui
    return cui

def process_mult_cui(cui):
    origin_cui = None
    all_cuis = []
    for cu in cui.split('|'):
        if origin_cui is None:
            cu = canonize_cui(cu)
            origin_cui = cu
        else:
#             cu = origin_cui[0:len(origin_cui)-len(cu)] + cu
            cu = origin_cui[0:-len(cu)] + cu
        all_cuis.append(cu)
    return all_cuis

def process_cui(cui):
    if '|' in cui:
        cuis = process_mult_cui(cui)
    else:
        cuis = [canonize_cui(cui)]
    return cuis

# %% [markdown]
# ## Example

# %%
df = pd.read_csv('Format_sents/form_sent_849503.csv',compression = 'gzip')

# %%
df
# Out:
#      PREDICATION_AUX_ID                                           SENTENCE  \
# 0             167307222  BACKGROUND: Two and a half years after commenc...
# 1             167307223  BACKGROUND: Two and a half years after commenc...
# 2             167307224  This subsequent outbreak provided the opportun...
# 3             167307225  Children with rotavirus-confirmed gastroenteri...
# 4             167307226  Nineteen (46%) of 41 case patients had receive...
# ..                  ...                                                ...
# 96            167307319  However, the subtype PsA was more prevalent in...
# 97            167307320  CONCLUSION: In Sweden the prevalence of spondy...
# 98            167307321  PsA was the most frequent subtype followed by ...
# 99            167307322  Magnetic resonance imaging of skeletal muscles...
# 100           167307323  Magnetic resonance imaging of skeletal muscles...
#
#                                      FORMATED_SENTENCE  \
# 0    BACKGROUND: Two and a half years after commenc...
# 1    BACKGROUND: Two and a half years after commenc...
# 2    This subsequent outbreak provided the opportun...
# 3    @PREDICAT$ @OBJECT$ rotavirus-confirmed @SUBJE...
# 4    Nineteen (46%) of 41 case patients had receive...
# ..                                                 ...
# 96   However, the subtype PsA was more prevalent in...
# 97   CONCLUSION: In Sweden the prevalence of @SUBJE...
# 98   @SUBJECT$ was the most frequent subtype @OBJEC...
# 99   @PREDICAT$ @OBJECT$ @SUBJECT$ in sporadic incl...
# 100  @SUBJECT$ of skeletal muscles @OBJECT$ @PREDIC...
#
#                         file_name
# 0    SENTENCE/split_990577.csv.gz
# 1    SENTENCE/split_990577.csv.gz
# 2    SENTENCE/split_990577.csv.gz
# 3    SENTENCE/split_990577.csv.gz
# 4    SENTENCE/split_990577.csv.gz
# ..                            ...
# 96   SENTENCE/split_990577.csv.gz
# 97   SENTENCE/split_990577.csv.gz
# 98   SENTENCE/split_990577.csv.gz
# 99   SENTENCE/split_990577.csv.gz
# 100  SENTENCE/split_990577.csv.gz
#
# [101 rows x 4 columns]

# %%
def vis_formating():

# %%
list(df.iloc[0,1:3])
# Out:
# ['BACKGROUND: Two and a half years after commencing routine vaccination with human rotavirus vaccine, an outbreak of rotavirus G2P[4] infection occurred in central Australia.',
#  'BACKGROUND: Two and a half years after commencing routine vaccination with @PREDICAT$@OBJECT$@SUBJECT$, an outbreak of rotavirus G2P[4] infection occurred in central Australia.']

# %%
list(df.iloc[2,1:3])
# Out:
# ['This subsequent outbreak provided the opportunity to evaluate vaccine effectiveness against hospitalizations for a non-vaccine-related genotype in the same population.',
#  'This subsequent outbreak provided the opportunity to evaluate vaccine effectiveness against @SUBJECT$ for a non-vaccine-related genotype @OBJECT$ the same @PREDICAT$.']

# %%
This ... against hospitalizations ... genotype in the same population
This ... against @SUBJECT$ ... genotype @OBJECT$ the same @PREDICAT$

# %%
list(df.iloc[3,1:3])
# Out:
# ['Children with rotavirus-confirmed gastroenteritis were individually matched by date of birth and Indigenous status with 4 control subjects.',
#  '@PREDICAT$ @OBJECT$ rotavirus-confirmed @SUBJECT$ were individually matched by date of birth and Indigenous status with 4 control subjects.']

# %%
Children with ... rotavirus-confirmed gastroenteritis were individually ...
@PREDICAT$ @OBJECT$ rotavirus-confirmed @SUBJECT$ were individually ...

# %%
list(df.iloc[4,1:3])
# Out:
# ['Nineteen (46%) of 41 case patients had received 2 doses of human rotavirus vaccine, compared with 87 (53%) of 164 control subjects.',
#  'Nineteen (46%) of 41 case patients had received 2 doses of @PREDICAT$@OBJECT$@SUBJECT$, compared with 87 (53%) of 164 control subjects.']

# %%
Nineteen ... human rotavirus vaccine, ....

# %%
Nineteen ... @PREDICAT$@OBJECT$@SUBJECT$, ...

# %%
list(df.iloc[5,1:3])
# Out:
# ['Nineteen (46%) of 41 case patients had received 2 doses of human rotavirus vaccine, compared with 87 (53%) of 164 control subjects.',
#  'Nineteen (46%) of 41 case @PREDICAT$ had @OBJECT$ 2 doses of human rotavirus @SUBJECT$, compared with 87 (53%) of 164 control subjects.']

# %%
Nineteen ... patients had received 2 doses of human rotavirus vaccine ...

# %%
Nineteen ... patients had received 2 doses of @PREDICAT$@OBJECT$@SUBJECT$, ...

# %%
Nineteen ... @PREDICAT$ had @OBJECT$ 2 doses of human rotavirus @SUBJECT$, ...

# %%
list(df.iloc[6,1:3])
# Out:
# ['On secondary analysis, there was evidence of a protective effect against disease complicated by acidosis in the subset of infants aged <12 months (odds ratio, .15; 95% confidence interval, .03-.84).',
#  'On secondary analysis, there was evidence of a protective effect against @PREDICAT$ @OBJECT$ by @SUBJECT$ in the subset of infants aged <12 months (odds ratio, .15; 95% confidence interval, .03-.84).']

# %%
list(df.iloc[7,1:3])
# Out:
# ['CONCLUSIONS: Evidence was not found for an overall protective effect of human rotavirus vaccine against hospitalization for rotavirus disease in this setting.',
#  'CONCLUSIONS: Evidence was not found for an overall protective effect of @PREDICAT$@OBJECT$@SUBJECT$ against hospitalization for rotavirus disease in this setting.']

# %%
all_paths = glob(join('Format_sents', '*'))

# %%
all_paths
# Out:
# ['Format_sents/labeled_sent_336531.csv',
#  'Format_sents/labeled_sent_880942.csv',
#  'Format_sents/labeled_sent_374527.csv',
#  'Format_sents/labeled_sent_444837.csv',
#  'Format_sents/labeled_sent_227041.csv',
#  'Format_sents/labeled_sent_414796.csv',
#  'Format_sents/labeled_sent_789753.csv',
#  'Format_sents/labeled_sent_454270.csv',
#  'Format_sents/labeled_sent_216764.csv',
#  'Format_sents/form_sent_849503.csv',
#  'Format_sents/labeled_sent_935261.csv',
#  'Format_sents/labeled_sent_558626.csv',
#  'Format_sents/form_sent_638818.csv',
#  'Format_sents/labeled_sent_969843.csv',
#  'Format_sents/form_sent_521379.csv',
#  'Format_sents/labeled_sent_955101.csv',
#  'Format_sents/form_sent_409495.csv',
#  'Format_sents/form_sent_427503.csv',
#  'Format_sents/form_sent_205471.csv',
#  'Format_sents/labeled_sent_224918.csv',
#  'Format_sents/labeled_sent_244187.csv',
#  'Format_sents/labeled_sent_566379.csv',
#  'Format_sents/labeled_sent_873693.csv',
#  'Format_sents/form_sent_159277.csv',
#  'Format_sents/labeled_sent_145490.csv',
#  'Format_sents/form_sent_693914.csv',
#  'Format_sents/form_sent_775186.csv',
#  'Format_sents/form_sent_1052225.csv',
#  'Format_sents/labeled_sent_339216.csv',
#  'Format_sents/form_sent_69513.csv',
#  'Format_sents/form_sent_455714.csv',
#  'Format_sents/form_sent_1044810.csv',
#  'Format_sents/labeled_sent_839583.csv',
#  'Format_sents/form_sent_500395.csv',
#  'Format_sents/labeled_sent_626818.csv',
#  'Format_sents/form_sent_749112.csv',
#  'Format_sents/form_sent_443730.csv',
#  'Format_sents/form_sent_416387.csv',
#  'Format_sents/labeled_sent_520704.csv',
#  'Format_sents/form_sent_862901.csv',
#  'Format_sents/labeled_sent_495037.csv',
#  'Format_sents/labeled_sent_407401.csv',
#  'Format_sents/labeled_sent_318786.csv',
#  'Format_sents/labeled_sent_582003.csv',
#  'Format_sents/labeled_sent_297595.csv',
#  'Format_sents/form_sent_278288.csv',
#  'Format_sents/form_sent_854872.csv',
#  'Format_sents/form_sent_117323.csv',
#  'Format_sents/labeled_sent_951904.csv',
#  'Format_sents/labeled_sent_831464.csv',
#  'Format_sents/labeled_sent_906979.csv',
#  'Format_sents/form_sent_672348.csv',
#  'Format_sents/form_sent_430489.csv',
#  'Format_sents/form_sent_641141.csv',
#  'Format_sents/labeled_sent_718657.csv',
#  'Format_sents/labeled_sent_918724.csv',
#  'Format_sents/labeled_sent_152340.csv',
#  'Format_sents/labeled_sent_1125914.csv',
#  'Format_sents/form_sent_818314.csv',
#  'Format_sents/form_sent_636949.csv',
#  'Format_sents/labeled_sent_1004618.csv',
#  'Format_sents/labeled_sent_735672.csv',
#  'Format_sents/form_sent_661804.csv',
#  'Format_sents/labeled_sent_762215.csv',
#  'Format_sents/form_sent_100247.csv',
#  'Format_sents/form_sent_274819.csv',
#  'Format_sents/labeled_sent_768084.csv',
#  'Format_sents/labeled_sent_457980.csv',
#  'Format_sents/labeled_sent_265559.csv',
#  'Format_sents/labeled_sent_2228.csv',
#  'Format_sents/form_sent_764577.csv',
#  'Format_sents/labeled_sent_610393.csv',
#  'Format_sents/labeled_sent_340419.csv',
#  'Format_sents/form_sent_105585.csv',
#  'Format_sents/labeled_sent_1050255.csv',
#  'Format_sents/form_sent_146578.csv',
#  'Format_sents/form_sent_537647.csv',
#  'Format_sents/form_sent_558743.csv',
#  'Format_sents/labeled_sent_411588.csv',
#  'Format_sents/form_sent_355465.csv',
#  'Format_sents/labeled_sent_116179.csv',
#  'Format_sents/form_sent_884639.csv',
#  'Format_sents/form_sent_1017255.csv',
#  'Format_sents/labeled_sent_107871.csv',
#  'Format_sents/form_sent_997358.csv',
#  'Format_sents/form_sent_272045.csv',
#  'Format_sents/labeled_sent_863191.csv',
#  'Format_sents/labeled_sent_472571.csv',
#  'Format_sents/labeled_sent_83551.csv',
#  'Format_sents/labeled_sent_167914.csv',
#  'Format_sents/form_sent_594265.csv',
#  'Format_sents/form_sent_17345.csv',
#  'Format_sents/labeled_sent_879083.csv',
#  'Format_sents/labeled_sent_552451.csv',
#  'Format_sents/form_sent_1002818.csv',
#  'Format_sents/form_sent_591436.csv',
#  'Format_sents/labeled_sent_450091.csv',
#  'Format_sents/form_sent_450164.csv',
#  'Format_sents/labeled_sent_273076.csv',
#  'Format_sents/labeled_sent_271451.csv',
#  'Format_sents/labeled_sent_741166.csv',
#  'Format_sents/form_sent_884680.csv',
#  'Format_sents/labeled_sent_1095491.csv',
#  'Format_sents/labeled_sent_72372.csv',
#  'Format_sents/form_sent_480276.csv',
#  'Format_sents/labeled_sent_1124470.csv',
#  'Format_sents/labeled_sent_773459.csv',
#  'Format_sents/form_sent_962318.csv',
#  'Format_sents/labeled_sent_815148.csv',
#  'Format_sents/labeled_sent_1029075.csv',
#  'Format_sents/form_sent_257750.csv',
#  'Format_sents/form_sent_776122.csv',
#  'Format_sents/form_sent_259618.csv',
#  'Format_sents/labeled_sent_1088433.csv',
#  'Format_sents/labeled_sent_116106.csv',
#  'Format_sents/labeled_sent_1017568.csv',
#  'Format_sents/form_sent_20049.csv',
#  'Format_sents/form_sent_810891.csv',
#  'Format_sents/form_sent_453733.csv',
#  'Format_sents/form_sent_609852.csv',
#  'Format_sents/form_sent_784442.csv',
#  'Format_sents/form_sent_714592.csv',
#  'Format_sents/labeled_sent_652798.csv',
#  'Format_sents/form_sent_1045327.csv',
#  'Format_sents/labeled_sent_279777.csv',
#  'Format_sents/form_sent_343121.csv',
#  'Format_sents/labeled_sent_533774.csv',
#  'Format_sents/labeled_sent_168222.csv',
#  'Format_sents/form_sent_638864.csv',
#  'Format_sents/form_sent_403290.csv',
#  'Format_sents/form_sent_863800.csv',
#  'Format_sents/form_sent_1087096.csv',
#  'Format_sents/form_sent_534150.csv',
#  'Format_sents/form_sent_1081569.csv',
#  'Format_sents/labeled_sent_126490.csv',
#  'Format_sents/labeled_sent_531452.csv',
#  'Format_sents/form_sent_355781.csv',
#  'Format_sents/form_sent_82281.csv',
#  'Format_sents/labeled_sent_1000033.csv',
#  'Format_sents/labeled_sent_489997.csv',
#  'Format_sents/labeled_sent_561493.csv',
#  'Format_sents/labeled_sent_332131.csv',
#  'Format_sents/labeled_sent_1087665.csv',
#  'Format_sents/labeled_sent_883232.csv',
#  'Format_sents/labeled_sent_335576.csv',
#  'Format_sents/form_sent_544698.csv',
#  'Format_sents/form_sent_677698.csv',
#  'Format_sents/labeled_sent_320283.csv',
#  'Format_sents/labeled_sent_35411.csv',
#  'Format_sents/labeled_sent_55751.csv',
#  'Format_sents/form_sent_214538.csv',
#  'Format_sents/form_sent_182110.csv',
#  'Format_sents/labeled_sent_396957.csv',
#  'Format_sents/labeled_sent_21754.csv',
#  'Format_sents/form_sent_487739.csv',
#  'Format_sents/form_sent_698474.csv',
#  'Format_sents/labeled_sent_952282.csv',
#  'Format_sents/form_sent_1033035.csv',
#  'Format_sents/form_sent_560761.csv',
#  'Format_sents/form_sent_578988.csv',
#  'Format_sents/labeled_sent_275237.csv',
#  'Format_sents/labeled_sent_387902.csv',
#  'Format_sents/labeled_sent_443954.csv',
#  'Format_sents/form_sent_922232.csv',
#  'Format_sents/labeled_sent_620945.csv',
#  'Format_sents/labeled_sent_59744.csv',
#  'Format_sents/labeled_sent_193845.csv',
#  'Format_sents/labeled_sent_294566.csv',
#  'Format_sents/form_sent_38836.csv',
#  'Format_sents/labeled_sent_808063.csv',
#  'Format_sents/labeled_sent_730389.csv',
#  'Format_sents/labeled_sent_1044796.csv',
#  'Format_sents/labeled_sent_106419.csv',
#  'Format_sents/form_sent_705767.csv',
#  'Format_sents/form_sent_120044.csv',
#  'Format_sents/form_sent_882855.csv',
#  'Format_sents/form_sent_252153.csv',
#  'Format_sents/form_sent_147214.csv',
#  'Format_sents/labeled_sent_1094880.csv',
#  'Format_sents/form_sent_1098528.csv',
#  'Format_sents/labeled_sent_399378.csv',
#  'Format_sents/form_sent_1062387.csv',
#  'Format_sents/form_sent_625354.csv',
#  'Format_sents/labeled_sent_15375.csv',
#  'Format_sents/form_sent_461122.csv',
#  'Format_sents/form_sent_813948.csv',
#  'Format_sents/form_sent_561274.csv',
#  'Format_sents/labeled_sent_254915.csv',
#  'Format_sents/form_sent_26427.csv',
#  'Format_sents/labeled_sent_842610.csv',
#  'Format_sents/labeled_sent_439583.csv',
#  'Format_sents/labeled_sent_50564.csv',
#  'Format_sents/form_sent_732677.csv',
#  'Format_sents/form_sent_588692.csv',
#  'Format_sents/form_sent_1112862.csv',
#  'Format_sents/labeled_sent_668169.csv',
#  'Format_sents/labeled_sent_556117.csv',
#  'Format_sents/labeled_sent_853740.csv',
#  'Format_sents/form_sent_842756.csv',
#  'Format_sents/labeled_sent_1057615.csv',
#  'Format_sents/labeled_sent_132449.csv',
#  'Format_sents/labeled_sent_92111.csv',
#  'Format_sents/form_sent_42423.csv',
#  'Format_sents/labeled_sent_221652.csv',
#  'Format_sents/labeled_sent_49747.csv',
#  'Format_sents/form_sent_1007491.csv',
#  'Format_sents/form_sent_265154.csv',
#  'Format_sents/labeled_sent_1120912.csv',
#  'Format_sents/labeled_sent_186494.csv',
#  'Format_sents/form_sent_173601.csv',
#  'Format_sents/labeled_sent_97704.csv',
#  'Format_sents/labeled_sent_1032063.csv',
#  'Format_sents/form_sent_462444.csv',
#  'Format_sents/form_sent_37234.csv',
#  'Format_sents/labeled_sent_940364.csv',
#  'Format_sents/labeled_sent_99235.csv',
#  'Format_sents/form_sent_383005.csv',
#  'Format_sents/labeled_sent_236398.csv',
#  'Format_sents/labeled_sent_971571.csv',
#  'Format_sents/labeled_sent_318050.csv',
#  'Format_sents/labeled_sent_250335.csv',
#  'Format_sents/labeled_sent_44395.csv',
#  'Format_sents/labeled_sent_147927.csv',
#  'Format_sents/labeled_sent_727083.csv',
#  'Format_sents/labeled_sent_207871.csv',
#  'Format_sents/labeled_sent_786468.csv',
#  'Format_sents/labeled_sent_450765.csv',
#  'Format_sents/form_sent_165862.csv',
#  'Format_sents/labeled_sent_551299.csv',
#  'Format_sents/form_sent_177239.csv',
#  'Format_sents/form_sent_672244.csv',
#  'Format_sents/labeled_sent_645441.csv',
#  'Format_sents/form_sent_888472.csv',
#  'Format_sents/labeled_sent_1059467.csv',
#  'Format_sents/form_sent_40401.csv',
#  'Format_sents/labeled_sent_887151.csv',
#  'Format_sents/form_sent_734310.csv',
#  'Format_sents/labeled_sent_201462.csv',
#  'Format_sents/form_sent_904395.csv',
#  'Format_sents/form_sent_746351.csv',
#  'Format_sents/form_sent_660387.csv',
#  'Format_sents/labeled_sent_735616.csv',
#  'Format_sents/labeled_sent_400047.csv',
#  'Format_sents/form_sent_1014446.csv',
#  'Format_sents/form_sent_825798.csv',
#  'Format_sents/form_sent_431667.csv',
#  'Format_sents/labeled_sent_348876.csv',
#  'Format_sents/form_sent_790090.csv',
#  'Format_sents/form_sent_851191.csv',
#  'Format_sents/labeled_sent_1029060.csv',
#  'Format_sents/form_sent_679070.csv',
#  'Format_sents/labeled_sent_234604.csv',
#  'Format_sents/labeled_sent_116820.csv',
#  'Format_sents/labeled_sent_584817.csv',
#  'Format_sents/labeled_sent_118152.csv',
#  'Format_sents/labeled_sent_493640.csv',
#  'Format_sents/labeled_sent_625031.csv',
#  'Format_sents/labeled_sent_155101.csv',
#  'Format_sents/labeled_sent_594665.csv',
#  'Format_sents/form_sent_998953.csv',
#  'Format_sents/form_sent_1079423.csv',
#  'Format_sents/labeled_sent_709304.csv',
#  'Format_sents/labeled_sent_585299.csv',
#  'Format_sents/form_sent_1091864.csv',
#  'Format_sents/form_sent_620694.csv',
#  'Format_sents/form_sent_852554.csv',
#  'Format_sents/labeled_sent_725374.csv',
#  'Format_sents/labeled_sent_570323.csv',
#  'Format_sents/labeled_sent_958775.csv',
#  'Format_sents/form_sent_350957.csv',
#  'Format_sents/labeled_sent_831144.csv',
#  'Format_sents/form_sent_74414.csv',
#  'Format_sents/labeled_sent_633647.csv',
#  'Format_sents/labeled_sent_625188.csv',
#  'Format_sents/form_sent_1099782.csv',
#  'Format_sents/form_sent_1117995.csv',
#  'Format_sents/labeled_sent_422510.csv',
#  'Format_sents/form_sent_600981.csv',
#  'Format_sents/labeled_sent_415447.csv',
#  'Format_sents/form_sent_3649.csv',
#  'Format_sents/form_sent_709902.csv',
#  'Format_sents/labeled_sent_180250.csv',
#  'Format_sents/form_sent_1101298.csv',
#  'Format_sents/form_sent_546899.csv',
#  'Format_sents/labeled_sent_885559.csv',
#  'Format_sents/labeled_sent_1102867.csv',
#  'Format_sents/form_sent_277151.csv',
#  'Format_sents/form_sent_234030.csv',
#  'Format_sents/form_sent_953747.csv',
#  'Format_sents/form_sent_983407.csv',
#  'Format_sents/form_sent_425105.csv',
#  'Format_sents/labeled_sent_617751.csv',
#  'Format_sents/form_sent_32496.csv',
#  'Format_sents/labeled_sent_1089056.csv',
#  'Format_sents/labeled_sent_108493.csv',
#  'Format_sents/labeled_sent_285007.csv',
#  'Format_sents/form_sent_1069242.csv',
#  'Format_sents/labeled_sent_168219.csv',
#  'Format_sents/form_sent_227891.csv',
#  'Format_sents/labeled_sent_919636.csv',
#  'Format_sents/labeled_sent_837380.csv',
#  'Format_sents/labeled_sent_255426.csv',
#  'Format_sents/labeled_sent_1030564.csv',
#  'Format_sents/form_sent_6907.csv',
#  'Format_sents/labeled_sent_173044.csv',
#  'Format_sents/form_sent_192623.csv',
#  'Format_sents/form_sent_683407.csv',
#  'Format_sents/labeled_sent_477850.csv',
#  'Format_sents/labeled_sent_416469.csv',
#  'Format_sents/labeled_sent_200409.csv',
#  'Format_sents/form_sent_647658.csv',
#  'Format_sents/form_sent_654392.csv',
#  'Format_sents/labeled_sent_863246.csv',
#  'Format_sents/form_sent_757730.csv',
#  'Format_sents/labeled_sent_279011.csv',
#  'Format_sents/labeled_sent_998663.csv',
#  'Format_sents/form_sent_1071308.csv',
#  'Format_sents/labeled_sent_836081.csv',
#  'Format_sents/form_sent_570104.csv',
#  'Format_sents/form_sent_92039.csv',
#  'Format_sents/form_sent_225770.csv',
#  'Format_sents/labeled_sent_1084205.csv',
#  'Format_sents/labeled_sent_901370.csv',
#  'Format_sents/labeled_sent_871176.csv',
#  'Format_sents/labeled_sent_145654.csv',
#  'Format_sents/form_sent_437059.csv',
#  'Format_sents/form_sent_176070.csv',
#  'Format_sents/form_sent_977623.csv',
#  'Format_sents/labeled_sent_647914.csv',
#  'Format_sents/labeled_sent_414283.csv',
#  'Format_sents/labeled_sent_1071992.csv',
#  'Format_sents/labeled_sent_615172.csv',
#  'Format_sents/form_sent_1112335.csv',
#  'Format_sents/form_sent_1122486.csv',
#  'Format_sents/form_sent_29770.csv',
#  'Format_sents/form_sent_1890.csv',
#  'Format_sents/form_sent_218704.csv',
#  'Format_sents/labeled_sent_1418.csv',
#  'Format_sents/form_sent_18354.csv',
#  'Format_sents/labeled_sent_239124.csv',
#  'Format_sents/form_sent_195472.csv',
#  'Format_sents/labeled_sent_460615.csv',
#  'Format_sents/form_sent_811655.csv',
#  'Format_sents/labeled_sent_497445.csv',
#  'Format_sents/form_sent_1002215.csv',
#  'Format_sents/form_sent_378618.csv',
#  'Format_sents/form_sent_414996.csv',
#  'Format_sents/labeled_sent_1007961.csv',
#  'Format_sents/labeled_sent_1000179.csv',
#  'Format_sents/form_sent_221193.csv',
#  'Format_sents/form_sent_638528.csv',
#  'Format_sents/labeled_sent_838331.csv',
#  'Format_sents/form_sent_1003752.csv',
#  'Format_sents/labeled_sent_1109613.csv',
#  'Format_sents/labeled_sent_304612.csv',
#  'Format_sents/labeled_sent_295761.csv',
#  'Format_sents/labeled_sent_137297.csv',
#  'Format_sents/form_sent_818590.csv',
#  'Format_sents/labeled_sent_70874.csv',
#  'Format_sents/labeled_sent_499885.csv',
#  'Format_sents/form_sent_362967.csv',
#  'Format_sents/labeled_sent_479819.csv',
#  'Format_sents/labeled_sent_945568.csv',
#  'Format_sents/form_sent_1002819.csv',
#  'Format_sents/labeled_sent_862963.csv',
#  'Format_sents/labeled_sent_458677.csv',
#  'Format_sents/form_sent_669860.csv',
#  'Format_sents/form_sent_681889.csv',
#  'Format_sents/form_sent_1099308.csv',
#  'Format_sents/form_sent_864804.csv',
#  'Format_sents/labeled_sent_992512.csv',
#  'Format_sents/labeled_sent_1019482.csv',
#  'Format_sents/labeled_sent_883980.csv',
#  'Format_sents/form_sent_425637.csv',
#  'Format_sents/labeled_sent_474472.csv',
#  'Format_sents/labeled_sent_174439.csv',
#  'Format_sents/labeled_sent_240949.csv',
#  'Format_sents/form_sent_913525.csv',
#  'Format_sents/labeled_sent_105140.csv',
#  'Format_sents/labeled_sent_171241.csv',
#  'Format_sents/form_sent_1064145.csv',
#  'Format_sents/form_sent_174394.csv',
#  'Format_sents/labeled_sent_1013980.csv',
#  'Format_sents/labeled_sent_296872.csv',
#  'Format_sents/labeled_sent_425430.csv',
#  'Format_sents/labeled_sent_846625.csv',
#  'Format_sents/form_sent_494327.csv',
#  'Format_sents/labeled_sent_114924.csv',
#  'Format_sents/form_sent_818060.csv',
#  'Format_sents/form_sent_785934.csv',
#  'Format_sents/labeled_sent_649048.csv',
#  'Format_sents/form_sent_426902.csv',
#  'Format_sents/form_sent_1014243.csv',
#  'Format_sents/labeled_sent_10591.csv',
#  'Format_sents/form_sent_394753.csv',
#  'Format_sents/form_sent_1005041.csv',
#  'Format_sents/labeled_sent_344705.csv',
#  'Format_sents/form_sent_524107.csv',
#  'Format_sents/labeled_sent_984845.csv',
#  'Format_sents/labeled_sent_317578.csv',
#  'Format_sents/labeled_sent_712547.csv',
#  'Format_sents/labeled_sent_850757.csv',
#  'Format_sents/labeled_sent_1018607.csv',
#  'Format_sents/labeled_sent_37975.csv',
#  'Format_sents/form_sent_584708.csv',
#  'Format_sents/labeled_sent_774462.csv',
#  'Format_sents/form_sent_1047116.csv',
#  'Format_sents/labeled_sent_785130.csv',
#  'Format_sents/labeled_sent_80368.csv',
#  'Format_sents/form_sent_682369.csv',
#  'Format_sents/form_sent_835025.csv',
#  'Format_sents/form_sent_467614.csv',
#  'Format_sents/labeled_sent_1017404.csv',
#  'Format_sents/labeled_sent_1060169.csv',
#  'Format_sents/labeled_sent_1014884.csv',
#  'Format_sents/form_sent_685473.csv',
#  'Format_sents/form_sent_382807.csv',
#  'Format_sents/form_sent_612104.csv',
#  'Format_sents/labeled_sent_618152.csv',
#  'Format_sents/form_sent_390658.csv',
#  'Format_sents/labeled_sent_262467.csv',
#  'Format_sents/form_sent_939614.csv',
#  'Format_sents/form_sent_166955.csv',
#  'Format_sents/form_sent_825580.csv',
#  'Format_sents/labeled_sent_687858.csv',
#  'Format_sents/labeled_sent_940045.csv',
#  'Format_sents/form_sent_385005.csv',
#  'Format_sents/labeled_sent_573097.csv',
#  'Format_sents/labeled_sent_441982.csv',
#  'Format_sents/form_sent_360371.csv',
#  'Format_sents/form_sent_15227.csv',
#  'Format_sents/labeled_sent_919079.csv',
#  'Format_sents/form_sent_798840.csv',
#  'Format_sents/form_sent_919717.csv',
#  'Format_sents/form_sent_38808.csv',
#  'Format_sents/labeled_sent_83693.csv',
#  'Format_sents/form_sent_399021.csv',
#  'Format_sents/labeled_sent_629674.csv',
#  'Format_sents/labeled_sent_500780.csv',
#  'Format_sents/form_sent_117610.csv',
#  'Format_sents/labeled_sent_852836.csv',
#  'Format_sents/labeled_sent_813816.csv',
#  'Format_sents/form_sent_1021642.csv',
#  'Format_sents/labeled_sent_866874.csv',
#  'Format_sents/labeled_sent_624127.csv',
#  'Format_sents/form_sent_1071852.csv',
#  'Format_sents/labeled_sent_1039933.csv',
#  'Format_sents/labeled_sent_1058854.csv',
#  'Format_sents/form_sent_402041.csv',
#  'Format_sents/form_sent_854483.csv',
#  'Format_sents/form_sent_802567.csv',
#  'Format_sents/form_sent_760012.csv',
#  'Format_sents/form_sent_928162.csv',
#  'Format_sents/form_sent_469013.csv',
#  'Format_sents/form_sent_18147.csv',
#  'Format_sents/form_sent_137176.csv',
#  'Format_sents/labeled_sent_501127.csv',
#  'Format_sents/labeled_sent_1002698.csv',
#  'Format_sents/form_sent_179717.csv',
#  'Format_sents/form_sent_58394.csv',
#  'Format_sents/labeled_sent_165995.csv',
#  'Format_sents/labeled_sent_624638.csv',
#  'Format_sents/labeled_sent_848628.csv',
#  'Format_sents/labeled_sent_562803.csv',
#  'Format_sents/labeled_sent_332855.csv',
#  'Format_sents/form_sent_981187.csv',
#  'Format_sents/labeled_sent_296339.csv',
#  'Format_sents/form_sent_871023.csv',
#  'Format_sents/form_sent_446997.csv',
#  'Format_sents/form_sent_624819.csv',
#  'Format_sents/form_sent_482453.csv',
#  'Format_sents/form_sent_435446.csv',
#  'Format_sents/labeled_sent_49914.csv',
#  'Format_sents/form_sent_675827.csv',
#  'Format_sents/form_sent_41752.csv',
#  'Format_sents/form_sent_509889.csv',
#  'Format_sents/form_sent_363676.csv',
#  'Format_sents/labeled_sent_856139.csv',
#  'Format_sents/form_sent_853850.csv',
#  'Format_sents/form_sent_500523.csv',
#  'Format_sents/labeled_sent_992133.csv',
#  'Format_sents/labeled_sent_280705.csv',
#  'Format_sents/labeled_sent_314010.csv',
#  'Format_sents/labeled_sent_596584.csv',
#  'Format_sents/labeled_sent_512586.csv',
#  'Format_sents/labeled_sent_669409.csv',
#  'Format_sents/form_sent_1085825.csv',
#  'Format_sents/form_sent_842861.csv',
#  'Format_sents/labeled_sent_67376.csv',
#  'Format_sents/labeled_sent_675561.csv',
#  'Format_sents/form_sent_863727.csv',
#  'Format_sents/labeled_sent_434995.csv',
#  'Format_sents/labeled_sent_59236.csv',
#  'Format_sents/form_sent_69722.csv',
#  'Format_sents/labeled_sent_37423.csv',
#  'Format_sents/form_sent_479763.csv',
#  'Format_sents/form_sent_305875.csv',
#  'Format_sents/form_sent_879249.csv',
#  'Format_sents/form_sent_622507.csv',
#  'Format_sents/form_sent_18084.csv',
#  'Format_sents/form_sent_939269.csv',
#  'Format_sents/form_sent_692594.csv',
#  'Format_sents/form_sent_1541.csv',
#  'Format_sents/form_sent_102669.csv',
#  'Format_sents/labeled_sent_980812.csv',
#  'Format_sents/form_sent_838218.csv',
#  'Format_sents/form_sent_921549.csv',
#  'Format_sents/form_sent_1117123.csv',
#  'Format_sents/labeled_sent_216481.csv',
#  'Format_sents/form_sent_767180.csv',
#  'Format_sents/labeled_sent_309225.csv',
#  'Format_sents/labeled_sent_766275.csv',
#  'Format_sents/labeled_sent_41342.csv',
#  'Format_sents/form_sent_879582.csv',
#  'Format_sents/labeled_sent_166879.csv',
#  'Format_sents/form_sent_913999.csv',
#  'Format_sents/labeled_sent_775803.csv',
#  'Format_sents/form_sent_358161.csv',
#  'Format_sents/labeled_sent_740740.csv',
#  'Format_sents/form_sent_310619.csv',
#  'Format_sents/form_sent_595073.csv',
#  'Format_sents/form_sent_983061.csv',
#  'Format_sents/form_sent_88191.csv',
#  'Format_sents/labeled_sent_115623.csv',
#  'Format_sents/labeled_sent_1086173.csv',
#  'Format_sents/form_sent_910493.csv',
#  'Format_sents/form_sent_628749.csv',
#  'Format_sents/labeled_sent_56964.csv',
#  'Format_sents/labeled_sent_329191.csv',
#  'Format_sents/labeled_sent_131791.csv',
#  'Format_sents/labeled_sent_577086.csv',
#  'Format_sents/labeled_sent_794903.csv',
#  'Format_sents/form_sent_286556.csv',
#  'Format_sents/form_sent_166358.csv',
#  'Format_sents/labeled_sent_50042.csv',
#  'Format_sents/labeled_sent_773469.csv',
#  'Format_sents/form_sent_342047.csv',
#  'Format_sents/labeled_sent_302357.csv',
#  'Format_sents/labeled_sent_816619.csv',
#  'Format_sents/form_sent_283286.csv',
#  'Format_sents/form_sent_1042064.csv',
#  'Format_sents/labeled_sent_1012581.csv',
#  'Format_sents/labeled_sent_793117.csv',
#  'Format_sents/labeled_sent_361511.csv',
#  'Format_sents/labeled_sent_376793.csv',
#  'Format_sents/form_sent_82075.csv',
#  'Format_sents/labeled_sent_957558.csv',
#  'Format_sents/labeled_sent_1095908.csv',
#  'Format_sents/labeled_sent_345496.csv',
#  'Format_sents/form_sent_230381.csv',
#  'Format_sents/form_sent_72238.csv',
#  'Format_sents/form_sent_90665.csv',
#  'Format_sents/labeled_sent_466779.csv',
#  'Format_sents/labeled_sent_827061.csv',
#  'Format_sents/labeled_sent_769861.csv',
#  'Format_sents/form_sent_590487.csv',
#  'Format_sents/labeled_sent_13350.csv',
#  'Format_sents/form_sent_281730.csv',
#  'Format_sents/labeled_sent_631891.csv',
#  'Format_sents/labeled_sent_55319.csv',
#  'Format_sents/labeled_sent_199785.csv',
#  'Format_sents/labeled_sent_392708.csv',
#  'Format_sents/labeled_sent_185032.csv',
#  'Format_sents/form_sent_753776.csv',
#  'Format_sents/labeled_sent_548525.csv',
#  'Format_sents/form_sent_36799.csv',
#  'Format_sents/form_sent_262298.csv',
#  'Format_sents/labeled_sent_630065.csv',
#  'Format_sents/labeled_sent_1082301.csv',
#  'Format_sents/labeled_sent_633117.csv',
#  'Format_sents/form_sent_62867.csv',
#  'Format_sents/labeled_sent_69579.csv',
#  'Format_sents/labeled_sent_728518.csv',
#  'Format_sents/form_sent_809821.csv',
#  'Format_sents/form_sent_753662.csv',
#  'Format_sents/form_sent_748895.csv',
#  'Format_sents/labeled_sent_268566.csv',
#  'Format_sents/form_sent_1107671.csv',
#  'Format_sents/form_sent_603874.csv',
#  'Format_sents/labeled_sent_796449.csv',
#  'Format_sents/form_sent_813302.csv',
#  'Format_sents/form_sent_635410.csv',
#  'Format_sents/form_sent_103558.csv',
#  'Format_sents/form_sent_547639.csv',
#  'Format_sents/labeled_sent_320897.csv',
#  'Format_sents/labeled_sent_927623.csv',
#  'Format_sents/labeled_sent_242187.csv',
#  'Format_sents/labeled_sent_246154.csv',
#  'Format_sents/labeled_sent_231325.csv',
#  'Format_sents/labeled_sent_396196.csv',
#  'Format_sents/labeled_sent_1034475.csv',
#  'Format_sents/labeled_sent_139911.csv',
#  'Format_sents/form_sent_92270.csv',
#  'Format_sents/form_sent_614728.csv',
#  'Format_sents/labeled_sent_710467.csv',
#  'Format_sents/labeled_sent_598230.csv',
#  'Format_sents/labeled_sent_361657.csv',
#  'Format_sents/labeled_sent_143965.csv',
#  'Format_sents/form_sent_202837.csv',
#  'Format_sents/form_sent_243475.csv',
#  'Format_sents/form_sent_748268.csv',
#  'Format_sents/form_sent_564557.csv',
#  'Format_sents/labeled_sent_176479.csv',
#  'Format_sents/form_sent_142287.csv',
#  'Format_sents/form_sent_487524.csv',
#  'Format_sents/form_sent_459398.csv',
#  'Format_sents/labeled_sent_188148.csv',
#  'Format_sents/form_sent_1071562.csv',
#  'Format_sents/labeled_sent_781298.csv',
#  'Format_sents/labeled_sent_641992.csv',
#  'Format_sents/form_sent_114078.csv',
#  'Format_sents/labeled_sent_954756.csv',
#  'Format_sents/labeled_sent_49998.csv',
#  'Format_sents/form_sent_520735.csv',
#  'Format_sents/form_sent_1037891.csv',
#  'Format_sents/form_sent_405944.csv',
#  'Format_sents/form_sent_323968.csv',
#  'Format_sents/labeled_sent_1051372.csv',
#  'Format_sents/labeled_sent_995381.csv',
#  'Format_sents/labeled_sent_305593.csv',
#  'Format_sents/labeled_sent_1024886.csv',
#  'Format_sents/labeled_sent_443753.csv',
#  'Format_sents/form_sent_838303.csv',
#  'Format_sents/form_sent_426455.csv',
#  'Format_sents/labeled_sent_696801.csv',
#  'Format_sents/labeled_sent_535673.csv',
#  'Format_sents/form_sent_456328.csv',
#  'Format_sents/labeled_sent_581968.csv',
#  'Format_sents/form_sent_713768.csv',
#  'Format_sents/labeled_sent_934357.csv',
#  'Format_sents/form_sent_354799.csv',
#  'Format_sents/form_sent_764167.csv',
#  'Format_sents/form_sent_443576.csv',
#  'Format_sents/form_sent_120085.csv',
#  'Format_sents/labeled_sent_301498.csv',
#  'Format_sents/labeled_sent_1037455.csv',
#  'Format_sents/form_sent_856665.csv',
#  'Format_sents/labeled_sent_803573.csv',
#  'Format_sents/form_sent_268910.csv',
#  'Format_sents/form_sent_296435.csv',
#  'Format_sents/form_sent_408933.csv',
#  'Format_sents/labeled_sent_995783.csv',
#  'Format_sents/labeled_sent_363992.csv',
#  'Format_sents/labeled_sent_4355.csv',
#  'Format_sents/form_sent_657849.csv',
#  'Format_sents/labeled_sent_540968.csv',
#  'Format_sents/form_sent_643705.csv',
#  'Format_sents/labeled_sent_75499.csv',
#  'Format_sents/form_sent_126144.csv',
#  'Format_sents/labeled_sent_553442.csv',
#  'Format_sents/labeled_sent_817185.csv',
#  'Format_sents/form_sent_725339.csv',
#  'Format_sents/labeled_sent_788280.csv',
#  'Format_sents/labeled_sent_959220.csv',
#  'Format_sents/labeled_sent_1107701.csv',
#  'Format_sents/form_sent_738340.csv',
#  'Format_sents/labeled_sent_689123.csv',
#  'Format_sents/labeled_sent_430614.csv',
#  'Format_sents/labeled_sent_892566.csv',
#  'Format_sents/labeled_sent_201711.csv',
#  'Format_sents/labeled_sent_419057.csv',
#  'Format_sents/form_sent_285847.csv',
#  'Format_sents/form_sent_731127.csv',
#  'Format_sents/labeled_sent_707546.csv',
#  'Format_sents/form_sent_1091721.csv',
#  'Format_sents/labeled_sent_91158.csv',
#  'Format_sents/form_sent_881119.csv',
#  'Format_sents/labeled_sent_422329.csv',
#  'Format_sents/form_sent_808579.csv',
#  'Format_sents/labeled_sent_803919.csv',
#  'Format_sents/labeled_sent_592206.csv',
#  'Format_sents/labeled_sent_337439.csv',
#  'Format_sents/form_sent_671463.csv',
#  'Format_sents/form_sent_405311.csv',
#  'Format_sents/labeled_sent_152015.csv',
#  'Format_sents/form_sent_1102107.csv',
#  'Format_sents/labeled_sent_390448.csv',
#  'Format_sents/form_sent_214753.csv',
#  'Format_sents/form_sent_217813.csv',
#  'Format_sents/labeled_sent_616546.csv',
#  'Format_sents/labeled_sent_535979.csv',
#  'Format_sents/labeled_sent_88904.csv',
#  'Format_sents/labeled_sent_152039.csv',
#  'Format_sents/labeled_sent_353230.csv',
#  'Format_sents/labeled_sent_124541.csv',
#  'Format_sents/form_sent_438990.csv',
#  'Format_sents/form_sent_6036.csv',
#  'Format_sents/labeled_sent_748507.csv',
#  'Format_sents/labeled_sent_575077.csv',
#  'Format_sents/form_sent_119248.csv',
#  'Format_sents/form_sent_857763.csv',
#  'Format_sents/labeled_sent_397256.csv',
#  'Format_sents/form_sent_256589.csv',
#  'Format_sents/form_sent_598248.csv',
#  'Format_sents/form_sent_574373.csv',
#  'Format_sents/form_sent_247307.csv',
#  'Format_sents/form_sent_671177.csv',
#  'Format_sents/labeled_sent_1020593.csv',
#  'Format_sents/labeled_sent_923714.csv',
#  'Format_sents/labeled_sent_10000.csv',
#  'Format_sents/form_sent_426775.csv',
#  'Format_sents/labeled_sent_479012.csv',
#  'Format_sents/form_sent_348559.csv',
#  'Format_sents/labeled_sent_895783.csv',
#  'Format_sents/form_sent_880706.csv',
#  'Format_sents/form_sent_784685.csv',
#  'Format_sents/labeled_sent_362035.csv',
#  'Format_sents/labeled_sent_670410.csv',
#  'Format_sents/labeled_sent_525205.csv',
#  'Format_sents/form_sent_349866.csv',
#  'Format_sents/form_sent_22661.csv',
#  'Format_sents/labeled_sent_1029822.csv',
#  'Format_sents/form_sent_356886.csv',
#  'Format_sents/labeled_sent_798481.csv',
#  'Format_sents/form_sent_1030527.csv',
#  'Format_sents/form_sent_282135.csv',
#  'Format_sents/form_sent_261094.csv',
#  'Format_sents/form_sent_354394.csv',
#  'Format_sents/form_sent_928704.csv',
#  'Format_sents/form_sent_779957.csv',
#  'Format_sents/form_sent_849192.csv',
#  'Format_sents/form_sent_1056330.csv',
#  'Format_sents/labeled_sent_1024369.csv',
#  'Format_sents/form_sent_966124.csv',
#  'Format_sents/form_sent_273018.csv',
#  'Format_sents/labeled_sent_1067581.csv',
#  'Format_sents/form_sent_558981.csv',
#  'Format_sents/form_sent_486370.csv',
#  'Format_sents/form_sent_888874.csv',
#  'Format_sents/labeled_sent_482863.csv',
#  'Format_sents/labeled_sent_512413.csv',
#  'Format_sents/labeled_sent_919780.csv',
#  'Format_sents/labeled_sent_201799.csv',
#  'Format_sents/labeled_sent_204239.csv',
#  'Format_sents/labeled_sent_615406.csv',
#  'Format_sents/labeled_sent_1092593.csv',
#  'Format_sents/form_sent_405910.csv',
#  'Format_sents/form_sent_670944.csv',
#  'Format_sents/labeled_sent_648845.csv',
#  'Format_sents/labeled_sent_1013016.csv',
#  'Format_sents/form_sent_1011660.csv',
#  'Format_sents/labeled_sent_668875.csv',
#  'Format_sents/labeled_sent_599822.csv',
#  'Format_sents/form_sent_490490.csv',
#  'Format_sents/labeled_sent_1088445.csv',
#  'Format_sents/form_sent_1033756.csv',
#  'Format_sents/labeled_sent_230334.csv',
#  'Format_sents/labeled_sent_212261.csv',
#  'Format_sents/labeled_sent_515268.csv',
#  'Format_sents/form_sent_455131.csv',
#  'Format_sents/form_sent_1104996.csv',
#  'Format_sents/labeled_sent_692164.csv',
#  'Format_sents/labeled_sent_669208.csv',
#  'Format_sents/labeled_sent_259500.csv',
#  'Format_sents/labeled_sent_73829.csv',
#  'Format_sents/form_sent_323157.csv',
#  'Format_sents/form_sent_629907.csv',
#  'Format_sents/form_sent_427078.csv',
#  'Format_sents/labeled_sent_440022.csv',
#  'Format_sents/form_sent_855009.csv',
#  'Format_sents/labeled_sent_733953.csv',
#  'Format_sents/labeled_sent_678216.csv',
#  'Format_sents/form_sent_951392.csv',
#  'Format_sents/form_sent_400031.csv',
#  'Format_sents/labeled_sent_325356.csv',
#  'Format_sents/labeled_sent_656610.csv',
#  'Format_sents/form_sent_139235.csv',
#  'Format_sents/labeled_sent_533598.csv',
#  'Format_sents/form_sent_560165.csv',
#  'Format_sents/form_sent_249180.csv',
#  'Format_sents/labeled_sent_413784.csv',
#  'Format_sents/form_sent_150126.csv',
#  'Format_sents/form_sent_992067.csv',
#  'Format_sents/labeled_sent_300297.csv',
#  'Format_sents/labeled_sent_1081360.csv',
#  'Format_sents/labeled_sent_636466.csv',
#  'Format_sents/form_sent_881716.csv',
#  'Format_sents/labeled_sent_604769.csv',
#  'Format_sents/labeled_sent_320328.csv',
#  'Format_sents/labeled_sent_465291.csv',
#  'Format_sents/form_sent_769601.csv',
#  'Format_sents/labeled_sent_1015711.csv',
#  'Format_sents/labeled_sent_1100993.csv',
#  'Format_sents/labeled_sent_323954.csv',
#  'Format_sents/form_sent_886070.csv',
#  'Format_sents/labeled_sent_326371.csv',
#  'Format_sents/labeled_sent_1012898.csv',
#  'Format_sents/form_sent_897900.csv',
#  'Format_sents/labeled_sent_144868.csv',
#  'Format_sents/form_sent_889589.csv',
#  'Format_sents/form_sent_141068.csv',
#  'Format_sents/labeled_sent_365711.csv',
#  'Format_sents/form_sent_128412.csv',
#  'Format_sents/labeled_sent_664216.csv',
#  'Format_sents/labeled_sent_976060.csv',
#  'Format_sents/form_sent_391424.csv',
#  'Format_sents/labeled_sent_281825.csv',
#  'Format_sents/form_sent_583520.csv',
#  'Format_sents/form_sent_873711.csv',
#  'Format_sents/form_sent_575174.csv',
#  'Format_sents/form_sent_764440.csv',
#  'Format_sents/labeled_sent_906346.csv',
#  'Format_sents/form_sent_1095697.csv',
#  'Format_sents/labeled_sent_545429.csv',
#  'Format_sents/labeled_sent_319307.csv',
#  'Format_sents/labeled_sent_672476.csv',
#  'Format_sents/labeled_sent_1030411.csv',
#  'Format_sents/labeled_sent_865112.csv',
#  'Format_sents/labeled_sent_501227.csv',
#  'Format_sents/form_sent_66779.csv',
#  'Format_sents/form_sent_1101912.csv',
#  'Format_sents/form_sent_1096374.csv',
#  'Format_sents/form_sent_78478.csv',
#  'Format_sents/labeled_sent_702268.csv',
#  'Format_sents/labeled_sent_454301.csv',
#  'Format_sents/labeled_sent_201625.csv',
#  'Format_sents/form_sent_1039907.csv',
#  'Format_sents/form_sent_367628.csv',
#  'Format_sents/form_sent_901688.csv',
#  'Format_sents/labeled_sent_296556.csv',
#  'Format_sents/labeled_sent_313878.csv',
#  'Format_sents/form_sent_62765.csv',
#  'Format_sents/labeled_sent_29878.csv',
#  'Format_sents/labeled_sent_460347.csv',
#  'Format_sents/form_sent_619500.csv',
#  'Format_sents/form_sent_957595.csv',
#  'Format_sents/labeled_sent_732482.csv',
#  'Format_sents/form_sent_489998.csv',
#  'Format_sents/form_sent_315917.csv',
#  'Format_sents/form_sent_35771.csv',
#  'Format_sents/form_sent_1122979.csv',
#  'Format_sents/labeled_sent_999917.csv',
#  'Format_sents/form_sent_161332.csv',
#  'Format_sents/labeled_sent_172029.csv',
#  'Format_sents/form_sent_999409.csv',
#  'Format_sents/labeled_sent_327720.csv',
#  'Format_sents/labeled_sent_759702.csv',
#  'Format_sents/form_sent_174914.csv',
#  'Format_sents/form_sent_989006.csv',
#  'Format_sents/form_sent_864650.csv',
#  'Format_sents/labeled_sent_45256.csv',
#  'Format_sents/form_sent_98893.csv',
#  'Format_sents/labeled_sent_49824.csv',
#  'Format_sents/form_sent_751218.csv',
#  'Format_sents/form_sent_281684.csv',
#  'Format_sents/form_sent_383182.csv',
#  'Format_sents/form_sent_651983.csv',
#  'Format_sents/labeled_sent_683176.csv',
#  'Format_sents/labeled_sent_260899.csv',
#  'Format_sents/labeled_sent_734151.csv',
#  'Format_sents/form_sent_282042.csv',
#  'Format_sents/labeled_sent_142386.csv',
#  'Format_sents/labeled_sent_669442.csv',
#  'Format_sents/labeled_sent_1076518.csv',
#  'Format_sents/form_sent_903224.csv',
#  'Format_sents/labeled_sent_38516.csv',
#  'Format_sents/form_sent_488793.csv',
#  'Format_sents/form_sent_609353.csv',
#  'Format_sents/form_sent_74394.csv',
#  'Format_sents/labeled_sent_557992.csv',
#  'Format_sents/labeled_sent_134260.csv',
#  'Format_sents/form_sent_254988.csv',
#  'Format_sents/form_sent_27925.csv',
#  'Format_sents/labeled_sent_54170.csv',
#  'Format_sents/labeled_sent_584016.csv',
#  'Format_sents/form_sent_927308.csv',
#  'Format_sents/labeled_sent_927154.csv',
#  'Format_sents/labeled_sent_159622.csv',
#  'Format_sents/form_sent_505140.csv',
#  'Format_sents/form_sent_43633.csv',
#  'Format_sents/form_sent_116110.csv',
#  'Format_sents/form_sent_498290.csv',
#  'Format_sents/labeled_sent_333437.csv',
#  'Format_sents/labeled_sent_883051.csv',
#  'Format_sents/form_sent_838533.csv',
#  'Format_sents/form_sent_880513.csv',
#  'Format_sents/form_sent_459236.csv',
#  'Format_sents/labeled_sent_525837.csv',
#  'Format_sents/labeled_sent_185573.csv',
#  'Format_sents/form_sent_800804.csv',
#  'Format_sents/labeled_sent_205110.csv',
#  'Format_sents/labeled_sent_586138.csv',
#  'Format_sents/form_sent_1044779.csv',
#  'Format_sents/form_sent_18940.csv',
#  'Format_sents/form_sent_587386.csv',
#  'Format_sents/form_sent_591391.csv',
#  'Format_sents/form_sent_110602.csv',
#  'Format_sents/form_sent_1019666.csv',
#  'Format_sents/form_sent_11526.csv',
#  'Format_sents/form_sent_815570.csv',
#  'Format_sents/labeled_sent_166877.csv',
#  'Format_sents/form_sent_992272.csv',
#  'Format_sents/form_sent_1055149.csv',
#  'Format_sents/form_sent_945312.csv',
#  'Format_sents/labeled_sent_905077.csv',
#  'Format_sents/form_sent_791806.csv',
#  'Format_sents/labeled_sent_96918.csv',
#  'Format_sents/form_sent_6114.csv',
#  'Format_sents/form_sent_560191.csv',
#  'Format_sents/form_sent_964738.csv',
#  'Format_sents/form_sent_386401.csv',
#  'Format_sents/labeled_sent_702572.csv',
#  'Format_sents/labeled_sent_584338.csv',
#  'Format_sents/labeled_sent_687281.csv',
#  'Format_sents/labeled_sent_1096143.csv',
#  'Format_sents/labeled_sent_772346.csv',
#  'Format_sents/form_sent_911786.csv',
#  'Format_sents/labeled_sent_267214.csv',
#  'Format_sents/form_sent_507612.csv',
#  'Format_sents/labeled_sent_726689.csv',
#  'Format_sents/form_sent_797081.csv',
#  'Format_sents/labeled_sent_716684.csv',
#  'Format_sents/labeled_sent_711227.csv',
#  'Format_sents/labeled_sent_416723.csv',
#  'Format_sents/labeled_sent_989332.csv',
#  'Format_sents/form_sent_683229.csv',
#  'Format_sents/form_sent_603155.csv',
#  'Format_sents/form_sent_535756.csv',
#  'Format_sents/form_sent_156185.csv',
#  'Format_sents/form_sent_715186.csv',
#  'Format_sents/labeled_sent_1124815.csv',
#  'Format_sents/labeled_sent_477256.csv',
#  'Format_sents/form_sent_652718.csv',
#  'Format_sents/form_sent_109199.csv',
#  'Format_sents/labeled_sent_732134.csv',
#  'Format_sents/labeled_sent_505629.csv',
#  'Format_sents/labeled_sent_16301.csv',
#  'Format_sents/labeled_sent_681548.csv',
#  'Format_sents/form_sent_543665.csv',
#  'Format_sents/form_sent_784883.csv',
#  'Format_sents/labeled_sent_158856.csv',
#  'Format_sents/form_sent_346595.csv',
#  'Format_sents/form_sent_615792.csv',
#  'Format_sents/labeled_sent_741878.csv',
#  'Format_sents/form_sent_642192.csv',
#  'Format_sents/labeled_sent_568858.csv',
#  'Format_sents/labeled_sent_127357.csv',
#  'Format_sents/labeled_sent_841967.csv',
#  'Format_sents/labeled_sent_593611.csv',
#  'Format_sents/labeled_sent_573975.csv',
#  'Format_sents/form_sent_209959.csv',
#  'Format_sents/labeled_sent_591436.csv',
#  'Format_sents/form_sent_57333.csv',
#  'Format_sents/labeled_sent_1004774.csv',
#  'Format_sents/form_sent_259654.csv',
#  'Format_sents/labeled_sent_686187.csv',
#  'Format_sents/labeled_sent_441645.csv',
#  'Format_sents/form_sent_484931.csv',
#  'Format_sents/form_sent_161482.csv',
#  'Format_sents/labeled_sent_400104.csv',
#  'Format_sents/form_sent_760207.csv',
#  'Format_sents/labeled_sent_1097933.csv',
#  'Format_sents/form_sent_691862.csv',
#  'Format_sents/labeled_sent_162241.csv',
#  'Format_sents/form_sent_563595.csv',
#  'Format_sents/form_sent_460383.csv',
#  'Format_sents/form_sent_748778.csv',
#  'Format_sents/labeled_sent_933297.csv',
#  'Format_sents/labeled_sent_411206.csv',
#  'Format_sents/form_sent_459043.csv',
#  'Format_sents/labeled_sent_733016.csv',
#  'Format_sents/form_sent_369242.csv',
#  'Format_sents/labeled_sent_819315.csv',
#  'Format_sents/labeled_sent_736933.csv',
#  'Format_sents/form_sent_869108.csv',
#  'Format_sents/form_sent_1125305.csv',
#  'Format_sents/form_sent_155592.csv',
#  'Format_sents/form_sent_274624.csv',
#  'Format_sents/form_sent_125628.csv',
#  'Format_sents/labeled_sent_805703.csv',
#  'Format_sents/labeled_sent_951664.csv',
#  'Format_sents/form_sent_615725.csv',
#  'Format_sents/labeled_sent_117384.csv',
#  'Format_sents/labeled_sent_292631.csv',
#  'Format_sents/form_sent_1046950.csv',
#  'Format_sents/labeled_sent_392170.csv',
#  'Format_sents/form_sent_631027.csv',
#  'Format_sents/form_sent_1063722.csv',
#  'Format_sents/labeled_sent_560476.csv',
#  'Format_sents/form_sent_77813.csv',
#  'Format_sents/labeled_sent_48958.csv',
#  'Format_sents/labeled_sent_999957.csv',
#  'Format_sents/labeled_sent_420170.csv',
#  'Format_sents/form_sent_1035534.csv',
#  'Format_sents/form_sent_1092021.csv',
#  'Format_sents/labeled_sent_38237.csv',
#  'Format_sents/form_sent_343123.csv',
#  'Format_sents/labeled_sent_235654.csv',
#  'Format_sents/form_sent_473269.csv',
#  'Format_sents/form_sent_251913.csv',
#  'Format_sents/labeled_sent_662321.csv',
#  'Format_sents/labeled_sent_560957.csv',
#  'Format_sents/labeled_sent_169509.csv',
#  'Format_sents/form_sent_635796.csv',
#  'Format_sents/labeled_sent_485773.csv',
#  'Format_sents/form_sent_529002.csv',
#  'Format_sents/form_sent_815695.csv',
#  'Format_sents/form_sent_276687.csv',
#  'Format_sents/form_sent_662633.csv',
#  'Format_sents/form_sent_975040.csv',
#  ...]

# %% [markdown]
# ## Viz interface Data

# %%
df = pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')

# %%
df.head()
# Out:
#    ORIGIN_ID   PREDICATE SUBJECT_CUI OBJECT_CUI  label_proba
# 0          0  PROCESS_OF    C0003725   C0999630     1.000000
# 1          1         ISA    C0039258   C0446169     1.000000
# 2          2         ISA    C0318627   C0206590     1.000000
# 3          3         ISA    C0446169   C0003725     1.000000
# 4          4  PROCESS_OF    C0012634   C0020114     0.989018

# %%
FG = nx.from_pandas_edgelist(df, source='SUBJECT_CUI', target='OBJECT_CUI', create_using=nx.DiGraph())

# %%
FG

# %%
save_json(join('all_triples', 'all_entity_eigenvector_centrality.json'), nx.eigenvector_centrality(FG))

# %%
max(list(nx.eigenvector_centrality(FG).values()))
# Out:
# 0.08687484613292439

# %%
min(list(nx.degree_centrality(FG).values())
# Out:
# 2.89863474303603e-06

# %%
max(list(nx.degree_centrality(FG).values()))
# Out:
# 0.3727934143018638

# %% [markdown]
# ## Node Names

# %%
all_files = sorted(glob(join(PREDICATION_DIR,'*.gz')))

# %%
def canonize_dict(cui_dict):
    fixed_dict = {}
    for cui in cui_dict:
        cuis = process_cui(cui)
        nots = cui_dict[cui].split('|')
        if (len(nots) == 1) & (len(cuis) > 1) :
            nots = nots*len(cuis)
        fixed_dict.update(dict(zip(cuis, nots)))
    return fixed_dict

def get_entity_names_types():
    all_files = sorted(glob(join(PREDICATION_DIR,'*.gz')))
    all_entity_names = {}
    all_entity_types = {}
    for f_name in tqdm(all_files):
        df = pd.read_csv(f_name,  compression= 'gzip', sep = ',', encoding='iso-8859-1', header=None, names = PREDICATION_COLS)
        cui_dict = canonize_dict(dict(zip(list(df['OBJECT_CUI']), list(df['OBJECT_NAME']))))
        all_entity_names.update(cui_dict)
        cui_dict = canonize_dict(dict(zip(list(df['OBJECT_CUI']), list(df['OBJECT_SEMTYPE']))))
        all_entity_types.update(cui_dict)
        cui_dict = canonize_dict(dict(zip(list(df['SUBJECT_CUI']), list(df['SUBJECT_NAME']))))
        all_entity_names.update(cui_dict)
        cui_dict = canonize_dict(dict(zip(list(df['SUBJECT_CUI']), list(df['SUBJECT_SEMTYPE']))))
        all_entity_types.update(cui_dict)
    return all_entity_names, all_entity_types

# %%
all_entity_names, all_entity_types = get_entity_names_types()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# /tmp/ipykernel_104960/2818945891.py:16: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f_name,  compression= 'gzip', sep = ',', encoding='iso-8859-1', header=None, names = PREDICATION_COLS)
# /tmp/ipykernel_104960/2818945891.py:16: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f_name,  compression= 'gzip', sep = ',', encoding='iso-8859-1', header=None, names = PREDICATION_COLS)
# /tmp/ipykernel_104960/2818945891.py:16: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f_name,  compression= 'gzip', sep = ',', encoding='iso-8859-1', header=None, names = PREDICATION_COLS)
# /tmp/ipykernel_104960/2818945891.py:16: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f_name,  compression= 'gzip', sep = ',', encoding='iso-8859-1', header=None, names = PREDICATION_COLS)
# /tmp/ipykernel_104960/2818945891.py:16: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f_name,  compression= 'gzip', sep = ',', encoding='iso-8859-1', header=None, names = PREDICATION_COLS)
# /tmp/ipykernel_104960/2818945891.py:16: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f_name,  compression= 'gzip', sep = ',', encoding='iso-8859-1', header=None, names = PREDICATION_COLS)

# %%
save_json(join('all_triples', 'all_entity_names.json'), all_entity_names)

# %%
save_json(join('all_triples', 'all_entity_types.json'), all_entity_types)

# %%
len(all_entity_names)
# Out:
# 370641

# %%
len(all_entity_types)
# Out:
# 370641

# %%
df[1]
# Out:
# {'C0999630': 'Lepus capensis',
#  'C0446169': 'California Group Viruses',
#  'C0206590': 'Coltivirus',
#  'C0003725': 'JUN',
#  'C0020114': 'Human',
#  'C0012634': 'Disease',
#  'C0003241': 'Antibodies',
#  'C0002273': 'FHL1',
#  'C0006034': 'Borrelia burgdorferi',
#  'C0019878': 'homocysteine',
#  'C0025646': 'Methionine',
#  'C0017262': 'Gene Expression',
#  'C0001675': 'CFD',
#  'C0042567': 'Vertebrates',
#  'C1167395': 'host',
#  'C0003062': 'HCRTR2',
#  'C0162318': 'Farm Animals',
#  'C1136254': 'Microbicides',
#  'C0949665': 'Fluoroquinolones',
#  'C0013227': 'Pharmaceutical Preparations',
#  'C0014061': 'Tick-Borne Encephalitis',
#  'C0030705': 'Patients',
#  'C0086287': 'Females',
#  'C0086582': 'Males',
#  'C1552130': '16s',
#  'C0237401': 'Individual',
#  'C1457887': 'Symptoms',
#  'C0021311': 'Infection',
#  'C0089701': '1-oleoyl-2-stearoylphosphatidylcholine',
#  'C0012854': 'DNA',
#  'C0456981': 'Specific antigen',
#  'C0021368': 'Inflammation',
#  'C0004368': 'Autoimmunity',
#  'C0039194': 'T-Lymphocyte',
#  'C0003315': 'HSPB1',
#  'C0670896': 'Toll-like receptors',
#  'C1185625': 'Compartments',
#  'C0597357': 'receptor',
#  'C0035549': 'Ribose',
#  'C0162638': 'Apoptosis',
#  'C0998896': 'Scorpaenidae',
#  'C0332124': 'No past history',
#  'C0015780': 'Female',
#  'C0998689': 'Hemicentrotus pulcherrimus',
#  'C0017199': 'Gastrula',
#  'C0162415': 'Mesenchyma',
#  'C0181909': 'Mounts',
#  'C0005539': 'biomedical engineering field',
#  'C0026591': 'Mothers',
#  'C0028661': 'Nurses',
#  'C0037863': 'Spermatocytes',
#  'C0007634': 'Cells',
#  'C0036679': 'Diastasis',
#  'C0034693': 'Rattus norvegicus',
#  'C0032594': 'Polysaccharides',
#  'C0033692': 'Proteoglycan',
#  'C0017973': 'Glycosaminoglycans',
#  'C0028959': 'TMEM176B',
#  'C0204514': 'Structural analysis',
#  'C0012611': 'Disaccharides',
#  'C1533168': 'Sorbate',
#  'C0039231': 'Tachycardia',
#  'C0029463': 'osteosarcoma',
#  'C0006826': 'Malignant Neoplasms',
#  'C0683971': 'General Population',
#  'C0087111': 'Therapeutic procedure',
#  'C0020063': 'PTH protein, human',
#  'C0025741': 'Methyldopa',
#  'C0027651': 'Neoplasm',
#  'C0017337': 'Genes',
#  'C1414461': 'ESR1 gene',
#  'C1412099': 'ABO gene',
#  'C1414462': 'ESR2 gene',
#  'C1412100': 'ADA',
#  'C0014939': 'Estrogens',
#  'C0043210': 'Woman',
#  'C0029456': 'Osteoporosis',
#  'C0028754': 'Obesity',
#  'C0227525': 'Hepatocyte',
#  'C0021390': 'Inflammatory Bowel Diseases',
#  'C0020541': 'Hypertension, Portal',
#  'C0001645': 'AKR1C1',
#  'C0016059': 'Fibrosis',
#  'C1511606': 'Cystic Lesion',
#  'C0235974': 'Pancreatic carcinoma',
#  'C0027051': 'Myocardial Infarction',
#  'C0240816': 'Prostitute NOS',
#  'C0342257': 'Complications of Diabetes Mellitus',
#  'C1275743': 'Co-morbid conditions',
#  'C0011854': 'Diabetes Mellitus, Insulin-Dependent',
#  'C0008946': 'Climate',
#  'C0016627': 'Influenza in Birds',
#  'C0027361': 'Persons',
#  'C0012746': 'Dissociative disorder',
#  'C1261469': 'End stage renal failure',
#  'C1565489': 'Renal Insufficiency',
#  'C0699748': 'Pathogenesis',
#  'C0010852': 'Cytoskeletal Proteins',
#  'C0024141': 'MARS',
#  'C0879626': 'Adverse effects',
#  'C0011065': 'UBE2C',
#  'C0160420': 'Injury to kidney NOS',
#  'C0277785': 'Functional disorder',
#  'C0079189': 'cytokine',
#  'C0175677': 'Injury',
#  'C0008059': 'Child',
#  'C0015879': 'Ferritin',
#  'C0022658': 'Kidney Diseases',
#  'C1257890': 'Population Group',
#  'C0022661': 'Kidney Failure, Chronic',
#  'C0035078': 'Kidney Failure',
#  'C0011947': 'Dialysis Solutions',
#  'C0021760': 'Interleukin-6',
#  'C1159690': 'sodium ion transport',
#  'C0019868': 'Homeostasis',
#  'C0552639': 'TUBULAR CELLS',
#  'C0031727': 'Phosphotransferases',
#  'C0002006': 'ELN',
#  'C0040649': 'Transcription, Genetic',
#  'C0005826': 'Abnormal blood pressure',
#  'C0022646': 'Kidney',
#  'C0019247': 'Hereditary Diseases',
#  'C1272641': 'Systemic arterial pressure',
#  'C0596070': 'American',
#  'C0574785': 'Lower urinary tract symptoms',
#  'C0025266': 'Male population group',
#  'C0003385': 'Muscarinic Antagonists',
#  'C0680022': 'member',
#  'C0026447': 'Monkeys',
#  'C0034927': 'Patient referral',
#  'C1261322': 'Assessment procedure',
#  'C0162326': 'DNA Sequence',
#  'C0201683': 'Chemical method',
#  'C0021102': 'Implants',
#  'C0221192': 'Author',
#  'C0022122': 'Bone structure of ischium',
#  'C0206365': 'Structure of collateral ligament',
#  'C0037004': 'Shoulder',
#  'C0243032': 'Magnetic Resonance Angiography',
#  'C0947637': 'Stenosis, unspecified',
#  'C0007282': 'Carotid Stenosis',
#  'C0333463': 'Senile Plaques',
#  'C0260280': 'Technologist NOS',
#  'C0871685': 'Clinicians',
#  'C0037313': 'Sleep',
#  'C0037317': 'Sleep disturbances',
#  'C0442696': 'Waking',
#  'C0920580': 'medical specialist',
#  'C0039593': 'Testing',
#  'C0003364': 'HUS1',
#  'C1420485': 'STN gene',
#  'C1421917': 'EEF1A2',
#  'C0948089': 'Acute coronary syndrome',
#  'C0162589': 'Defibrillators, Implantable',
#  'C0017638': 'Glioma',
#  'C0007595': 'Cell Growth',
#  'C0178874': 'Neoplasm progression',
#  'C0074992': 'sphingosine 1-phosphate',
#  'C0599779': 'Animal Model',
#  'C0431085': '[M]Unspecified tumor cell NOS',
#  'C1307407': 'FRAP1 protein, human',
#  'C1302475': 'MTOR',
#  'C0280100': 'Solid tumor',
#  'C0678613': 'feedback inhibition',
#  'C0013081': 'Down-Regulation',
#  'C0023467': 'NPTXR',
#  'C0026809': 'Mus',
#  'C0596263': 'Carcinogenesis',
#  'C0242379': 'Malignant neoplasm of lung',
#  'C0001418': 'Adenocarcinoma',
#  'C0599161': 'Reverse Transcriptase Polymerase Chain Reaction',
#  'C0685938': 'Malignant neoplasm of gastrointestinal tract',
#  'C0237753': 'Numbers',
#  'C0027627': 'Neoplasm Metastasis',
#  'C1326912': 'Tumorigenesis',
#  'C0003250': 'Monoclonal Antibodies',
#  'C0005847': 'Blood Vessels',
#  'C0450238': 'Whole chromosome',
#  'C0028303': 'Nondisjunction, Genetic',
#  'C0796346': 'polymorphic microsatellite markers',
#  'C0015576': 'Family',
#  'C0009917': 'Contracture',
#  'C0205851': 'Germ cell tumor',
#  'C0175895': 'calcification',
#  'C0039082': 'Syndrome',
#  'C0221198': 'Lesion',
#  'C0687140': 'Hemangioma of skin',
#  'C0027960': 'Nevus',
#  'C0023516': 'SLC39A14',
#  'C1427070': 'TWIST2 gene',
#  'C1117581': 'TWIST2',
#  'C0021270': 'Infant',
#  'C0030208': 'Paintings',
#  'C0162789': 'Fluorescent in Situ Hybridization',
#  'C0182400': 'Probes',
#  'C0004509': 'ATP8',
#  'C1420418': 'SRY gene',
#  'C1426736': 'SRY',
#  'C0026882': 'Mutation',
#  'C0006926': 'Caprolactam',
#  'C0243069': 'Hypoplasia',
#  'C0013570': 'Ecthyma, Contagious',
#  'C0000768': 'CA9',
#  'C1564139': 'Mutant Proteins',
#  'C0003123': 'HLA-DRB1',
#  'C0129831': 'RBM45',
#  'C0337857': 'Athabascans',
#  'C0002085': 'Alleles',
#  'C0870604': 'Girls',
#  'C0240182': 'Leukonychia',
#  'C0263534': "Beau's lines",
#  'C0152096': "Edward's syndrome NOS",
#  'C0007603': 'Cell membrane',
#  'C0023779': 'ARHGAP8',
#  'C1524082': 'Derivation procedure',
#  'C0683911': 'Vehicle accident NOS',
#  'C0018787': 'Heart',
#  'C0677898': 'Invasive Malignant Neoplasm',
#  'C1527116': 'Workers',
#  'C0015264': 'Exertion',
#  'C0030450': 'Paramedical Personnel',
#  'C1280632': 'Entire trunk',
#  'C1273869': 'Intervention regimes',
#  'C0208355': 'multicatalytic endopeptidase complex',
#  'C0175996': 'Protoplasm',
#  'C0023884': 'Liver',
#  'C1150095': 'hydrolase, acting on peptide bonds activity',
#  'C0679646': 'Participant',
#  'C0079633': 'Interleukin-8',
#  'C1171892': 'VEGF protein, human',
#  'C1177422': 'VEGFA',
#  'C0018270': 'Growth',
#  'C0302600': 'Angiogenesis',
#  'C0030946': 'Endopeptidases',
#  'C0449619': 'ERVK-7',
#  'C0619465': 'ERVK-8',
#  '100616101': 'ERVK-10',
#  '100616102': 'ERVK-9',
#  '100616103': 'ERVK-21',
#  '100775105': 'ERVK-18',
#  '100862683': 'ERVK-25',
#  '100862684': 'ERVK-24',
#  '100862685': 'ERVK-19',
#  'C0040018': 'Thrombin',
#  'C0033954': 'Psychosine',
#  'C0005320': 'Betaxolol',
#  'C0008399': 'PLA2G10',
#  'C0023521': 'RPL13A',
#  'C0027347': 'STK39',
#  'C0079904': 'NF-kappa B',
#  'C0752312': 'Mitogen-Activated Protein Kinases',
#  'C1367731': 'MAPK8 gene',
#  'C1365599': 'MAPK8',
#  'C1451465': 'CRK protein, human',
#  'C1451398': 'CRK',
#  'C0024296': 'Lymphoid Tissue',
#  'C0524851': 'Neurodegenerative Disorders',
#  'C0521989': 'Associated symptom',
#  'C0025914': 'House mice',
#  'C1136031': 'RNA Interference',
#  'C1510464': 'Protein Structure',
#  'C0036025': 'Saccharomyces cerevisiae',
#  'C0032433': 'Polyamines',
#  'C0037871': 'Spermidine',
#  'C0037874': 'Spermine',
#  'C0000618': '6-Mercaptopurine',
#  'C0039902': 'Thioguanine',
#  'C0597573': 'thiopurine',
#  'C0061415': 'Glucose-1-phosphate adenylyltransferase',
#  'C0014442': 'Enzymes',
#  'C0021853': 'Intestines',
#  'C0275521': 'Clinical infection',
#  'C0647210': 'monooxyethylene trimethylolpropane tristearate',
#  'C0036945': 'Sheep',
#  'C0031164': 'Permeability',
#  'C0019054': 'hemolysis',
#  'C0030956': 'Peptides',
#  'C0007526': 'Capuchin Monkey',
#  'C0999514': 'Cebus apella',
#  'C0027312': 'NADPH Dehydrogenase',
#  'C0003402': 'Antioxidants',
#  'C1556111': 'Supernumerary mandibular left first primary molar',
#  'C0243144': 'uptake',
#  'C0220839': 'Glutamate',
#  'C0521119': 'Extracellular',
#  'C0599732': 'cell injury',
#  'C0003596': 'IL13',
#  'C0871261': 'response',
#  'C1330957': 'Cytokinesis of the fertilized ovum',
#  'C0007124': 'Noninfiltrating Intraductal Carcinoma',
#  'C0025920': 'Mice, Inbred C3H',
#  'C0016693': 'Free Radicals',
#  'C0007682': 'CNS disorder',
#  'C0070002': 'panaxydol',
#  'C0135190': 'panaxynol',
#  'C0007587': 'ZNF37A',
#  'C0600437': 'Nitric Oxide Donors',
#  'C0037533': 'Sodium Nitroprusside',
#  'C0162493': 'Transcriptional Activation',
#  'C1159816': 'anti-apoptosis',
#  'C0027746': 'Nerve Degeneration',
#  'C0039259': 'Tail',
#  'C0053932': 'Bone Morphogenetic Proteins',
#  'C0243043': 'Heat-Shock Proteins 70',
#  'C0243308': 'HSPA4',
#  'C0085078': 'Lysosomal Storage Diseases',
#  'C0057192': 'MCOLN1',
#  'C0238286': 'Type IV Mucolipidosis',
#  'C0005495': 'PPM1B',
#  'C0010620': 'ARID3B',
#  'C0037303': 'Bone structure of cranium',
#  'C0015914': 'Fertilization',
#  'C0755562': 'PRKAA1',
#  'C0169101': 'Mitogen-Activated Protein Kinase Kinases',
#  'C1326638': 'midbrain development',
#  'C0026649': 'Movement',
#  'C0005075': 'PAX1',
#  'C0006899': 'Capillaria philippinensis infection',
#  'C0081029': 'WNT5B',
#  'C1333539': 'FGF8 gene',
#  'C1332253': 'FGF8',
#  'C0013935': 'Embryo',
#  'C0035298': 'Retina',
#  'C0027908': 'Neurotransmitters',
#  'C0154828': 'Traction detachment of retina',
#  'C0016904': 'gamma-Aminobutyric Acid',
#  'C0017890': 'Glycine',
#  'C0039350': 'Taurine',
#  'C0085845': 'Aspartate',
#  'C0271055': 'Rhegmatogenous retinal detachment',
#  'C0043457': 'Zebrafish',
#  'C0055359': 'STYK1',
#  'C0035309': 'Retinal Diseases',
#  'C0042164': 'Uveitis',
#  'C0015392': 'Eye',
#  'C0042338': 'Human herpesvirus 3',
#  'C0006962': 'TRBV20OR9-2',
#  'C1155266': 'Inflammatory Response',
#  'C0001992': 'SERPINB1',
#  'C0033684': 'Proteins',
#  'C0034700': 'Rats, Inbred BN',
#  'C0025519': 'Metabolism',
#  'C0035322': 'Structure of retinal pigment epithelium',
#  'C0242643': 'P-Glycoprotein',
#  'C0039005': 'Family suidae',
#  'C0376622': 'ABCB1 gene',
#  'C0375243': 'ABCB1',
#  'C0042523': 'Verapamil',
#  'C0598829': 'MDCK cell',
#  'C0026336': 'Study models',
#  'C0242383': 'Age related macular degeneration',
#  'C0724693': 'Sildenafil citrate',
#  'C0200189': 'Fundus photography',
#  'C0032042': 'Placebos',
#  'C0595862': 'Vasodilation disorder',
#  'C0595921': 'Intraocular pressure disorder',
#  'C0017601': 'Glaucoma',
#  'C0543467': 'Operative Surgical Procedures',
#  'C0161398': 'Optic Nerve Injuries',
#  'C0014597': 'Epithelial Cells',
#  'C1278886': 'Entire lacrimal gland',
#  'C0015283': 'Exocytosis',
#  'C0085243': 'Mice, Inbred NOD',
#  'C0069580': 'Opsin',
#  'C1366586': 'SNW1 Gene',
#  'C1182610': 'Corneal epithelial cell',
#  'C0005575': 'PRKAR1B',
#  'C0033640': 'PROTEIN KINASE',
#  'C0164786': 'Proto-Oncogene Proteins c-akt',
#  'C0164207': 'AKT1',
#  'C0085140': 'Prosencephalon',
#  'C0700329': 'Physical shape',
#  'C0004153': 'MBL2',
#  'C0022203': 'Isomerism',
#  'C0253005': 'chitotriosidase',
#  'C0026473': 'monocyte',
#  'C0599755': 'cohort',
#  'C0031676': 'Phospholipids',
#  'C0577631': 'Carotid Atherosclerosis',
#  'C0003313': 'HSPA9',
#  'C0004366': 'Autoimmune Response',
#  'C0003320': 'HSP90AA1',
#  'C0023820': 'Lipoproteins',
#  'C0003593': 'Apolipoproteins B',
#  'C0003338': 'Antigens, Protozoan',
#  'C0008377': 'Cholesterol',
#  'C0205847': 'Middle Aged',
#  'C1441526': 'COMPUTED',
#  'C0201699': 'Electrophoresis, Capillary',
#  'C0038792': 'Sulindac',
#  'C0544357': 'Human plasma',
#  'C0043047': 'Water',
#  'C0870883': 'Metabolites',
#  'C0042960': 'Voluntary Workers',
#  'C1511790': 'Detection',
#  'C0010825': 'NEU3',
#  'C1155099': 'cytokine biosynthesis',
#  'C0376387': 'Recipient, Transplant',
#  'C0443769': 'volatile substances',
#  'C0085979': 'Cavia',
#  'C0172537': 'Gelatinase A',
#  'C0596981': 'Muscle Cells',
#  'C0035126': 'Reperfusion Injury',
#  'C0232164': 'Cardiac function',
#  'C0000970': 'CD70',
#  'C0085540': 'Anabaena',
#  'C0949707': 'Sensory Rhodopsins',
#  'C0025979': 'Microfilaments',
#  'C1517186': 'Filament',
#  'C1180307': 'F-Actin',
#  'C0920283': 'helicase',
#  'C0164045': 'HFM1',
#  'C0334861': 'Biological scientist NOS',
#  'C0009368': 'SLC9A3R1',
#  'C0669372': 'NOS2A protein, human',
#  'C0664843': 'NOS2',
#  'C1519670': 'Tumor Angiogenesis',
#  'C0520484': 'Xenograft procedure',
#  'C1122629': 'ZD 6126',
#  'C0598934': 'tumor growth',
#  'C0032821': 'Potassium',
#  'C0002062': 'Alkaloids',
#  'C0007097': 'TLR2',
#  'C0077678': 'ubiquitin-protein ligase',
#  'C1481993': 'Haloviruses',
#  'C0003346': 'HTN1',
#  'C0007435': 'Catheterization, Central Venous',
#  'C0010614': 'HEXIM1',
#  'C0042776': 'Virus',
#  'C1136253': 'Prophages',
#  'C0677040': 'Stereochemistry',
#  'C0728810': 'Butyrylcholinesterase',
#  'C0728590': 'BCHE',
#  'C0032447': 'Polychlorinated Biphenyls',
#  'C0020247': 'Hydrocarbons, Chlorinated',
#  'C0043076': 'Waxes',
#  'C0969677': 'alpha Tocopherol',
#  'C0075816': 'taraxerol',
#  'C0024947': 'Maxilla',
#  'C0033147': 'Primates',
#  'C0007009': 'TMBIM6',
#  'C0040642': 'Transcobalamins',
#  'C0699791': 'Stomach Carcinoma',
#  'C0016157': 'Fish Oils',
#  'C0007613': 'Cell physiology',
#  'C0010406': 'Cryoprotective Agents',
#  'C0007450': 'Felis catus',
#  'C0021359': 'Infertility',
#  'C0012984': 'Canis familiaris',
#  'C0939793': 'Bitch',
#  'C0029045': 'Oocytes',
#  'C0032961': 'Pregnancy',
#  'C0007452': 'Cattle',
#  'C0680063': 'Offspring',
#  'C0009013': 'TAF1C',
#  'C1334043': 'Homologous Gene',
#  'C0230956': 'Infraclass Eutheria',
#  'C1335188': 'PAG gene',
#  'C1335052': 'PRDX1',
#  'C1355824': 'PAG1',
#  'C0025252': 'Membrane Proteins',
#  'C0037813': 'Spectrum Analysis, Mass',
#  'C1167622': 'Binding (Molecular Function)',
#  'C0029418': 'Osteoblasts',
#  'C0180153': 'Covers',
#  'C0007586': 'ZKSCAN1',
#  'C0235169': 'Excitability',
#  'C0007765': 'Cerebellum',
#  'C0184906': 'Bifurcation',
#  'C0043775': "1,2-bis(2-aminophenoxy)ethane-N,N,N',N'-tetraacetic acid",
#  'C0288263': 'Calcium Channels, L-Type',
#  'C0006732': 'SRPK1',
#  'C0006685': 'Calcium Channel',
#  'C1395184': 'depolarization',
#  'C0011646': 'Dermis',
#  'C0150866': 'Biopsy of skin procedure',
#  'C1540912': 'Hypereosinophilic syndrome',
#  'C0024301': 'Lymphoma, Follicular',
#  'C0013216': 'Pharmacotherapy',
#  'C0040808': 'Treatment Protocols',
#  'C0032136': 'Plasmids',
#  'C0025516': 'Metabolic Detoxication, Drug',
#  'C0033809': 'Pseudomonas aeruginosa',
#  'C0029224': 'Organic Chemicals',
#  'C0441665': 'Disk diffusion',
#  'C0054498': 'SMOX',
#  'C0014834': 'Escherichia coli',
#  'C0599770': 'genetic element',
#  'C0004589': 'MUC7',
#  'C0042765': 'Virulence',
#  'C0817320': 'Left femur',
#  'C0001166': 'Acoustics',
#  'C1328436': 'Amino acid level',
#  'C0023401': 'Leucine',
#  'C0002521': 'Amino Acids, Branched-Chain',
#  'C0034703': 'Rats, Inbred F344',
#  'C0028778': 'Obstruction',
#  'C1519106': 'Rodent Model',
#  'C0525033': 'Probiotics',
#  'C0010125': 'RASGRP1',
#  'C0812385': 'BCR gene',
#  'C0812613': 'BCR',
#  'C0034790': 'T-Cell Receptor',
#  'C0036962': 'TRBV20OR9-2',
#  'C0214570': 'cyclin D2',
#  'C0214894': 'CCND2',
#  'C0021758': 'Interleukin-4',
#  'C0029433': 'Osteogenesis',
#  'C0021289': 'Infant, Newborn',
#  'C0131450': 'CD200R1',
#  'C0029431': 'Osteoclasts',
#  'C0333957': 'Growth acceleration',
#  'C1154313': 'biological_process',
#  'C0002895': 'GRID2',
#  'C0014792': 'Erythrocytes',
#  'C0018801': 'Heart failure',
#  'C0038435': 'Stress',
#  'C0021641': 'Insulin',
#  'C0004936': 'Mental disorders',
#  'C0029343': 'Influenza A Virus, Avian',
#  'C0935640': 'Baculovirus',
#  'C1522485': 'Tracer',
#  'C0040674': 'Transposition procedure',
#  'C0003242': 'HPD',
#  'C0064755': 'C16orf58',
#  'C0012923': 'DNA Viruses',
#  'C1579410': 'Nucleoside Analogs',
#  'C0206580': 'Orthopoxvirus',
#  'C0441633': 'Scanning',
#  'C0030498': 'Parasites',
#  'C0008415': 'Choline Kinase',
#  'C0029235': 'Organism',
#  'C0529330': 'Receptor, Angiotensin, Type 1',
#  'C0000185': 'AGTR1',
#  'C0027950': 'neutrophil',
#  'C0040395': 'tomography',
#  'C0598958': 'Neuroprotection',
#  'C0600388': 'Extracellular Signal Regulated Kinases',
#  'C0035565': 'Ribulose-Bisphosphate Carboxylase',
#  'C0995501': 'Rhodopseudomonas palustris',
#  'C0679670': 'network',
#  'C0678601': 'covalence',
#  'C0019944': 'Equus caballus',
#  'C0658195': 'sulfide oxidase',
#  'C0046079': '2-diethylaminoethanol',
#  'C0007974': 'Chelating Agents',
#  'C0032089': 'Plant Proteins',
#  'C0034493': 'Oryctolagus cuniculus',
#  'C0301872': 'Immune response',
#  'C0085104': 'Drug Delivery Systems',
#  'C0236075': 'Menopausal symptom',
#  'C0005802': 'PTPRS',
#  'C0178784': 'Organ',
#  'C0033362': 'Proinsulin',
#  'C0029408': 'Degenerative polyarthritis',
#  'C0021107': 'Implantation procedure',
#  'C0029468': 'Osteotomy',
#  'C0010957': 'Tissue damage',
#  'C0013470': 'Eating',
#  'C1154417': 'growth hormone secretion',
#  'C0391690': 'growth hormone secretagogue receptor',
#  'C0041236': 'TRYPSIN',
#  'C0001792': 'Elderly',
#  'C0338656': 'Impaired cognition',
#  'C0596020': 'Does hit',
#  'C0678603': 'electron affinity',
#  'C0175723': 'Bands',
#  'C0042210': 'Vaccines',
#  'C0475463': 'Neutralizing antibody',
#  'C0020964': 'Immunity',
#  'C0180392': 'Detectors',
#  'C0282641': 'Transgenes',
#  'C0079460': 'Granulocyte-Macrophage Colony-Stimulating Factor',
#  'C0071437': 'CSF2',
#  'C0073918': 'LAMC2',
#  'C0206194': 'Survivors',
#  'C1279051': 'Entire fascia',
#  'C0334044': 'Dysplasia',
#  'C0152027': 'Sensory Disorders',
#  'C0423572': 'Pins and needles',
#  'C0002028': 'ENPEP',
#  'C1550678': 'Water Specimen',
#  'C0600688': 'Toxic effect',
#  'C0184661': 'Procedures',
#  'C0004927': 'Behavior',
#  'C0231170': 'Disability NOS',
#  'C0145947': 'Tissue-Inhibitor of Metalloproteinase-1',
#  'C0239946': 'Fibrosis, Liver',
#  'C0016767': 'Fruit',
#  'C0014653': 'Equilibrium',
#  'C0028908': 'Oils',
#  'C0206135': 'Platinum Compounds',
#  'C0599918': 'NEPHROTOXICITY',
#  'C0028128': 'Nitric Oxide',
#  'C0022023': 'Ions',
#  'C0006212': 'Bromates',
#  'C0020282': 'Hydrogen Sulfide',
#  'C0013502': 'Echinococcosis',
#  'C0431648': 'Rokitansky sequence',
#  'C0598067': 'Chondrogenesis',
#  'C1519726': 'Tyrosine Phosphorylation',
#  'C0021665': 'Insulin-Like Growth Factor I',
#  'C0450442': 'Agent',
#  'C0086982': 'Signal Transduction Pathways',
#  'C0971859': 'Bone Growth',
#  'C0007090': 'TLE3',
#  'C0007137': 'TNNI3',
#  'C0003162': 'HMOX1',
#  'C0001430': 'adenoma',
#  'C0024109': 'Lung',
#  'C0023610': 'Gonadorelin',
#  'C0022796': 'COG2',
#  'C1417166': 'MICE gene',
#  'C0001545': 'CYP1B1',
#  'C0919425': 'CYP1A1 gene',
#  'C0911543': 'CYP1A1',
#  'C1148673': 'DNA Binding',
#  'C0035696': 'RNA, Messenger',
#  'C0439861': 'Substance',
#  'C1451357': 'BCAR1 protein, human',
#  'C1459564': 'BCAR1',
#  'C0001275': 'Activated Charcoal',
#  'C0003075': 'CFH',
#  'C0442540': 'Streams',
#  'C0060600': 'fly ash',
#  'C0608091': "Low's mixture",
#  'C0076733': 'titanium dioxide',
#  'C0599786': 'Pollutant',
#  'C0350056': 'Adsorbents',
#  'C0031117': 'Peripheral Neuropathy',
#  'C0442874': 'Neuropathy',
#  'C0458247': 'Allodynia',
#  'C0027836': 'Neuroglia',
#  'C0278220': 'Auditory reflex',
#  'C0036341': 'Schizophrenia',
#  'C0037083': 'Signal Transduction',
#  'C0598501': 'Chromosome Pairing',
#  'C0061928': 'GTPase-Activating Proteins',
#  'C1281026': 'Entire dentate gyrus',
#  'C0107103': 'Brain-Derived Neurotrophic Factor',
#  'C0000761': 'CA3',
#  'C0022471': 'Kainic Acid',
#  'C0085301': 'COL27A1',
#  'C0082353': 'FOS',
#  'C0596588': 'FOS Protein',
#  'C0592353': 'FOS',
#  'C1414908': 'GABRA1 gene',
#  'C1412554': 'GABRA1',
#  'C0027765': 'nervous system disorder',
#  'C0678903': 'Neuronal Transmission',
#  'C0040822': 'Tremor',
#  'C0002554': 'GABRA1',
#  'C0596611': 'Gene Mutation',
#  'C0270736': 'Essential Tremor',
#  'C0007457': 'Caucasoid Race',
#  'C0015859': 'Ferrets',
#  'C0227650': 'Juxtaglomerular cell',
#  'C0268731': 'Renal glomerular disease',
#  'C1260875': 'mating',
#  'C0001041': 'CDSN',
#  'C0026845': 'Muscle',
#  'C0376702': 'COS Cells',
#  'C0001044': 'CDX1',
#  'C0040669': 'Transfection',
#  'C0031849': 'Physostigmine',
#  'C0025086': 'Medical Imaging',
#  'C0162772': 'Reactive Oxygen Species',
#  'C0030193': 'Pain',
#  'C0012683': 'Disinfection',
#  'C0007286': 'TUFT1',
#  'C0311392': 'Physical findings',
#  'C0751922': 'Median Neuropathy',
#  'C0144576': 'Paclitaxel',
#  'C0020429': 'Hyperalgesia',
#  'C0011164': 'Degenerative abnormality',
#  'C0004461': 'Axon',
#  'C0501385': 'Sensory nerve',
#  'C1157338': 'isoprenoid biosynthesis',
#  'C0858318': 'Plasmodium falciparum infection',
#  'C0762819': 'ROP 1 protein, Toxoplasma gondii',
#  'C0678544': 'wave',
#  'C0011573': 'Endogenous depression',
#  'C0167206': 'TM4SF1 protein, human',
#  'C0164071': 'TM4SF1',
#  'C0682708': 'White Matter',
#  'C0058990': 'Eukaryotic Initiation Factor-4G',
#  'C0030943': 'Peptide Initiation Factors',
#  'C0487637': 'T lymphocyte antigen',
#  'C0007786': 'MAP3K12',
#  'C0521449': 'Cytoplasmic',
#  'C0020960': 'Immune Sera',
#  'C0021792': 'Interneurons',
#  'C0575090': 'Equilibration disorder',
#  'C0015535': 'Faculty',
#  'C1335770': 'PTPN1',
#  'C0206745': 'Mice, Knockout',
#  'C0162512': 'Neostriatum',
#  'C0007370': 'Catalepsy',
#  'C0162788': 'In Situ Hybridization',
#  'C0042839': 'Vitamin A',
#  'C0015674': 'Chronic Fatigue Syndrome',
#  'C0020255': 'Hydrocephalus',
#  'C0022116': 'Ischemia',
#  'C0149784': 'biological adaptation to stress',
#  'C0746574': 'METHYLATE',
#  'C1136249': 'Mental Retardation, X-Linked',
#  'C0282109': 'Holoenzymes',
#  'C0013139': 'Drosophila melanogaster',
#  'C0011529': 'Deoxyribonucleotides',
#  'C0026584': 'Culicidae',
#  'C0302583': 'Iron',
#  'C0041912': 'Infections, Upper Respiratory',
#  'C0264221': 'Disorder of upper respiratory system',
#  'C0028429': 'Nose',
#  'C1260880': 'Snuffles',
#  'C0214439': 'marbofloxacin',
#  'C0733758': 'Follicle Stimulating Hormone',
#  'C0736046': 'BRD2',
#  'C0013798': 'Electrocardiogram',
#  'C0002186': 'Alpacas',
#  'C0677666': 'soy protein isolate',
#  'C0007103': 'TSPAN8',
#  'C0074926': 'Soy Proteins',
#  'C0032150': 'Plasmodium falciparum',
#  'C0002345': 'Alternative Splicing',
#  'C0024660': 'Mammals',
#  'C0385463': 'leptin receptor',
#  'C0383953': 'LEPR',
#  'C0017375': 'tat Genes',
#  'C0016898': 'TAT',
#  'C0006104': 'Brain',
#  'C0871125': 'Prepulse Inhibition',
#  'C1337069': 'Trauma, chest',
#  'C0009630': 'GNA14',
#  'C0021756': 'Interleukin-2',
#  'C1159339': 'Protein Secretion',
#  'C0288011': 'NF-AT',
#  'C1155046': 'T-Cell Proliferation',
#  'C0001492': 'Adenylate Cyclase',
#  'C0544650': 'Adrenergic receptor function',
#  'C0002395': 'FXN',
#  'C0017837': 'Glutathione S-Transferase',
#  'C0133482': 'SLCO6A1',
#  'C0373156': 'GSTK1',
#  'C0243192': 'agonists',
#  'C1158770': 'Transcriptional Regulation',
#  'C0020281': 'Hydrogen Peroxide',
#  'C0003197': 'HOXA@',
#  'C0003198': 'HOXA1',
#  'C0003200': 'HOXA3',
#  'C0003201': 'HOXA4',
#  'C0003202': 'HOXA5',
#  'C0003203': 'HOXA6',
#  'C0003204': 'HOXA7',
#  'C0003205': 'HOXA9',
#  'C0003206': 'HOXA10',
#  'C0003207': 'Anti-Infective Agents, Urinary',
#  'C0003209': 'HOXA13',
#  'C1419746': 'RPS6KA5 gene',
#  'C1419252': 'RPS6KA5',
#  'C0031715': 'Phosphorylation',
#  'C0085828': 'Transcription Factor AP-1',
#  'C0082354': 'FOSB',
#  'C0083725': 'Neurofibromatosis Type 1 Protein',
#  'C0083726': 'JUNB',
#  'C0083727': 'Neurogranin',
#  'C0040648': 'TRANSCRIPTION FACTOR',
#  'C0041904': 'Up-Regulation (Physiology)',
#  'C0007620': 'Cell Survival',
#  'C0017360': 'UGP2',
#  '100616496': 'ERVW-4',
#  'C0035668': 'RNA',
#  'C0314732': 'Infectious agent',
#  'C100616496': 'ERVW-4',
#  'C0035366': 'Retroviridae',
#  'C0017281': 'Gene Products, pol',
#  'C0031212': 'Personality Disorders',
#  'C0027882': 'Neurons',
#  'C0047845': '4,5,6,7-tetrahydroisoxazolo(5,4-c)pyridin-3-ol',
#  'C1253955': 'Body cavity structure',
#  'C0038818': 'Sunscreening Agents',
#  'C0857127': 'Induction',
#  'C0020971': 'Immunization',
#  'C0000973': 'Acetanilide',
#  '102723407': 'LOC102723407',
#  'C1332104': 'APPBP2 gene',
#  'C1310513': 'APPBP2',
#  'C0010513': 'APPBP2',
#  'C0206358': 'Umbridae',
#  'C0012186': 'Diethyl Pyrocarbonate',
#  'C0001128': 'CHRM1',
#  'C0042930': 'Vocal cord structure',
#  'C0015350': 'Extracellular Matrix',
#  'C1521828': 'Rate',
#  'C0018483': 'Haemophilus influenzae',
#  'C0052796': 'Azithromycin',
#  'C0340044': 'Acute exacerbation of chronic obstructive airways disease',
#  'C0001617': 'DAZ1',
#  'C0243065': 'Aplasia, NOS',
#  'C0426706': 'Absent kidney',
#  'C0476273': 'Respiratory distress',
#  'C0646681': 'Carrington dermal wound gel',
#  'C0037494': 'Sodium Chloride',
#  'C0023870': 'Lithium',
#  'C0014175': 'Endometriosis, site unspecified',
#  'C0870221': 'Boys',
#  'C0026848': 'Myopathy',
#  'C0521450': 'Lysosomal',
#  'C0450138': 'Cultured skin',
#  'C0015278': 'Glucan 1,4-alpha-Glucosidase',
#  'C0337580': 'Cousin',
#  'C0270960': 'Congenital myopathy, NOS',
#  'C0037047': 'sibling',
#  'C1336014': 'Small RNA',
#  'C1160638': 'Viral life cycle',
#  'C0017004': 'Gamma Cameras',
#  'C0038220': 'Status Epilepticus',
#  'C0012472': 'Dinoprostone',
#  'C0085387': 'Cyclooxygenase Inhibitors',
#  'C0002716': 'Amyloid',
#  'C0486805': 'FRAGMENTS',
#  'C0004774': 'NFIA',
#  'C0004781': 'NFIB',
#  'C0004782': 'NFIC',
#  'C0004784': 'NFIX',
#  'C0114799': 'ESCO1',
#  'C0023621': 'BACE1',
#  'C1269578': 'Entire substantia nigra',
#  'C0013384': 'Dyskinetic syndrome',
#  'C0023570': 'Levodopa',
#  'C1154437': 'dopamine metabolism',
#  'C0030567': 'Parkinson Disease',
#  'C1136180': 'Disease Resistance',
#  'C0057738': 'Diazepam Binding Inhibitor',
#  'C0034170': 'Putrescine',
#  'C0029282': 'Ornithine Decarboxylase',
#  'C0019587': 'Amine Oxidase (Copper-Containing)',
#  'C0052331': 'Arginine decarboxylase',
#  'C0007590': 'Cell division',
#  'C0542479': 'Energy, Physics',
#  'C0001109': 'AKR1C4',
#  'C0034320': 'Diphosphates',
#  'C1157206': 'starch biosynthesis',
#  'C0065042': 'Annexins',
#  'C0032520': 'GAST',
#  'C1157011': 'phenylpropanoid metabolism',
#  'C1156971': 'anthocyanin biosynthesis',
#  'C0004728': 'NDUFS8',
#  'C0374291': 'NDUFS7',
#  'C1370600': 'MAP Kinase Gene',
#  'C1443775': 'Epidermal growth factor receptor inhibitor',
#  'C0596290': 'Cell Proliferation',
#  'C0242982': 'c-erbB-1 Proto-Oncogenes',
#  'C0241956': 'EGFR',
#  'C0387583': 'cyclooxygenase 2',
#  'C0018282': 'Growth Inhibitors',
#  'C1257954': 'Cyclooxygenase 2 Inhibitors',
#  'C0334227': 'Tumor cells, malignant',
#  'C0021557': 'myo-Inositol-1-Phosphate Synthase',
#  'C0596902': 'Membrane Transport Proteins',
#  'C0031621': 'Phosphatidylinositols',
#  'C0021547': 'Inositol',
#  'C0016163': 'Fishes',
#  'C0013839': 'Electromyography',
#  'C1552132': 'Supernumerary mandibular left second molar',
#  'C0008972': 'MGAM',
#  'C1265658': 'Anterior dislocation',
#  'C1293903': 'Vagal stimulation',
#  'C0206131': 'Adipocytes',
#  'C0034715': 'Rats, Sprague-Dawley',
#  'C0596843': 'Adipogenesis',
#  'C0166417': 'PPAR gamma',
#  'C0041004': 'Triglycerides',
#  'C1260899': 'Diamond-Blackfan anemia',
#  'C0073320': 'ribosomal protein S19',
#  'C0398550': 'Congenital pure red cell aplasia',
#  'C0086282': 'Family member',
#  'C0525038': 'Amino Acid Substitution',
#  'C1171362': 'Protein Expression',
#  'C0076934': 'Transposase',
#  'C0446085': 'Aspergillus awamori',
#  'C1335623': 'RIPK1 gene',
#  'C1338737': 'RIPK1',
#  'C0004038': 'LRP4',
#  'C0949771': 'Amino Acid Transporter',
#  'C0230770': 'Endoplasmic reticulum, membrane',
#  'C1159342': 'secretory pathway',
#  'C0016832': 'fungus',
#  'C0033382': 'Proline',
#  'C0017345': 'Genes, Fungal',
#  'C1334046': 'Housekeeping Gene',
#  'C0283827': 'Elongation Factor 1alpha',
#  'C0004810': 'NHS',
#  'C0319683': 'Pleurotus ostreatus',
#  'C1269100': 'Eosinophilic major basic protein',
#  'C1264155': 'MBP',
#  'C0004037': 'Aspergillus fumigatus',
#  'C0017696': 'Glucans',
#  'C0521049': 'Conidium',
#  'C0007623': 'Cell Wall',
#  'C0001962': 'EHHADH',
#  'C0014544': 'Epilepsy',
#  'C0038317': 'Steroids',
#  'C0328038': 'Cyprinus carpio',
#  'C0018120': 'Ovarian Follicle',
#  'C0304866': 'Insulin, Beef',
#  'C0205065': 'Ovaro-',
#  'C0220821': 'dihydropyridine',
#  'C1141639': 'Human Chorionic Gonadotropin',
#  'C1141081': 'CGA',
#  'C1143342': 'HTC2',
#  'C1193659': 'CGB5',
#  'C1325702': 'germinal vesicle',
#  'C0010934': 'MORF4',
#  'C1160520': 'oocyte maturation',
#  'C1366555': 'DPYD gene',
#  'C1361806': 'DPYD',
#  'C0020855': 'IgG1',
#  'C0181835': 'Micromanipulators',
#  'C0017110': 'Gases',
#  'C0020564': 'Hypertrophy',
#  'C0018284': 'Growth Factor',
#  'C0022984': 'Laminin',
#  'C0206535': 'Mice, Inbred mdx',
#  'C0040690': 'Transforming Growth Factor beta',
#  'C0015075': 'Ethylene',
#  'C0920552': 'hormone regulation',
#  'C0597252': 'plant growth/development',
#  'C0678632': 'two-dimensional electrophoresis',
#  'C0068003': 'n-heptane',
#  'C0001975': 'EIF4B',
#  'C0014898': 'Esters',
#  'C0015083': 'ethylene glycol',
#  'C0077096': 'triethylamine',
#  'C0982392': 'SODIUM MONOHYDRATE',
#  'C0035525': 'Ribavirin',
#  'C0002594': 'Transaminases',
#  'C0015695': 'Fatty Liver',
#  'C0010674': 'DURS1',
#  'C0004611': 'Bacteria',
#  'C0175925': 'Dairy cattle',
#  'C0035204': 'Respiration Disorders',
#  'C1136170': 'Virulence Factors',
#  'C0220905': 'regulatory',
#  'C0029921': 'Outpatients',
#  'C0020034': 'Host-Parasite Relations',
#  'C0936012': 'Analysis',
#  'C0019169': 'Hepatitis B Virus',
#  'C0005955': 'Bone Marrow Cells',
#  'C0025936': 'NSL1',
#  'C0301521': 'Therapeutic vaccine',
#  'C0005790': 'Blood coagulation tests',
#  'C0684072': 'albino rat',
#  'C0043342': 'Xenopus',
#  'C1267211': 'Entire duct',
#  'C0006574': 'SLC20A1',
#  'C0231048': 'Pronephric structure',
#  'C0042449': 'Veins',
#  'C0043240': 'Wound Healing',
#  'C1415406': 'H2AFX gene',
#  'C1413014': 'C6 gene',
#  'C0243114': 'purification',
#  'C0008550': 'MAPKAPK5',
#  'C0023630': 'INS',
#  'C0002245': 'FGD1',
#  'C0317603': 'Lactobacillus fermentum',
#  'C0002712': 'GK2',
#  'C0002732': 'Amylose',
#  'C0024658': 'Maltose',
#  'C0065603': 'maltoheptaose',
#  'C0021186': 'Indapamide',
#  'C0185115': 'Extraction',
#  'C0059747': 'ethyl acetate',
#  'C0238806': 'BONE MASS',
#  'C0085268': 'Bone remodeling',
#  'C0033497': 'Propranolol',
#  'C0029419': 'Osteocalcin',
#  'C0000054': 'ACP5',
#  'C0029458': 'Osteoporosis, Postmenopausal',
#  'C0012544': 'Diphosphonates',
#  'C0379199': 'Ibandronate',
#  'C0039401': 'Educational process of instructing',
#  'C0021900': 'Intrauterine Devices',
#  'C0289121': 'PP5 protein-serine-threonine phosphatase',
#  'C0243044': 'HSP90 Heat-Shock Proteins',
#  'C0243320': 'HSP90AA1',
#  'C1335884': 'SWI1',
#  'C0026764': 'Multiple Myeloma',
#  'C1176309': 'bortezomib',
#  'C1443643': 'INSR',
#  'C0178522': 'boronic acid',
#  'C0001271': 'Actins',
#  'C0598148': 'hybrid protein',
#  'C0597428': 'Sedimentation procedure',
#  'C1519619': 'Translational Repression',
#  'C0270814': 'Spastic syndrome',
#  'C0242849': 'Microscopy, Atomic Force',
#  'C0597545': 'synaptogenesis',
#  'C1519751': 'Ubiquitination',
#  'C0302614': 'Guide device',
#  ...}

# %% [markdown]
# ## Full Data

# %%
schema = {
        'source_col' : 'SUBJECT_CUI',
        'rel_col' : 'PREDICATE',
        'dest_col' : 'OBJECT_CUI',
        'source_score' : None,
        'rel_score' : None,
        'dest_score' : None,
        'source_type' : None,
        'rel_type' : None,
        'dest_type' : None,
        'triple_attr_col':None,
        'source_attr_col':None,
        'target_attr_col':None,
    }

# %%
def visual_triples():
    df = pd.read_csv(join('all_triples', 'triples_probabilities.csv'), compression = 'gzip')
    all_entity_names = read_json(join('all_triples', 'all_entity_names.json'))
    all_entity_types = read_json(join('all_triples', 'all_entity_types.json'))
    all_entity_ec = read_json(join('all_triples', 'all_entity_eigenvector_centrality.json'))
    df['SUBJECT_EC'] = df['SUBJECT_CUI'].map(all_entity_ec)
    df['OBJECT_EC'] = df['OBJECT_CUI'].map(all_entity_ec)
    df['SUBJECT_NAME'] = df['SUBJECT_CUI'].map(all_entity_names)
    df['OBJECT_NAME'] = df['OBJECT_CUI'].map(all_entity_names)
    df['SUBJECT_TYPE'] = df['SUBJECT_CUI'].map(all_entity_types)
    df['OBJECT_TYPE'] = df['OBJECT_CUI'].map(all_entity_types)
    return df

# %%
df = visual_triples()

# %%
df
# Out:
#           ORIGIN_ID      PREDICATE SUBJECT_CUI OBJECT_CUI  label_proba  \
# 0                 0     PROCESS_OF    C0003725   C0999630     1.000000
# 1                 1            ISA    C0039258   C0446169     1.000000
# 2                 2            ISA    C0318627   C0206590     1.000000
# 3                 3            ISA    C0446169   C0003725     1.000000
# 4                 4     PROCESS_OF    C0012634   C0020114     0.989018
# ...             ...            ...         ...        ...          ...
# 28416912   23857434  COEXISTS_WITH    C1413909   C1413914     1.000000
# 28416913   23857435     PROCESS_OF    C4023614   C1413909     1.000000
# 28416914   23857435     PROCESS_OF    C4023614   C1413909     1.000000
# 28416915   23857436     PROCESS_OF    C4023614   C1413914     1.000000
# 28416916   23857436     PROCESS_OF    C4023614   C1413914     1.000000
#
#           SUBJECT_EC  OBJECT_EC              SUBJECT_NAME  \
# 0           0.003565   0.000934                       JUN
# 1           0.000257   0.000259              Tahyna virus
# 2           0.000041   0.000223               Eyach virus
# 3           0.000259   0.003565  California Group Viruses
# 4           0.079762   0.076038                   Disease
# ...              ...        ...                       ...
# 28416912    0.000561   0.000397                     LAMA3
# 28416913    0.000016   0.000561       Digenic inheritance
# 28416914    0.000016   0.000561       Digenic inheritance
# 28416915    0.000016   0.000397       Digenic inheritance
# 28416916    0.000016   0.000397       Digenic inheritance
#
#                         OBJECT_NAME SUBJECT_TYPE OBJECT_TYPE
# 0         Lepus capensis (organism)         gngm        mamm
# 1          California Group Viruses         virs        virs
# 2                        Coltivirus         virs        virs
# 3                               JUN         virs        gngm
# 4                             Human         dsyn        grup
# ...                             ...          ...         ...
# 28416912                      LAMB3         gngm        aapp
# 28416913                      LAMA3         genf        gngm
# 28416914                      LAMA3         genf        gngm
# 28416915                      LAMB3         genf        aapp
# 28416916                      LAMB3         genf        aapp
#
# [28416917 rows x 11 columns]

# %%
df.to_csv(join('all_triples', 'triples_probabilities_visual.csv'), index = False, compression = 'gzip')
